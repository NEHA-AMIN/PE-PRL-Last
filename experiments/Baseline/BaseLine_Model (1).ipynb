# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# ls -la /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020/
# Out:
# total 75
# -rw------- 1 root root  5049 May 16 08:44 baseline_phase1.sh
# -rw------- 1 root root  5174 May 16 08:46 COLAB_INSTRUCTIONS.md
# drwx------ 2 root root  4096 May 16 08:47 data
# -rw------- 1 root root   206 May 16 08:39 Dockerfile
# -rw------- 1 root root   198 May 16 08:39 environment.yml
# drwx------ 2 root root  4096 May 16 08:47 exp
# drwx------ 2 root root  4096 May 16 08:47 .git
# drwx------ 2 root root  4096 May 16 08:47 img
# -rw------- 1 root root 11357 May 16 08:39 LICENSE
# -rw------- 1 root root  7204 May 16 08:39 main_informer.py
# -rw------- 1 root root  1366 May 16 08:39 Makefile
# drwx------ 2 root root  4096 May 16 08:47 models
# -rw------- 1 root root 13200 May 16 08:39 README.md
# -rw------- 1 root root    91 May 16 08:39 requirements.txt
# drwx------ 2 root root  4096 May 16 08:47 scripts
# -rw------- 1 root root   987 May 16 08:44 setup_dataset.sh
# drwx------ 2 root root  4096 May 16 08:47 utils

# %% [markdown]
# 1. We faced an issue in utils/tools.py np.Inf and we had to change it to np.inf before running the below command

# %%
import os

project_path = '/content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1'
os.chdir(project_path)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020/baseline_phase1.sh
# Out:
# ...
# Baseline |  PHASE 1 — EXPLORATION
# Components:   Standard Informer (No Ablation)
# Dataset:      ETTh1
# Seed:         2021 (single — exploration only)
# Pred lengths: 96, 192 (trend detection only)
# Total runs:   2
# Start time:   Sat May 16 08:57:06 AM UTC 2026
# ...
# Running from directory: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020
#
# ---------------------------------------------
# RUN:        baseline_ph1_ETTh1_pred96_seed2021
# Pred len:   96
# Start:      Sat May 16 08:57:06 AM UTC 2026
# ---------------------------------------------
# Args in experiment:
# ...

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020/baseline_phase2.sh
# Out:
# ...
# Baseline |  PHASE 2 — COMPREHENSIVE EVALUATION
# Components:   Standard Informer (No Ablation)
# Dataset:      ETTh1
# Seeds:        2021, 2022, 2023 (stability)
# Pred lengths: 24, 48, 96, 192, 336, 720
# Total runs:   18 (6 pred_len × 3 seeds)
# Start time:   Sat May 16 09:11:11 AM UTC 2026
# ...
# Running from directory: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020
#
# ---------------------------------------------
# RUN:        baseline_ph2_ETTh1_pred24_seed2021
# Pred len:   24
# Seed:       2021
# Progress:   0/1 completed
# Start:      Sat May 16 09:11:11 AM UTC 2026
# ---------------------------------------------
# Args in experiment:
# ...

# %% [markdown]
# | Pred Length | Seed | MSE                 | MAE                |
# | ----------- | ---- | ------------------- | ------------------ |
# | 24          | 2021 | 0.49535754323005676 | 0.5016863942146301 |
# | 24          | 2022 | 0.6392446160316467  | 0.5717778205871582 |
# | 24          | 2023 | 0.5344194769859314  | 0.5390632748603821 |
# | 48          | 2021 | 0.6693400740623474  | 0.6273155212402344 |
# | 48          | 2022 | 0.7257512807846069  | 0.6524583101272583 |
# | 48          | 2023 | 0.9293985366821289  | 0.7621724605560303 |
# | 96          | 2021 | 1.2970737218856812  | 0.9025352597236633 |
# | 96          | 2022 | 1.1551694869995117  | 0.8473746776580810 |
# | 96          | 2023 | 1.0166363716125488  | 0.8072066307067871 |
# | 192         | 2021 | 1.2044571638107300  | 0.8983949422836304 |
# | 192         | 2022 | 1.1976531744003296  | 0.8904136419296265 |
# | 192         | 2023 | 1.2741620540618896  | 0.9223884940147400 |
# | 336         | 2021 | 1.3778516054153442  | 0.9498274326324463 |
# | 336         | 2022 | 1.3866355419158936  | 0.9564903974533081 |
# | 336         | 2023 | 1.3751783370971680  | 0.9588176012039185 |
