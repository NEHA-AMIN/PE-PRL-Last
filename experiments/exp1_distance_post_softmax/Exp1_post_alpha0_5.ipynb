# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

project_path = '/content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1'
os.chdir(project_path)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/exp1_distance_post_softmax/setup_dataset.sh
# Out:
# ...
# Setting up ETTh1 Dataset
# ...
# --2026-05-16 13:50:02--  https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2589657 (2.5M) [text/plain]
# Saving to: ‘data/ETT/ETTh1.csv’
#
# data/ETT/ETTh1.csv  100%[===================>]   2.47M  --.-KB/s    in 0.04s
#
# 2026-05-16 13:50:02 (58.9 MB/s) - ‘data/ETT/ETTh1.csv’ saved [2589657/2589657]
#
# ✓ ETTh1.csv downloaded successfully
# File size: 2.5M
# Lines: 17421
# ...
# Dataset setup complete!
# ...

# %%
import os

# Set your Informer data directory
informer_path = f'{project_path}/Informer2020-original'
data_dir = f'{informer_path}/data/ETT'
os.makedirs(data_dir, exist_ok=True)

# File path
data_file = f'{data_dir}/ETTh1.csv'

# Download ETTh1 dataset
if not os.path.exists(data_file):
    print("Downloading ETTh1.csv...")
    os.system(
        f'wget -q "https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv" '
        f'-O "{data_file}"'
    )

# Verify
if os.path.exists(data_file):
    print(f"✅ Download successful: {data_file}")
else:
    print("❌ Download failed.")
# Out:
# ✅ Download successful: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/data/ETT/ETTh1.csv

# %% [markdown]
# ```
# ============================================================
# Exp1-Post  |  PHASE 2 — RESULTS STABILITY (alpha=0.5)
# ============================================================
# Seed      : 2021, 2022, 2023 | Pred lengths: 48, 96, 192, 336
# Start: Sat May 16 01:04:12 PM UTC 2026
# ============================================================
# Files copied.
#
# ------------------------------------------------------------
# RUN 1/12: exp1post_ph2_ETTh1_alpha0.5_pred48_seed2021
# pred_len=48 | seed=2021 | alpha=0.5
# Start: Sat May 16 01:04:12 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred48_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred48_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# 	iters: 100, epoch: 1 | loss: 0.4047991
# 	speed: 0.0896s/iter; left time: 133.5591s
# 	iters: 200, epoch: 1 | loss: 0.4165125
# 	speed: 0.0753s/iter; left time: 104.7867s
# Epoch: 1 cost time: 20.721877813339233
# Epoch: 1, Steps: 265 | Train Loss: 0.4725254 Vali Loss: 0.9832315 Test Loss: 0.8010365
# Validation loss decreased (inf --> 0.983231).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3180692
# 	speed: 0.1773s/iter; left time: 217.4180s
# 	iters: 200, epoch: 2 | loss: 0.3311384
# 	speed: 0.0807s/iter; left time: 90.8670s
# Epoch: 2 cost time: 21.241329431533813
# Epoch: 2, Steps: 265 | Train Loss: 0.3218186 Vali Loss: 1.0184716 Test Loss: 0.8168586
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2600915
# 	speed: 0.1894s/iter; left time: 182.0541s
# 	iters: 200, epoch: 3 | loss: 0.2574400
# 	speed: 0.0863s/iter; left time: 74.2645s
# Epoch: 3 cost time: 22.685966730117798
# Epoch: 3, Steps: 265 | Train Loss: 0.2703719 Vali Loss: 0.9762754 Test Loss: 0.8368736
# Validation loss decreased (0.983231 --> 0.976275).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2483814
# 	speed: 0.1844s/iter; left time: 128.3246s
# 	iters: 200, epoch: 4 | loss: 0.2403499
# 	speed: 0.0819s/iter; left time: 48.7999s
# Epoch: 4 cost time: 21.387677669525146
# Epoch: 4, Steps: 265 | Train Loss: 0.2472901 Vali Loss: 1.0314707 Test Loss: 0.8443373
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.2465499
# 	speed: 0.1789s/iter; left time: 77.1234s
# 	iters: 200, epoch: 5 | loss: 0.2398147
# 	speed: 0.0809s/iter; left time: 26.7938s
# Epoch: 5 cost time: 21.34688711166382
# Epoch: 5, Steps: 265 | Train Loss: 0.2360944 Vali Loss: 1.0240210 Test Loss: 0.8392075
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.2449279
# 	speed: 0.1803s/iter; left time: 29.9233s
# 	iters: 200, epoch: 6 | loss: 0.2209951
# 	speed: 0.0814s/iter; left time: 5.3726s
# Epoch: 6 cost time: 21.46479821205139
# Epoch: 6, Steps: 265 | Train Loss: 0.2298589 Vali Loss: 1.0201882 Test Loss: 0.8268957
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred48_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.8368735313415527, mae:0.7083427309989929
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:06:58 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/12: exp1post_ph2_ETTh1_alpha0.5_pred96_seed2021
# pred_len=96 | seed=2021 | alpha=0.5
# Start: Sat May 16 01:06:58 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.5022398
# 	speed: 0.1123s/iter; left time: 166.7319s
# 	iters: 200, epoch: 1 | loss: 0.4109127
# 	speed: 0.1011s/iter; left time: 140.0371s
# Epoch: 1 cost time: 26.913702726364136
# Epoch: 1, Steps: 264 | Train Loss: 0.5129936 Vali Loss: 1.2104125 Test Loss: 0.9341089
# Validation loss decreased (inf --> 1.210413).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3292662
# 	speed: 0.2260s/iter; left time: 275.9578s
# 	iters: 200, epoch: 2 | loss: 0.3369533
# 	speed: 0.1010s/iter; left time: 113.2481s
# Epoch: 2 cost time: 26.601910829544067
# Epoch: 2, Steps: 264 | Train Loss: 0.3378776 Vali Loss: 1.2712275 Test Loss: 0.7853269
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2927466
# 	speed: 0.2224s/iter; left time: 212.8316s
# 	iters: 200, epoch: 3 | loss: 0.2717262
# 	speed: 0.0995s/iter; left time: 85.2702s
# Epoch: 3 cost time: 26.250582933425903
# Epoch: 3, Steps: 264 | Train Loss: 0.2746608 Vali Loss: 1.2678671 Test Loss: 0.7997403
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2343801
# 	speed: 0.2225s/iter; left time: 154.1919s
# 	iters: 200, epoch: 4 | loss: 0.2569034
# 	speed: 0.1010s/iter; left time: 59.8720s
# Epoch: 4 cost time: 26.54686951637268
# Epoch: 4, Steps: 264 | Train Loss: 0.2489666 Vali Loss: 1.2786050 Test Loss: 0.8105453
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.9341089129447937, mae:0.7257674932479858
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:09:15 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 3/12: exp1post_ph2_ETTh1_alpha0.5_pred192_seed2021
# pred_len=192 | seed=2021 | alpha=0.5
# Start: Sat May 16 01:09:15 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# 	iters: 100, epoch: 1 | loss: 0.5070879
# 	speed: 0.1453s/iter; left time: 213.1910s
# 	iters: 200, epoch: 1 | loss: 0.4025541
# 	speed: 0.1383s/iter; left time: 189.0386s
# Epoch: 1 cost time: 35.888673305511475
# Epoch: 1, Steps: 261 | Train Loss: 0.5595934 Vali Loss: 1.5119539 Test Loss: 1.0011131
# Validation loss decreased (inf --> 1.511954).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.4059753
# 	speed: 0.2958s/iter; left time: 356.7382s
# 	iters: 200, epoch: 2 | loss: 0.3392051
# 	speed: 0.1331s/iter; left time: 147.1794s
# Epoch: 2 cost time: 34.80296444892883
# Epoch: 2, Steps: 261 | Train Loss: 0.3748451 Vali Loss: 1.5224072 Test Loss: 1.1511949
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2884879
# 	speed: 0.2883s/iter; left time: 272.4615s
# 	iters: 200, epoch: 3 | loss: 0.3050632
# 	speed: 0.1348s/iter; left time: 113.9416s
# Epoch: 3 cost time: 35.072784185409546
# Epoch: 3, Steps: 261 | Train Loss: 0.3031624 Vali Loss: 1.5474784 Test Loss: 1.2962580
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2812993
# 	speed: 0.2923s/iter; left time: 199.9103s
# 	iters: 200, epoch: 4 | loss: 0.2688852
# 	speed: 0.1347s/iter; left time: 78.6550s
# Epoch: 4 cost time: 35.1312153339386
# Epoch: 4, Steps: 261 | Train Loss: 0.2769397 Vali Loss: 1.5748770 Test Loss: 1.4254652
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:1.0011125802993774, mae:0.7463927865028381
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:12:15 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 4/12: exp1post_ph2_ETTh1_alpha0.5_pred336_seed2021
# pred_len=336 | seed=2021 | alpha=0.5
# Start: Sat May 16 01:12:15 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred336_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred336_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# 	iters: 100, epoch: 1 | loss: 0.5402782
# 	speed: 0.2062s/iter; left time: 296.3224s
# 	iters: 200, epoch: 1 | loss: 0.4730504
# 	speed: 0.2015s/iter; left time: 269.3422s
# Epoch: 1 cost time: 50.66315412521362
# Epoch: 1, Steps: 256 | Train Loss: 0.5924005 Vali Loss: 1.5652438 Test Loss: 1.0854852
# Validation loss decreased (inf --> 1.565244).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.4443709
# 	speed: 0.4031s/iter; left time: 476.1156s
# 	iters: 200, epoch: 2 | loss: 0.3734454
# 	speed: 0.1923s/iter; left time: 207.8482s
# Epoch: 2 cost time: 49.14125871658325
# Epoch: 2, Steps: 256 | Train Loss: 0.4031662 Vali Loss: 1.7091045 Test Loss: 1.0198233
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3408083
# 	speed: 0.4065s/iter; left time: 376.0283s
# 	iters: 200, epoch: 3 | loss: 0.3275965
# 	speed: 0.1931s/iter; left time: 159.3150s
# Epoch: 3 cost time: 49.47741079330444
# Epoch: 3, Steps: 256 | Train Loss: 0.3282206 Vali Loss: 1.7355998 Test Loss: 1.0443475
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.3088921
# 	speed: 0.4014s/iter; left time: 268.5570s
# 	iters: 200, epoch: 4 | loss: 0.3051113
# 	speed: 0.1932s/iter; left time: 109.9098s
# Epoch: 4 cost time: 49.321356534957886
# Epoch: 4, Steps: 256 | Train Loss: 0.3029163 Vali Loss: 1.7391986 Test Loss: 1.0619696
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred336_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.0854859352111816, mae:0.785200297832489
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:16:26 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 5/12: exp1post_ph2_ETTh1_alpha0.5_pred48_seed2022
# pred_len=48 | seed=2022 | alpha=0.5
# Start: Sat May 16 01:16:26 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred48_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred48_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# 	iters: 100, epoch: 1 | loss: 0.4470874
# 	speed: 0.0994s/iter; left time: 148.2497s
# 	iters: 200, epoch: 1 | loss: 0.3384043
# 	speed: 0.0812s/iter; left time: 112.9377s
# Epoch: 1 cost time: 22.13976812362671
# Epoch: 1, Steps: 265 | Train Loss: 0.4808329 Vali Loss: 0.9842253 Test Loss: 0.8457359
# Validation loss decreased (inf --> 0.984225).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3192956
# 	speed: 0.1876s/iter; left time: 229.9558s
# 	iters: 200, epoch: 2 | loss: 0.3374206
# 	speed: 0.0819s/iter; left time: 92.1779s
# Epoch: 2 cost time: 21.770948886871338
# Epoch: 2, Steps: 265 | Train Loss: 0.3271579 Vali Loss: 0.9752966 Test Loss: 0.7702089
# Validation loss decreased (0.984225 --> 0.975297).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2669905
# 	speed: 0.1824s/iter; left time: 175.2408s
# 	iters: 200, epoch: 3 | loss: 0.2978041
# 	speed: 0.0810s/iter; left time: 69.7496s
# Epoch: 3 cost time: 21.369659900665283
# Epoch: 3, Steps: 265 | Train Loss: 0.2733896 Vali Loss: 0.9741821 Test Loss: 0.8426909
# Validation loss decreased (0.975297 --> 0.974182).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2648235
# 	speed: 0.1812s/iter; left time: 126.1094s
# 	iters: 200, epoch: 4 | loss: 0.2560145
# 	speed: 0.0810s/iter; left time: 48.2891s
# Epoch: 4 cost time: 21.429095029830933
# Epoch: 4, Steps: 265 | Train Loss: 0.2488379 Vali Loss: 0.9550852 Test Loss: 0.7866635
# Validation loss decreased (0.974182 --> 0.955085).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.2532487
# 	speed: 0.1822s/iter; left time: 78.5158s
# 	iters: 200, epoch: 5 | loss: 0.2163927
# 	speed: 0.0810s/iter; left time: 26.8190s
# Epoch: 5 cost time: 21.44308376312256
# Epoch: 5, Steps: 265 | Train Loss: 0.2358579 Vali Loss: 0.9528008 Test Loss: 0.7947472
# Validation loss decreased (0.955085 --> 0.952801).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.2152553
# 	speed: 0.1828s/iter; left time: 30.3376s
# 	iters: 200, epoch: 6 | loss: 0.2184467
# 	speed: 0.0808s/iter; left time: 5.3360s
# Epoch: 6 cost time: 21.46493148803711
# Epoch: 6, Steps: 265 | Train Loss: 0.2297522 Vali Loss: 0.9658059 Test Loss: 0.8004614
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred48_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.7947472333908081, mae:0.6721062660217285
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:19:13 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 6/12: exp1post_ph2_ETTh1_alpha0.5_pred96_seed2022
# pred_len=96 | seed=2022 | alpha=0.5
# Start: Sat May 16 01:19:13 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred96_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred96_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.5001888
# 	speed: 0.1176s/iter; left time: 174.6983s
# 	iters: 200, epoch: 1 | loss: 0.4540088
# 	speed: 0.1008s/iter; left time: 139.6194s
# Epoch: 1 cost time: 26.92685079574585
# Epoch: 1, Steps: 264 | Train Loss: 0.5222316 Vali Loss: 1.1883538 Test Loss: 0.9021871
# Validation loss decreased (inf --> 1.188354).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3539288
# 	speed: 0.2267s/iter; left time: 276.7844s
# 	iters: 200, epoch: 2 | loss: 0.3198631
# 	speed: 0.1010s/iter; left time: 113.2145s
# Epoch: 2 cost time: 26.572988271713257
# Epoch: 2, Steps: 264 | Train Loss: 0.3508135 Vali Loss: 1.2153668 Test Loss: 0.9711096
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3027683
# 	speed: 0.2207s/iter; left time: 211.2533s
# 	iters: 200, epoch: 3 | loss: 0.2817507
# 	speed: 0.0992s/iter; left time: 84.9806s
# Epoch: 3 cost time: 26.20780086517334
# Epoch: 3, Steps: 264 | Train Loss: 0.2842245 Vali Loss: 1.2715989 Test Loss: 0.9898044
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2518770
# 	speed: 0.2228s/iter; left time: 154.3727s
# 	iters: 200, epoch: 4 | loss: 0.2515655
# 	speed: 0.1011s/iter; left time: 59.9261s
# Epoch: 4 cost time: 26.595197916030884
# Epoch: 4, Steps: 264 | Train Loss: 0.2565008 Vali Loss: 1.2416213 Test Loss: 0.9839885
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred96_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.9021872878074646, mae:0.6953125596046448
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:21:30 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 7/12: exp1post_ph2_ETTh1_alpha0.5_pred192_seed2022
# pred_len=192 | seed=2022 | alpha=0.5
# Start: Sat May 16 01:21:30 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred192_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred192_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# 	iters: 100, epoch: 1 | loss: 0.5083776
# 	speed: 0.1459s/iter; left time: 214.0622s
# 	iters: 200, epoch: 1 | loss: 0.4852226
# 	speed: 0.1361s/iter; left time: 186.1108s
# Epoch: 1 cost time: 35.62183904647827
# Epoch: 1, Steps: 261 | Train Loss: 0.5558234 Vali Loss: 1.4216589 Test Loss: 1.0810927
# Validation loss decreased (inf --> 1.421659).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.4114411
# 	speed: 0.2949s/iter; left time: 355.6655s
# 	iters: 200, epoch: 2 | loss: 0.3672883
# 	speed: 0.1337s/iter; left time: 147.8689s
# Epoch: 2 cost time: 34.877053022384644
# Epoch: 2, Steps: 261 | Train Loss: 0.3797315 Vali Loss: 1.5107168 Test Loss: 1.0108385
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2977664
# 	speed: 0.2879s/iter; left time: 272.0576s
# 	iters: 200, epoch: 3 | loss: 0.2831209
# 	speed: 0.1342s/iter; left time: 113.4408s
# Epoch: 3 cost time: 34.95179748535156
# Epoch: 3, Steps: 261 | Train Loss: 0.3074416 Vali Loss: 1.5692266 Test Loss: 0.9900132
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2849137
# 	speed: 0.2914s/iter; left time: 199.3283s
# 	iters: 200, epoch: 4 | loss: 0.2792263
# 	speed: 0.1349s/iter; left time: 78.7754s
# Epoch: 4 cost time: 35.14120626449585
# Epoch: 4, Steps: 261 | Train Loss: 0.2804058 Vali Loss: 1.5561609 Test Loss: 0.9864972
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred192_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:1.0810928344726562, mae:0.7923176884651184
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:24:30 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 8/12: exp1post_ph2_ETTh1_alpha0.5_pred336_seed2022
# pred_len=336 | seed=2022 | alpha=0.5
# Start: Sat May 16 01:24:30 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred336_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred336_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# 	iters: 100, epoch: 1 | loss: 0.6055079
# 	speed: 0.2062s/iter; left time: 296.3516s
# 	iters: 200, epoch: 1 | loss: 0.4498246
# 	speed: 0.1975s/iter; left time: 264.0782s
# Epoch: 1 cost time: 50.44519090652466
# Epoch: 1, Steps: 256 | Train Loss: 0.5843028 Vali Loss: 1.6036568 Test Loss: 1.1433383
# Validation loss decreased (inf --> 1.603657).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.4009806
# 	speed: 0.4056s/iter; left time: 478.9945s
# 	iters: 200, epoch: 2 | loss: 0.3457044
# 	speed: 0.1926s/iter; left time: 208.1916s
# Epoch: 2 cost time: 49.206218242645264
# Epoch: 2, Steps: 256 | Train Loss: 0.3987719 Vali Loss: 1.6988460 Test Loss: 1.0050713
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3051638
# 	speed: 0.4029s/iter; left time: 372.7150s
# 	iters: 200, epoch: 3 | loss: 0.3028657
# 	speed: 0.1940s/iter; left time: 160.0829s
# Epoch: 3 cost time: 49.499780893325806
# Epoch: 3, Steps: 256 | Train Loss: 0.3221564 Vali Loss: 1.7750751 Test Loss: 0.9855635
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.3165157
# 	speed: 0.4044s/iter; left time: 270.5599s
# 	iters: 200, epoch: 4 | loss: 0.2833492
# 	speed: 0.1946s/iter; left time: 110.7401s
# Epoch: 4 cost time: 49.64551496505737
# Epoch: 4, Steps: 256 | Train Loss: 0.2980126 Vali Loss: 1.7641741 Test Loss: 0.9971914
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred336_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.1433380842208862, mae:0.8151294589042664
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:28:39 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 9/12: exp1post_ph2_ETTh1_alpha0.5_pred48_seed2023
# pred_len=48 | seed=2023 | alpha=0.5
# Start: Sat May 16 01:28:39 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred48_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred48_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# 	iters: 100, epoch: 1 | loss: 0.4136700
# 	speed: 0.0941s/iter; left time: 140.2462s
# 	iters: 200, epoch: 1 | loss: 0.3987590
# 	speed: 0.0811s/iter; left time: 112.8288s
# Epoch: 1 cost time: 21.942947387695312
# Epoch: 1, Steps: 265 | Train Loss: 0.4723064 Vali Loss: 0.9772505 Test Loss: 0.7885661
# Validation loss decreased (inf --> 0.977251).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3137549
# 	speed: 0.1850s/iter; left time: 226.7651s
# 	iters: 200, epoch: 2 | loss: 0.3312908
# 	speed: 0.0816s/iter; left time: 91.8920s
# Epoch: 2 cost time: 21.59634494781494
# Epoch: 2, Steps: 265 | Train Loss: 0.3203881 Vali Loss: 0.9654221 Test Loss: 0.9079141
# Validation loss decreased (0.977251 --> 0.965422).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2889893
# 	speed: 0.1823s/iter; left time: 175.1845s
# 	iters: 200, epoch: 3 | loss: 0.2712289
# 	speed: 0.0819s/iter; left time: 70.5459s
# Epoch: 3 cost time: 21.504838943481445
# Epoch: 3, Steps: 265 | Train Loss: 0.2700133 Vali Loss: 0.9317257 Test Loss: 0.8547909
# Validation loss decreased (0.965422 --> 0.931726).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2523710
# 	speed: 0.1828s/iter; left time: 127.2085s
# 	iters: 200, epoch: 4 | loss: 0.2492638
# 	speed: 0.0811s/iter; left time: 48.3075s
# Epoch: 4 cost time: 21.40153431892395
# Epoch: 4, Steps: 265 | Train Loss: 0.2461727 Vali Loss: 0.9558799 Test Loss: 0.8721378
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.2287687
# 	speed: 0.1810s/iter; left time: 78.0123s
# 	iters: 200, epoch: 5 | loss: 0.2301276
# 	speed: 0.0809s/iter; left time: 26.7889s
# Epoch: 5 cost time: 21.424379348754883
# Epoch: 5, Steps: 265 | Train Loss: 0.2349960 Vali Loss: 0.9458899 Test Loss: 0.8708031
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.2107567
# 	speed: 0.1807s/iter; left time: 29.9923s
# 	iters: 200, epoch: 6 | loss: 0.2301773
# 	speed: 0.0810s/iter; left time: 5.3446s
# Epoch: 6 cost time: 21.388653993606567
# Epoch: 6, Steps: 265 | Train Loss: 0.2297873 Vali Loss: 0.9433975 Test Loss: 0.8929445
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred48_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.8547910451889038, mae:0.7146947383880615
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:31:25 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 10/12: exp1post_ph2_ETTh1_alpha0.5_pred96_seed2023
# pred_len=96 | seed=2023 | alpha=0.5
# Start: Sat May 16 01:31:25 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred96_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred96_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.5268546
# 	speed: 0.1117s/iter; left time: 165.8115s
# 	iters: 200, epoch: 1 | loss: 0.4615183
# 	speed: 0.1011s/iter; left time: 139.9603s
# Epoch: 1 cost time: 26.84588623046875
# Epoch: 1, Steps: 264 | Train Loss: 0.5313667 Vali Loss: 1.1581700 Test Loss: 0.9504246
# Validation loss decreased (inf --> 1.158170).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3828691
# 	speed: 0.2262s/iter; left time: 276.1565s
# 	iters: 200, epoch: 2 | loss: 0.3291917
# 	speed: 0.1010s/iter; left time: 113.2646s
# Epoch: 2 cost time: 26.600579023361206
# Epoch: 2, Steps: 264 | Train Loss: 0.3547152 Vali Loss: 1.2871042 Test Loss: 0.9119205
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3146252
# 	speed: 0.2219s/iter; left time: 212.3516s
# 	iters: 200, epoch: 3 | loss: 0.2857748
# 	speed: 0.0994s/iter; left time: 85.1862s
# Epoch: 3 cost time: 26.23041796684265
# Epoch: 3, Steps: 264 | Train Loss: 0.2892981 Vali Loss: 1.2959081 Test Loss: 0.9516854
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2547059
# 	speed: 0.2228s/iter; left time: 154.4209s
# 	iters: 200, epoch: 4 | loss: 0.2603683
# 	speed: 0.1011s/iter; left time: 59.9228s
# Epoch: 4 cost time: 26.62761950492859
# Epoch: 4, Steps: 264 | Train Loss: 0.2615280 Vali Loss: 1.3355469 Test Loss: 1.0034662
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred96_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.9504245519638062, mae:0.7206427454948425
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Sat May 16 01:33:42 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 11/12: exp1post_ph2_ETTh1_alpha0.5_pred192_seed2023
# pred_len=192 | seed=2023 | alpha=0.5
# Start: Sat May 16 01:33:42 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='exp1post_ph2_ETTh1_alpha0.5_pred192_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_exp1post_ph2_ETTh1_alpha0.5_pred192_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# 	iters: 100, epoch: 1 | loss: 0.5071067
# 	speed: 0.1457s/iter; left time: 213.7856s
# 	iters: 200, epoch: 1 | loss: 0.4329349
# 	speed: 0.1363s/iter; left time: 186.3468s
# Epoch: 1 cost time: 35.662636041641235
# Epoch: 1, Steps: 261 | Train Loss: 0.5648191 Vali Loss: 1.3718147 Test Loss: 1.0983051
# Validation loss decreased (inf --> 1.371815).  Saving model ...
# Updating learning rate to 0.0001
#
# ```

# %% [markdown]
# I Went to bring BALL and it got interrupted so i am running the remaining below !

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/exp1_distance_post_softmax/exp1_alpha0.5.sh
# Out:
# bash: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/exp1_distance_post_softmax/exp1_alpha0.5.sh: No such file or directory

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/exp1_distance_post_softmax/exp1_remaining_ball.sh
# Out:
# ...
# Exp1-Post  |  PHASE 2 FORCE RE-RUN (alpha=0.5)
# ...
# Forcing re-run: seed=2023, pred_len=192 & 336
# Start: Sat May 16 02:04:52 PM UTC 2026
# ...
# Files copied.
# Renamed old log to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/logs/exp1post_phase2/exp1post_ph2_ETTh1_alpha0.5_pred192_seed2023.log.old_20260516_140453
#
# ------------------------------------------------------------
# RUN 1/2: exp1post_ph2_ETTh1_alpha0.5_pred192_seed2023
# pred_len=192 | seed=2023 | alpha=0.5
# Start: Sat May 16 02:04:53 PM UTC 2026
# Args in experiment:
# ...

# %% [markdown]
# | Experiment Name | Pred Len | Alpha | Seed | MSE | MAE |
# |---|---|---|---|---|---|
# | exp1_post_ph2_al_0.5 | 48 | 0.5 | 2021 | 0.8368735313 | 0.7083427310 |
# | exp1_post_ph2_al_0.5 | 96 | 0.5 | 2021 | 0.9341089129 | 0.7257674932 |
# | exp1_post_ph2_al_0.5 | 192 | 0.5 | 2021 | 1.0011125803 | 0.7463927865 |
# | exp1_post_ph2_al_0.5 | 336 | 0.5 | 2021 | 1.0854859352 | 0.7852002978 |
# | exp1_post_ph2_al_0.5 | 48 | 0.5 | 2022 | 0.7947472334 | 0.6721062660 |
# | exp1_post_ph2_al_0.5 | 96 | 0.5 | 2022 | 0.9021872878 | 0.6953125596 |
# | exp1_post_ph2_al_0.5 | 192 | 0.5 | 2022 | 1.0810928345 | 0.7923176885 |
# | exp1_post_ph2_al_0.5 | 336 | 0.5 | 2022 | 1.1433380842 | 0.8151294589 |
# | exp1_post_ph2_al_0.5 | 48 | 0.5 | 2023 | 0.8547910452 | 0.7146947384 |
# | exp1_post_ph2_al_0.5 | 96 | 0.5 | 2023 | 0.9504245520 | 0.7206427455 |
# | exp1_post_ph2_al_0.5 | 192 | 0.5 | 2023 | 1.0402499437 | 0.7550259829 |
# | exp1_post_ph2_al_0.5 | 336 | 0.5 | 2023 | 1.0935609341 | 0.7818585634 |
