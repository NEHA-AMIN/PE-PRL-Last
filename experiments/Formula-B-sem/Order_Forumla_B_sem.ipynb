# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

project_path = '/content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1'
os.chdir(project_path)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1

# %%
# !ls -la /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-sem/formula-B-sem-ph1.sh
# Out:
# -rw------- 1 root root 7252 Aug  5 11:14 /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-sem/formula-B-sem-ph1.sh

# %%
import os

# Set your Informer data directory
informer_path = f'{project_path}/Informer2020-original'
data_dir = f'{informer_path}/data/ETT'
os.makedirs(data_dir, exist_ok=True)

# File path
data_file = f'{data_dir}/ETTh1.csv'

# Download ETTh1 dataset
if not os.path.exists(data_file):
    print("Downloading ETTh1.csv...")
    os.system(
        f'wget -q "https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv" '
        f'-O "{data_file}"'
    )

# Verify
if os.path.exists(data_file):
    print(f"✅ Download successful: {data_file}")
else:
    print("❌ Download failed.")
# Out:
# ✅ Download successful: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/data/ETT/ETTh1.csv

# %%
# Fix np.Inf -> np.inf in tools.py (removed in NumPy 2.0)
tools_path = f'{project_path}/Informer2020-original/utils/tools.py'

with open(tools_path, 'r') as f:
    content = f.read()

content_fixed = content.replace('np.Inf', 'np.inf')

with open(tools_path, 'w') as f:
    f.write(content_fixed)

print(":white_check_mark: Fixed np.Inf -> np.inf in utils/tools.py")
# Out:
# :white_check_mark: Fixed np.Inf -> np.inf in utils/tools.py

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-sem/formula-B-sem-ph1.sh
# Out:
# ============================================================
#  Formula B (Semantic Space) — Phase 1: Global Mean Deviation
#  Date: Wed Aug  5 01:06:57 PM UTC 2026
# ------------------------------------------------------------
#  Formula:  X'_i = V_i + T_i + Ordering_i
#  Signal:   Ordering_i = (mu - V_i) / (x_bar + 1e-8)
#  pe_mode:  formula_b_sem
# ------------------------------------------------------------
#  Seed:       2021
#  Pred lens:  96, 192
#  Total runs: 2
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/2: formula_b_sem_ph1_ETTh1_pred96_seed2021
# Start: Wed Aug  5 01:07:09 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph1_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph1_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [FORMULA_B_SEM step=0] val_norm=31.2490 | ordering_norm=0.6008 | temp_norm=7.6310 | x_bar=31.2490 | ordering/val=0.0192
# [FORMULA_B_SEM step=0] val_norm=12.6521 | ordering_norm=1.1116 | temp_norm=7.4084 | x_bar=12.6521 | ordering/val=0.0879
# 	iters: 100, epoch: 1 | loss: 0.4359252
# 	speed: 0.1595s/iter; left time: 236.8395s
# [FORMULA_B_SEM step=100] val_norm=29.0018 | ordering_norm=0.6483 | temp_norm=7.6330 | x_bar=29.0018 | ordering/val=0.0224
# [FORMULA_B_SEM step=100] val_norm=12.0391 | ordering_norm=1.1016 | temp_norm=7.4274 | x_bar=12.0391 | ordering/val=0.0915
# 	iters: 200, epoch: 1 | loss: 0.3191853
# 	speed: 0.0845s/iter; left time: 117.0399s
# [FORMULA_B_SEM step=200] val_norm=29.4824 | ordering_norm=0.6679 | temp_norm=7.6607 | x_bar=29.4824 | ordering/val=0.0227
# [FORMULA_B_SEM step=200] val_norm=11.7341 | ordering_norm=1.0993 | temp_norm=7.4090 | x_bar=11.7341 | ordering/val=0.0937
# Epoch: 1 cost time: 23.81328296661377
# Epoch: 1, Steps: 264 | Train Loss: 0.4175887 Vali Loss: 0.9796073 Test Loss: 0.8911135
# Validation loss decreased (inf --> 0.979607).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=29.9243 | ordering_norm=0.6255 | temp_norm=7.7033 | x_bar=29.9243 | ordering/val=0.0209
# [FORMULA_B_SEM step=300] val_norm=12.2263 | ordering_norm=1.1058 | temp_norm=7.4823 | x_bar=12.2263 | ordering/val=0.0904
# 	iters: 100, epoch: 2 | loss: 0.2934467
# 	speed: 0.1938s/iter; left time: 236.6787s
# [FORMULA_B_SEM step=400] val_norm=29.7764 | ordering_norm=0.6174 | temp_norm=7.6654 | x_bar=29.7764 | ordering/val=0.0207
# [FORMULA_B_SEM step=400] val_norm=12.1403 | ordering_norm=1.0997 | temp_norm=7.4378 | x_bar=12.1403 | ordering/val=0.0906
# 	iters: 200, epoch: 2 | loss: 0.2401754
# 	speed: 0.0869s/iter; left time: 97.4032s
# [FORMULA_B_SEM step=500] val_norm=31.0706 | ordering_norm=0.5819 | temp_norm=7.6912 | x_bar=31.0706 | ordering/val=0.0187
# [FORMULA_B_SEM step=500] val_norm=12.7006 | ordering_norm=1.1128 | temp_norm=7.3933 | x_bar=12.7006 | ordering/val=0.0876
# Epoch: 2 cost time: 22.826515197753906
# Epoch: 2, Steps: 264 | Train Loss: 0.2648225 Vali Loss: 1.0499648 Test Loss: 0.8755685
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=27.7230 | ordering_norm=0.6437 | temp_norm=7.7511 | x_bar=27.7230 | ordering/val=0.0232
# [FORMULA_B_SEM step=600] val_norm=11.1905 | ordering_norm=1.0811 | temp_norm=7.4428 | x_bar=11.1905 | ordering/val=0.0966
# 	iters: 100, epoch: 3 | loss: 0.2073592
# 	speed: 0.1935s/iter; left time: 185.2153s
# [FORMULA_B_SEM step=700] val_norm=29.0186 | ordering_norm=0.6853 | temp_norm=7.7009 | x_bar=29.0186 | ordering/val=0.0236
# [FORMULA_B_SEM step=700] val_norm=11.9155 | ordering_norm=1.0953 | temp_norm=7.5014 | x_bar=11.9155 | ordering/val=0.0919
# 	iters: 200, epoch: 3 | loss: 0.2048116
# 	speed: 0.0876s/iter; left time: 75.0972s
# Epoch: 3 cost time: 23.0910484790802
# Epoch: 3, Steps: 264 | Train Loss: 0.2168748 Vali Loss: 1.0651237 Test Loss: 0.8789788
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=30.2053 | ordering_norm=0.6151 | temp_norm=7.6544 | x_bar=30.2053 | ordering/val=0.0204
# [FORMULA_B_SEM step=800] val_norm=12.0901 | ordering_norm=1.0981 | temp_norm=7.4440 | x_bar=12.0901 | ordering/val=0.0908
# 	iters: 100, epoch: 4 | loss: 0.1970904
# 	speed: 0.1958s/iter; left time: 135.6996s
# [FORMULA_B_SEM step=900] val_norm=29.8940 | ordering_norm=0.6502 | temp_norm=7.6627 | x_bar=29.8940 | ordering/val=0.0218
# [FORMULA_B_SEM step=900] val_norm=12.2567 | ordering_norm=1.1086 | temp_norm=7.4530 | x_bar=12.2567 | ordering/val=0.0904
# 	iters: 200, epoch: 4 | loss: 0.2036745
# 	speed: 0.0893s/iter; left time: 52.9406s
# [FORMULA_B_SEM step=1000] val_norm=29.2459 | ordering_norm=0.6436 | temp_norm=7.7510 | x_bar=29.2459 | ordering/val=0.0220
# [FORMULA_B_SEM step=1000] val_norm=12.1709 | ordering_norm=1.1006 | temp_norm=7.4906 | x_bar=12.1709 | ordering/val=0.0904
# Epoch: 4 cost time: 23.476865768432617
# Epoch: 4, Steps: 264 | Train Loss: 0.1976134 Vali Loss: 1.0638639 Test Loss: 0.8805315
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph1_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8911137580871582, mae:0.7640805244445801
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:09:42 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/2: formula_b_sem_ph1_ETTh1_pred192_seed2021
# Start: Wed Aug  5 01:09:42 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph1_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph1_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_SEM step=0] val_norm=28.8230 | ordering_norm=0.6120 | temp_norm=7.5947 | x_bar=28.8230 | ordering/val=0.0212
# [FORMULA_B_SEM step=0] val_norm=8.5185 | ordering_norm=1.0789 | temp_norm=7.6709 | x_bar=8.5185 | ordering/val=0.1267
# 	iters: 100, epoch: 1 | loss: 0.4355000
# 	speed: 0.1368s/iter; left time: 200.7500s
# [FORMULA_B_SEM step=100] val_norm=27.9073 | ordering_norm=0.6393 | temp_norm=7.6053 | x_bar=27.9074 | ordering/val=0.0229
# [FORMULA_B_SEM step=100] val_norm=8.3638 | ordering_norm=1.0602 | temp_norm=7.6586 | x_bar=8.3638 | ordering/val=0.1268
# 	iters: 200, epoch: 1 | loss: 0.3638527
# 	speed: 0.1181s/iter; left time: 161.4627s
# [FORMULA_B_SEM step=200] val_norm=28.4512 | ordering_norm=0.6395 | temp_norm=7.5907 | x_bar=28.4512 | ordering/val=0.0225
# [FORMULA_B_SEM step=200] val_norm=8.7512 | ordering_norm=1.0895 | temp_norm=7.6343 | x_bar=8.7512 | ordering/val=0.1245
# Epoch: 1 cost time: 31.23611092567444
# Epoch: 1, Steps: 261 | Train Loss: 0.4277719 Vali Loss: 1.1810529 Test Loss: 0.9621933
# Validation loss decreased (inf --> 1.181053).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=30.2199 | ordering_norm=0.6111 | temp_norm=7.5157 | x_bar=30.2199 | ordering/val=0.0202
# [FORMULA_B_SEM step=300] val_norm=8.8676 | ordering_norm=1.1004 | temp_norm=7.6543 | x_bar=8.8676 | ordering/val=0.1241
# 	iters: 100, epoch: 2 | loss: 0.2923630
# 	speed: 0.2576s/iter; left time: 310.7182s
# [FORMULA_B_SEM step=400] val_norm=28.8529 | ordering_norm=0.6257 | temp_norm=7.6113 | x_bar=28.8529 | ordering/val=0.0217
# [FORMULA_B_SEM step=400] val_norm=8.4655 | ordering_norm=1.0726 | temp_norm=7.6692 | x_bar=8.4655 | ordering/val=0.1267
# 	iters: 200, epoch: 2 | loss: 0.2558605
# 	speed: 0.1197s/iter; left time: 132.4069s
# [FORMULA_B_SEM step=500] val_norm=30.6923 | ordering_norm=0.6091 | temp_norm=7.5057 | x_bar=30.6923 | ordering/val=0.0198
# [FORMULA_B_SEM step=500] val_norm=8.8953 | ordering_norm=1.1006 | temp_norm=7.5686 | x_bar=8.8953 | ordering/val=0.1237
# Epoch: 2 cost time: 31.1488037109375
# Epoch: 2, Steps: 261 | Train Loss: 0.2756723 Vali Loss: 1.2186705 Test Loss: 0.9829942
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=27.6047 | ordering_norm=0.7068 | temp_norm=7.7038 | x_bar=27.6047 | ordering/val=0.0256
# [FORMULA_B_SEM step=600] val_norm=8.2666 | ordering_norm=1.0559 | temp_norm=7.7958 | x_bar=8.2666 | ordering/val=0.1277
# 	iters: 100, epoch: 3 | loss: 0.2276233
# 	speed: 0.2603s/iter; left time: 245.9432s
# [FORMULA_B_SEM step=700] val_norm=28.8766 | ordering_norm=0.6484 | temp_norm=7.5978 | x_bar=28.8766 | ordering/val=0.0225
# [FORMULA_B_SEM step=700] val_norm=8.5212 | ordering_norm=1.0808 | temp_norm=7.6349 | x_bar=8.5212 | ordering/val=0.1268
# 	iters: 200, epoch: 3 | loss: 0.2146896
# 	speed: 0.1210s/iter; left time: 102.2041s
# Epoch: 3 cost time: 31.48394227027893
# Epoch: 3, Steps: 261 | Train Loss: 0.2334414 Vali Loss: 1.2581213 Test Loss: 1.0656188
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=30.6901 | ordering_norm=0.6103 | temp_norm=7.5242 | x_bar=30.6901 | ordering/val=0.0199
# [FORMULA_B_SEM step=800] val_norm=8.9263 | ordering_norm=1.0986 | temp_norm=7.6896 | x_bar=8.9263 | ordering/val=0.1231
# 	iters: 100, epoch: 4 | loss: 0.2107421
# 	speed: 0.2623s/iter; left time: 179.3920s
# [FORMULA_B_SEM step=900] val_norm=30.2991 | ordering_norm=0.6507 | temp_norm=7.4956 | x_bar=30.2991 | ordering/val=0.0215
# [FORMULA_B_SEM step=900] val_norm=9.0437 | ordering_norm=1.1052 | temp_norm=7.6177 | x_bar=9.0437 | ordering/val=0.1222
# 	iters: 200, epoch: 4 | loss: 0.2090806
# 	speed: 0.1214s/iter; left time: 70.9184s
# [FORMULA_B_SEM step=1000] val_norm=31.4034 | ordering_norm=0.6045 | temp_norm=7.4858 | x_bar=31.4034 | ordering/val=0.0192
# [FORMULA_B_SEM step=1000] val_norm=9.1024 | ordering_norm=1.1087 | temp_norm=7.5051 | x_bar=9.1024 | ordering/val=0.1218
# Epoch: 4 cost time: 31.612361669540405
# Epoch: 4, Steps: 261 | Train Loss: 0.2152141 Vali Loss: 1.2635257 Test Loss: 1.0669028
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph1_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.9621934294700623, mae:0.7902503609657288
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:12:24 PM UTC 2026
#
# ============================================================
#  PHASE 1 SUMMARY — Formula B (Semantic Space)
#  Total: 2 | Completed: 2 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
#  RUN_ID                                                         MSE        MAE
#  ------------------------------------------------------- ---------- ----------
#  formula_b_sem_ph1_ETTh1_pred96_seed2021                 0.8911137580871582 0.7640805244445801
#  formula_b_sem_ph1_ETTh1_pred192_seed2021                0.9621934294700623 0.7902503609657288
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0 (seed=2021):
#    pred=96  MSE=0.8683
#    pred=192 MSE=0.8463  ← target to beat
#
#  DECISION GUIDE:
#    Formula-B-sem wins BOTH vs Exp1-Pre → proceed to Phase 2
#    Formula-B-sem wins ONE  vs Exp1-Pre → Phase 2 to confirm
#    Formula-B-sem loses BOTH            → document, stop
# ============================================================
# End: Wed Aug  5 01:12:24 PM UTC 2026

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-sem/formula-B-sem-ph2.sh
# Out:
# ============================================================
#  Formula B (Semantic Space) — Phase 2: Global Mean Deviation
#  Date: Wed Aug  5 01:14:40 PM UTC 2026
# ------------------------------------------------------------
#  Formula:  X'_i = V_i + T_i + Ordering_i
#  Signal:   Ordering_i = (mu - V_i) / (x_bar + 1e-8)
#  pe_mode:  formula_b_sem
# ------------------------------------------------------------
#  Seeds:      2021, 2022, 2023
#  Pred lens:  48, 96, 192, 336
#  Total runs: 12
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/12: formula_b_sem_ph2_ETTh1_pred48_seed2021
# pred_len=48 | seed=2021
# Start: Wed Aug  5 01:14:40 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred48_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred48_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# [FORMULA_B_SEM step=0] val_norm=28.3258 | ordering_norm=0.6690 | temp_norm=7.6100 | x_bar=28.3258 | ordering/val=0.0236
# [FORMULA_B_SEM step=0] val_norm=16.4841 | ordering_norm=1.0154 | temp_norm=7.6913 | x_bar=16.4841 | ordering/val=0.0616
# 	iters: 100, epoch: 1 | loss: 0.3568880
# 	speed: 0.0862s/iter; left time: 128.5782s
# [FORMULA_B_SEM step=100] val_norm=29.0404 | ordering_norm=0.6602 | temp_norm=7.6316 | x_bar=29.0404 | ordering/val=0.0227
# [FORMULA_B_SEM step=100] val_norm=16.1350 | ordering_norm=1.0078 | temp_norm=7.7083 | x_bar=16.1350 | ordering/val=0.0625
# 	iters: 200, epoch: 1 | loss: 0.2999715
# 	speed: 0.0708s/iter; left time: 98.5354s
# [FORMULA_B_SEM step=200] val_norm=29.2733 | ordering_norm=0.6401 | temp_norm=7.6449 | x_bar=29.2733 | ordering/val=0.0219
# [FORMULA_B_SEM step=200] val_norm=16.1308 | ordering_norm=1.0007 | temp_norm=7.7721 | x_bar=16.1308 | ordering/val=0.0620
# Epoch: 1 cost time: 19.278966903686523
# Epoch: 1, Steps: 265 | Train Loss: 0.3886993 Vali Loss: 0.8688602 Test Loss: 0.9602017
# Validation loss decreased (inf --> 0.868860).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=28.3136 | ordering_norm=0.6925 | temp_norm=7.6587 | x_bar=28.3136 | ordering/val=0.0245
# [FORMULA_B_SEM step=300] val_norm=15.9774 | ordering_norm=1.0112 | temp_norm=7.8041 | x_bar=15.9774 | ordering/val=0.0633
# 	iters: 100, epoch: 2 | loss: 0.2455947
# 	speed: 0.1598s/iter; left time: 195.8655s
# [FORMULA_B_SEM step=400] val_norm=30.1297 | ordering_norm=0.6019 | temp_norm=7.6685 | x_bar=30.1297 | ordering/val=0.0200
# [FORMULA_B_SEM step=400] val_norm=16.7410 | ordering_norm=0.9978 | temp_norm=7.7280 | x_bar=16.7410 | ordering/val=0.0596
# 	iters: 200, epoch: 2 | loss: 0.2552078
# 	speed: 0.0722s/iter; left time: 81.2747s
# [FORMULA_B_SEM step=500] val_norm=28.2576 | ordering_norm=0.6714 | temp_norm=7.6369 | x_bar=28.2576 | ordering/val=0.0238
# [FORMULA_B_SEM step=500] val_norm=16.1750 | ordering_norm=1.0091 | temp_norm=7.7783 | x_bar=16.1750 | ordering/val=0.0624
# Epoch: 2 cost time: 19.047520399093628
# Epoch: 2, Steps: 265 | Train Loss: 0.2579241 Vali Loss: 0.9021643 Test Loss: 0.9873247
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=27.5393 | ordering_norm=0.7390 | temp_norm=7.6921 | x_bar=27.5393 | ordering/val=0.0268
# [FORMULA_B_SEM step=600] val_norm=15.2773 | ordering_norm=1.0176 | temp_norm=7.7825 | x_bar=15.2773 | ordering/val=0.0666
# 	iters: 100, epoch: 3 | loss: 0.2190631
# 	speed: 0.1608s/iter; left time: 154.5330s
# [FORMULA_B_SEM step=700] val_norm=27.5283 | ordering_norm=0.6948 | temp_norm=7.6294 | x_bar=27.5283 | ordering/val=0.0252
# [FORMULA_B_SEM step=700] val_norm=15.3136 | ordering_norm=1.0141 | temp_norm=7.7804 | x_bar=15.3136 | ordering/val=0.0662
# 	iters: 200, epoch: 3 | loss: 0.2119181
# 	speed: 0.0731s/iter; left time: 62.9271s
# Epoch: 3 cost time: 19.345513105392456
# Epoch: 3, Steps: 265 | Train Loss: 0.2099382 Vali Loss: 0.9127901 Test Loss: 0.8799253
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=30.7893 | ordering_norm=0.6226 | temp_norm=7.7610 | x_bar=30.7893 | ordering/val=0.0202
# [FORMULA_B_SEM step=800] val_norm=17.3238 | ordering_norm=1.0053 | temp_norm=7.8273 | x_bar=17.3238 | ordering/val=0.0580
# 	iters: 100, epoch: 4 | loss: 0.1895885
# 	speed: 0.1636s/iter; left time: 113.8603s
# [FORMULA_B_SEM step=900] val_norm=29.0516 | ordering_norm=0.6354 | temp_norm=7.6011 | x_bar=29.0516 | ordering/val=0.0219
# [FORMULA_B_SEM step=900] val_norm=16.7535 | ordering_norm=1.0084 | temp_norm=7.7232 | x_bar=16.7535 | ordering/val=0.0602
# 	iters: 200, epoch: 4 | loss: 0.1782980
# 	speed: 0.0746s/iter; left time: 44.4902s
# [FORMULA_B_SEM step=1000] val_norm=30.4026 | ordering_norm=0.6133 | temp_norm=7.6611 | x_bar=30.4026 | ordering/val=0.0202
# [FORMULA_B_SEM step=1000] val_norm=17.3207 | ordering_norm=1.0019 | temp_norm=7.6797 | x_bar=17.3207 | ordering/val=0.0578
# Epoch: 4 cost time: 19.69028115272522
# Epoch: 4, Steps: 265 | Train Loss: 0.1897982 Vali Loss: 0.9635363 Test Loss: 0.8912081
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred48_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.9602015018463135, mae:0.7683544158935547
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:16:22 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/12: formula_b_sem_ph2_ETTh1_pred96_seed2021
# pred_len=96 | seed=2021
# Start: Wed Aug  5 01:16:22 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [FORMULA_B_SEM step=0] val_norm=29.7203 | ordering_norm=0.6267 | temp_norm=7.4987 | x_bar=29.7203 | ordering/val=0.0211
# [FORMULA_B_SEM step=0] val_norm=11.8466 | ordering_norm=1.1012 | temp_norm=7.6722 | x_bar=11.8466 | ordering/val=0.0930
# 	iters: 100, epoch: 1 | loss: 0.4017990
# 	speed: 0.1064s/iter; left time: 157.9378s
# [FORMULA_B_SEM step=100] val_norm=30.6642 | ordering_norm=0.6199 | temp_norm=7.3513 | x_bar=30.6642 | ordering/val=0.0202
# [FORMULA_B_SEM step=100] val_norm=12.0245 | ordering_norm=1.1014 | temp_norm=7.4925 | x_bar=12.0245 | ordering/val=0.0916
# 	iters: 200, epoch: 1 | loss: 0.2843214
# 	speed: 0.0936s/iter; left time: 129.6559s
# [FORMULA_B_SEM step=200] val_norm=31.0203 | ordering_norm=0.5981 | temp_norm=7.5346 | x_bar=31.0203 | ordering/val=0.0193
# [FORMULA_B_SEM step=200] val_norm=11.9854 | ordering_norm=1.0926 | temp_norm=7.6557 | x_bar=11.9854 | ordering/val=0.0912
# Epoch: 1 cost time: 25.121949672698975
# Epoch: 1, Steps: 264 | Train Loss: 0.4042290 Vali Loss: 0.9829323 Test Loss: 0.7835377
# Validation loss decreased (inf --> 0.982932).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=30.7984 | ordering_norm=0.6215 | temp_norm=7.4709 | x_bar=30.7984 | ordering/val=0.0202
# [FORMULA_B_SEM step=300] val_norm=12.2747 | ordering_norm=1.1065 | temp_norm=7.5423 | x_bar=12.2747 | ordering/val=0.0901
# 	iters: 100, epoch: 2 | loss: 0.2383158
# 	speed: 0.2127s/iter; left time: 259.6931s
# [FORMULA_B_SEM step=400] val_norm=29.2997 | ordering_norm=0.6678 | temp_norm=7.5062 | x_bar=29.2997 | ordering/val=0.0228
# [FORMULA_B_SEM step=400] val_norm=11.4741 | ordering_norm=1.0903 | temp_norm=7.6082 | x_bar=11.4741 | ordering/val=0.0950
# 	iters: 200, epoch: 2 | loss: 0.2297644
# 	speed: 0.0950s/iter; left time: 106.4571s
# [FORMULA_B_SEM step=500] val_norm=29.3914 | ordering_norm=0.6863 | temp_norm=7.4567 | x_bar=29.3914 | ordering/val=0.0234
# [FORMULA_B_SEM step=500] val_norm=11.5614 | ordering_norm=1.0944 | temp_norm=7.5719 | x_bar=11.5614 | ordering/val=0.0947
# Epoch: 2 cost time: 25.08055591583252
# Epoch: 2, Steps: 264 | Train Loss: 0.2611208 Vali Loss: 0.9967447 Test Loss: 0.8815747
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=31.1747 | ordering_norm=0.5755 | temp_norm=7.4666 | x_bar=31.1747 | ordering/val=0.0185
# [FORMULA_B_SEM step=600] val_norm=12.0823 | ordering_norm=1.1036 | temp_norm=7.6272 | x_bar=12.0823 | ordering/val=0.0913
# 	iters: 100, epoch: 3 | loss: 0.2087267
# 	speed: 0.2069s/iter; left time: 198.0071s
# [FORMULA_B_SEM step=700] val_norm=28.9589 | ordering_norm=0.6444 | temp_norm=7.4314 | x_bar=28.9589 | ordering/val=0.0223
# [FORMULA_B_SEM step=700] val_norm=11.0781 | ordering_norm=1.0815 | temp_norm=7.4615 | x_bar=11.0781 | ordering/val=0.0976
# 	iters: 200, epoch: 3 | loss: 0.2047561
# 	speed: 0.0933s/iter; left time: 79.9708s
# Epoch: 3 cost time: 24.62111473083496
# Epoch: 3, Steps: 264 | Train Loss: 0.2175119 Vali Loss: 1.0212129 Test Loss: 0.9185410
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=29.8320 | ordering_norm=0.6273 | temp_norm=7.4621 | x_bar=29.8320 | ordering/val=0.0210
# [FORMULA_B_SEM step=800] val_norm=11.7180 | ordering_norm=1.1010 | temp_norm=7.6404 | x_bar=11.7180 | ordering/val=0.0940
# 	iters: 100, epoch: 4 | loss: 0.2010877
# 	speed: 0.2071s/iter; left time: 143.5365s
# [FORMULA_B_SEM step=900] val_norm=29.8101 | ordering_norm=0.6072 | temp_norm=7.4605 | x_bar=29.8101 | ordering/val=0.0204
# [FORMULA_B_SEM step=900] val_norm=11.7928 | ordering_norm=1.0955 | temp_norm=7.6040 | x_bar=11.7928 | ordering/val=0.0929
# 	iters: 200, epoch: 4 | loss: 0.2004214
# 	speed: 0.0942s/iter; left time: 55.8813s
# [FORMULA_B_SEM step=1000] val_norm=28.8349 | ordering_norm=0.6602 | temp_norm=7.3830 | x_bar=28.8349 | ordering/val=0.0229
# [FORMULA_B_SEM step=1000] val_norm=11.3668 | ordering_norm=1.0941 | temp_norm=7.5625 | x_bar=11.3668 | ordering/val=0.0963
# Epoch: 4 cost time: 24.79988694190979
# Epoch: 4, Steps: 264 | Train Loss: 0.1997298 Vali Loss: 1.0309956 Test Loss: 0.9086806
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.7835373878479004, mae:0.682116687297821
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:18:31 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 3/12: formula_b_sem_ph2_ETTh1_pred192_seed2021
# pred_len=192 | seed=2021
# Start: Wed Aug  5 01:18:31 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_SEM step=0] val_norm=31.5780 | ordering_norm=0.5799 | temp_norm=7.5766 | x_bar=31.5780 | ordering/val=0.0184
# [FORMULA_B_SEM step=0] val_norm=9.1535 | ordering_norm=1.1219 | temp_norm=7.5046 | x_bar=9.1535 | ordering/val=0.1226
# 	iters: 100, epoch: 1 | loss: 0.4566957
# 	speed: 0.1373s/iter; left time: 201.3613s
# [FORMULA_B_SEM step=100] val_norm=29.3812 | ordering_norm=0.6101 | temp_norm=7.6787 | x_bar=29.3812 | ordering/val=0.0208
# [FORMULA_B_SEM step=100] val_norm=8.5629 | ordering_norm=1.0816 | temp_norm=7.5376 | x_bar=8.5629 | ordering/val=0.1263
# 	iters: 200, epoch: 1 | loss: 0.3644792
# 	speed: 0.1247s/iter; left time: 170.5246s
# [FORMULA_B_SEM step=200] val_norm=31.0098 | ordering_norm=0.6571 | temp_norm=7.5526 | x_bar=31.0098 | ordering/val=0.0212
# [FORMULA_B_SEM step=200] val_norm=8.9109 | ordering_norm=1.0906 | temp_norm=7.4980 | x_bar=8.9109 | ordering/val=0.1224
# Epoch: 1 cost time: 32.85812449455261
# Epoch: 1, Steps: 261 | Train Loss: 0.4240961 Vali Loss: 1.2099643 Test Loss: 0.9376522
# Validation loss decreased (inf --> 1.209964).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=28.8376 | ordering_norm=0.6396 | temp_norm=7.7447 | x_bar=28.8376 | ordering/val=0.0222
# [FORMULA_B_SEM step=300] val_norm=8.1600 | ordering_norm=1.0573 | temp_norm=7.5941 | x_bar=8.1600 | ordering/val=0.1296
# 	iters: 100, epoch: 2 | loss: 0.2803216
# 	speed: 0.2698s/iter; left time: 325.3857s
# [FORMULA_B_SEM step=400] val_norm=30.1663 | ordering_norm=0.6137 | temp_norm=7.7159 | x_bar=30.1663 | ordering/val=0.0203
# [FORMULA_B_SEM step=400] val_norm=8.4712 | ordering_norm=1.0831 | temp_norm=7.5414 | x_bar=8.4712 | ordering/val=0.1279
# 	iters: 200, epoch: 2 | loss: 0.2640874
# 	speed: 0.1238s/iter; left time: 136.9651s
# [FORMULA_B_SEM step=500] val_norm=31.9405 | ordering_norm=0.5676 | temp_norm=7.7295 | x_bar=31.9405 | ordering/val=0.0178
# [FORMULA_B_SEM step=500] val_norm=8.9767 | ordering_norm=1.1024 | temp_norm=7.6278 | x_bar=8.9767 | ordering/val=0.1228
# Epoch: 2 cost time: 32.304386615753174
# Epoch: 2, Steps: 261 | Train Loss: 0.2725464 Vali Loss: 1.2694459 Test Loss: 0.9478289
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=29.9439 | ordering_norm=0.6330 | temp_norm=7.7031 | x_bar=29.9439 | ordering/val=0.0211
# [FORMULA_B_SEM step=600] val_norm=8.2429 | ordering_norm=1.0655 | temp_norm=7.5426 | x_bar=8.2429 | ordering/val=0.1293
# 	iters: 100, epoch: 3 | loss: 0.2318044
# 	speed: 0.2674s/iter; left time: 252.7069s
# [FORMULA_B_SEM step=700] val_norm=30.9063 | ordering_norm=0.6189 | temp_norm=7.6034 | x_bar=30.9063 | ordering/val=0.0200
# [FORMULA_B_SEM step=700] val_norm=8.9773 | ordering_norm=1.1107 | temp_norm=7.5192 | x_bar=8.9773 | ordering/val=0.1237
# 	iters: 200, epoch: 3 | loss: 0.2222066
# 	speed: 0.1241s/iter; left time: 104.8323s
# Epoch: 3 cost time: 32.305458784103394
# Epoch: 3, Steps: 261 | Train Loss: 0.2283240 Vali Loss: 1.2544482 Test Loss: 0.9928414
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=29.8621 | ordering_norm=0.5884 | temp_norm=7.8020 | x_bar=29.8621 | ordering/val=0.0197
# [FORMULA_B_SEM step=800] val_norm=8.6737 | ordering_norm=1.0969 | temp_norm=7.5863 | x_bar=8.6737 | ordering/val=0.1265
# 	iters: 100, epoch: 4 | loss: 0.2091518
# 	speed: 0.2678s/iter; left time: 183.1898s
# [FORMULA_B_SEM step=900] val_norm=28.7124 | ordering_norm=0.5831 | temp_norm=7.7513 | x_bar=28.7124 | ordering/val=0.0203
# [FORMULA_B_SEM step=900] val_norm=8.2037 | ordering_norm=1.0710 | temp_norm=7.6554 | x_bar=8.2037 | ordering/val=0.1305
# 	iters: 200, epoch: 4 | loss: 0.2005742
# 	speed: 0.1243s/iter; left time: 72.5627s
# [FORMULA_B_SEM step=1000] val_norm=29.5292 | ordering_norm=0.6168 | temp_norm=7.6456 | x_bar=29.5292 | ordering/val=0.0209
# [FORMULA_B_SEM step=1000] val_norm=8.6331 | ordering_norm=1.0853 | temp_norm=7.5485 | x_bar=8.6331 | ordering/val=0.1257
# Epoch: 4 cost time: 32.36051559448242
# Epoch: 4, Steps: 261 | Train Loss: 0.2086735 Vali Loss: 1.3058985 Test Loss: 1.0128678
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.9376522302627563, mae:0.7857064008712769
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:21:16 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 4/12: formula_b_sem_ph2_ETTh1_pred336_seed2021
# pred_len=336 | seed=2021
# Start: Wed Aug  5 01:21:16 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred336_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [FORMULA_B_SEM step=0] val_norm=28.4257 | ordering_norm=0.6433 | temp_norm=7.6731 | x_bar=28.4257 | ordering/val=0.0226
# [FORMULA_B_SEM step=0] val_norm=6.1413 | ordering_norm=0.9554 | temp_norm=7.6689 | x_bar=6.1413 | ordering/val=0.1556
# 	iters: 100, epoch: 1 | loss: 0.4725203
# 	speed: 0.1941s/iter; left time: 278.9744s
# [FORMULA_B_SEM step=100] val_norm=29.2956 | ordering_norm=0.6421 | temp_norm=7.6282 | x_bar=29.2956 | ordering/val=0.0219
# [FORMULA_B_SEM step=100] val_norm=6.2141 | ordering_norm=0.9564 | temp_norm=7.6193 | x_bar=6.2141 | ordering/val=0.1539
# 	iters: 200, epoch: 1 | loss: 0.3790952
# 	speed: 0.1824s/iter; left time: 243.8214s
# [FORMULA_B_SEM step=200] val_norm=29.8634 | ordering_norm=0.6543 | temp_norm=7.6140 | x_bar=29.8634 | ordering/val=0.0219
# [FORMULA_B_SEM step=200] val_norm=6.3646 | ordering_norm=0.9798 | temp_norm=7.7655 | x_bar=6.3646 | ordering/val=0.1539
# Epoch: 1 cost time: 46.86172032356262
# Epoch: 1, Steps: 256 | Train Loss: 0.4357608 Vali Loss: 1.2315468 Test Loss: 0.9643482
# Validation loss decreased (inf --> 1.231547).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=28.7599 | ordering_norm=0.6522 | temp_norm=7.7682 | x_bar=28.7599 | ordering/val=0.0227
# [FORMULA_B_SEM step=300] val_norm=6.1637 | ordering_norm=0.9466 | temp_norm=7.7365 | x_bar=6.1637 | ordering/val=0.1536
# 	iters: 100, epoch: 2 | loss: 0.3134195
# 	speed: 0.3771s/iter; left time: 445.3321s
# [FORMULA_B_SEM step=400] val_norm=30.2098 | ordering_norm=0.6220 | temp_norm=7.6878 | x_bar=30.2098 | ordering/val=0.0206
# [FORMULA_B_SEM step=400] val_norm=6.3179 | ordering_norm=0.9702 | temp_norm=7.7770 | x_bar=6.3179 | ordering/val=0.1536
# 	iters: 200, epoch: 2 | loss: 0.2676313
# 	speed: 0.1813s/iter; left time: 195.9675s
# [FORMULA_B_SEM step=500] val_norm=29.3325 | ordering_norm=0.6339 | temp_norm=7.7035 | x_bar=29.3325 | ordering/val=0.0216
# [FORMULA_B_SEM step=500] val_norm=6.2196 | ordering_norm=0.9585 | temp_norm=7.7112 | x_bar=6.2196 | ordering/val=0.1541
# Epoch: 2 cost time: 46.324634075164795
# Epoch: 2, Steps: 256 | Train Loss: 0.2875546 Vali Loss: 1.2833732 Test Loss: 1.1234753
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=30.5677 | ordering_norm=0.5969 | temp_norm=7.5869 | x_bar=30.5677 | ordering/val=0.0195
# [FORMULA_B_SEM step=600] val_norm=6.3054 | ordering_norm=0.9886 | temp_norm=7.6969 | x_bar=6.3054 | ordering/val=0.1568
# 	iters: 100, epoch: 3 | loss: 0.2465640
# 	speed: 0.3771s/iter; left time: 348.8628s
# [FORMULA_B_SEM step=700] val_norm=31.3304 | ordering_norm=0.5645 | temp_norm=7.6139 | x_bar=31.3304 | ordering/val=0.0180
# [FORMULA_B_SEM step=700] val_norm=6.4475 | ordering_norm=0.9919 | temp_norm=7.7028 | x_bar=6.4475 | ordering/val=0.1538
# 	iters: 200, epoch: 3 | loss: 0.2354387
# 	speed: 0.1825s/iter; left time: 150.5496s
# Epoch: 3 cost time: 46.57978415489197
# Epoch: 3, Steps: 256 | Train Loss: 0.2412637 Vali Loss: 1.2933621 Test Loss: 1.2474561
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=27.6681 | ordering_norm=0.7154 | temp_norm=7.7165 | x_bar=27.6681 | ordering/val=0.0259
# [FORMULA_B_SEM step=800] val_norm=5.9311 | ordering_norm=0.9039 | temp_norm=7.7303 | x_bar=5.9311 | ordering/val=0.1524
# 	iters: 100, epoch: 4 | loss: 0.2288283
# 	speed: 0.3778s/iter; left time: 252.7773s
# [FORMULA_B_SEM step=900] val_norm=29.6411 | ordering_norm=0.6848 | temp_norm=7.7327 | x_bar=29.6411 | ordering/val=0.0231
# [FORMULA_B_SEM step=900] val_norm=6.1604 | ordering_norm=0.9421 | temp_norm=7.6957 | x_bar=6.1604 | ordering/val=0.1529
# 	iters: 200, epoch: 4 | loss: 0.2177769
# 	speed: 0.1823s/iter; left time: 103.7403s
# [FORMULA_B_SEM step=1000] val_norm=30.5895 | ordering_norm=0.6374 | temp_norm=7.6984 | x_bar=30.5895 | ordering/val=0.0208
# [FORMULA_B_SEM step=1000] val_norm=6.1778 | ordering_norm=0.9566 | temp_norm=7.6661 | x_bar=6.1778 | ordering/val=0.1548
# Epoch: 4 cost time: 46.56420660018921
# Epoch: 4, Steps: 256 | Train Loss: 0.2207105 Vali Loss: 1.3110359 Test Loss: 1.2127489
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:0.9643481969833374, mae:0.7918732762336731
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:25:10 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 5/12: formula_b_sem_ph2_ETTh1_pred48_seed2022
# pred_len=48 | seed=2022
# Start: Wed Aug  5 01:25:10 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred48_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred48_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# [FORMULA_B_SEM step=0] val_norm=28.5701 | ordering_norm=0.6777 | temp_norm=7.6866 | x_bar=28.5701 | ordering/val=0.0237
# [FORMULA_B_SEM step=0] val_norm=16.2484 | ordering_norm=1.0222 | temp_norm=7.7086 | x_bar=16.2484 | ordering/val=0.0629
# 	iters: 100, epoch: 1 | loss: 0.4312677
# 	speed: 0.0993s/iter; left time: 148.0315s
# [FORMULA_B_SEM step=100] val_norm=30.6073 | ordering_norm=0.6293 | temp_norm=7.5025 | x_bar=30.6073 | ordering/val=0.0206
# [FORMULA_B_SEM step=100] val_norm=17.0504 | ordering_norm=1.0052 | temp_norm=7.4983 | x_bar=17.0504 | ordering/val=0.0590
# 	iters: 200, epoch: 1 | loss: 0.3651198
# 	speed: 0.0785s/iter; left time: 109.2406s
# [FORMULA_B_SEM step=200] val_norm=30.6929 | ordering_norm=0.6115 | temp_norm=7.5531 | x_bar=30.6929 | ordering/val=0.0199
# [FORMULA_B_SEM step=200] val_norm=16.7083 | ordering_norm=1.0085 | temp_norm=7.5445 | x_bar=16.7083 | ordering/val=0.0604
# Epoch: 1 cost time: 21.50484037399292
# Epoch: 1, Steps: 265 | Train Loss: 0.4048925 Vali Loss: 0.8861173 Test Loss: 0.8743395
# Validation loss decreased (inf --> 0.886117).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=29.7907 | ordering_norm=0.6331 | temp_norm=7.6046 | x_bar=29.7907 | ordering/val=0.0213
# [FORMULA_B_SEM step=300] val_norm=16.4167 | ordering_norm=1.0075 | temp_norm=7.5424 | x_bar=16.4167 | ordering/val=0.0614
# 	iters: 100, epoch: 2 | loss: 0.2759241
# 	speed: 0.1762s/iter; left time: 215.9895s
# [FORMULA_B_SEM step=400] val_norm=29.9051 | ordering_norm=0.6452 | temp_norm=7.4962 | x_bar=29.9051 | ordering/val=0.0216
# [FORMULA_B_SEM step=400] val_norm=16.2458 | ordering_norm=1.0073 | temp_norm=7.5057 | x_bar=16.2458 | ordering/val=0.0620
# 	iters: 200, epoch: 2 | loss: 0.2286014
# 	speed: 0.0787s/iter; left time: 88.6074s
# [FORMULA_B_SEM step=500] val_norm=29.9660 | ordering_norm=0.6406 | temp_norm=7.4341 | x_bar=29.9660 | ordering/val=0.0214
# [FORMULA_B_SEM step=500] val_norm=16.2597 | ordering_norm=1.0066 | temp_norm=7.4543 | x_bar=16.2597 | ordering/val=0.0619
# Epoch: 2 cost time: 20.85460925102234
# Epoch: 2, Steps: 265 | Train Loss: 0.2583857 Vali Loss: 0.8725104 Test Loss: 0.8936453
# Validation loss decreased (0.886117 --> 0.872510).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=29.4831 | ordering_norm=0.6305 | temp_norm=7.5520 | x_bar=29.4831 | ordering/val=0.0214
# [FORMULA_B_SEM step=600] val_norm=16.2698 | ordering_norm=1.0010 | temp_norm=7.5205 | x_bar=16.2698 | ordering/val=0.0615
# 	iters: 100, epoch: 3 | loss: 0.1939206
# 	speed: 0.1751s/iter; left time: 168.2368s
# [FORMULA_B_SEM step=700] val_norm=28.5598 | ordering_norm=0.6938 | temp_norm=7.5242 | x_bar=28.5598 | ordering/val=0.0243
# [FORMULA_B_SEM step=700] val_norm=15.8450 | ordering_norm=1.0184 | temp_norm=7.5198 | x_bar=15.8450 | ordering/val=0.0643
# 	iters: 200, epoch: 3 | loss: 0.2020722
# 	speed: 0.0784s/iter; left time: 67.5187s
# Epoch: 3 cost time: 20.72205924987793
# Epoch: 3, Steps: 265 | Train Loss: 0.2113075 Vali Loss: 0.9528131 Test Loss: 0.9875765
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=30.7809 | ordering_norm=0.6267 | temp_norm=7.5964 | x_bar=30.7809 | ordering/val=0.0204
# [FORMULA_B_SEM step=800] val_norm=16.8873 | ordering_norm=1.0153 | temp_norm=7.5364 | x_bar=16.8873 | ordering/val=0.0601
# 	iters: 100, epoch: 4 | loss: 0.1860347
# 	speed: 0.1733s/iter; left time: 120.6406s
# [FORMULA_B_SEM step=900] val_norm=31.7480 | ordering_norm=0.6015 | temp_norm=7.5563 | x_bar=31.7480 | ordering/val=0.0189
# [FORMULA_B_SEM step=900] val_norm=17.2411 | ordering_norm=1.0112 | temp_norm=7.4946 | x_bar=17.2411 | ordering/val=0.0586
# 	iters: 200, epoch: 4 | loss: 0.1814335
# 	speed: 0.0782s/iter; left time: 46.6316s
# [FORMULA_B_SEM step=1000] val_norm=28.1763 | ordering_norm=0.6454 | temp_norm=7.4732 | x_bar=28.1763 | ordering/val=0.0229
# [FORMULA_B_SEM step=1000] val_norm=15.6309 | ordering_norm=1.0041 | temp_norm=7.4606 | x_bar=15.6309 | ordering/val=0.0642
# Epoch: 4 cost time: 20.662738800048828
# Epoch: 4, Steps: 265 | Train Loss: 0.1922438 Vali Loss: 0.9743624 Test Loss: 0.9352610
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# [FORMULA_B_SEM step=1100] val_norm=30.3526 | ordering_norm=0.6298 | temp_norm=7.5398 | x_bar=30.3526 | ordering/val=0.0207
# [FORMULA_B_SEM step=1100] val_norm=16.8466 | ordering_norm=1.0076 | temp_norm=7.5755 | x_bar=16.8466 | ordering/val=0.0598
# 	iters: 100, epoch: 5 | loss: 0.1716713
# 	speed: 0.1738s/iter; left time: 74.8997s
# [FORMULA_B_SEM step=1200] val_norm=30.9939 | ordering_norm=0.6390 | temp_norm=7.4978 | x_bar=30.9939 | ordering/val=0.0206
# [FORMULA_B_SEM step=1200] val_norm=17.2118 | ordering_norm=1.0144 | temp_norm=7.4961 | x_bar=17.2118 | ordering/val=0.0589
# 	iters: 200, epoch: 5 | loss: 0.1827921
# 	speed: 0.0784s/iter; left time: 25.9483s
# [FORMULA_B_SEM step=1300] val_norm=29.7900 | ordering_norm=0.5986 | temp_norm=7.5219 | x_bar=29.7900 | ordering/val=0.0201
# [FORMULA_B_SEM step=1300] val_norm=16.4585 | ordering_norm=1.0008 | temp_norm=7.4975 | x_bar=16.4585 | ordering/val=0.0608
# Epoch: 5 cost time: 20.718727350234985
# Epoch: 5, Steps: 265 | Train Loss: 0.1826800 Vali Loss: 1.0184722 Test Loss: 0.9596900
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred48_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.8936455249786377, mae:0.7376778721809387
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:27:25 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 6/12: formula_b_sem_ph2_ETTh1_pred96_seed2022
# pred_len=96 | seed=2022
# Start: Wed Aug  5 01:27:25 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred96_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [FORMULA_B_SEM step=0] val_norm=31.3121 | ordering_norm=0.5917 | temp_norm=7.7372 | x_bar=31.3121 | ordering/val=0.0189
# [FORMULA_B_SEM step=0] val_norm=12.6623 | ordering_norm=1.1074 | temp_norm=7.7167 | x_bar=12.6623 | ordering/val=0.0875
# 	iters: 100, epoch: 1 | loss: 0.4764071
# 	speed: 0.1078s/iter; left time: 160.0695s
# [FORMULA_B_SEM step=100] val_norm=28.7448 | ordering_norm=0.6435 | temp_norm=7.6410 | x_bar=28.7448 | ordering/val=0.0224
# [FORMULA_B_SEM step=100] val_norm=11.8235 | ordering_norm=1.0897 | temp_norm=7.7126 | x_bar=11.8235 | ordering/val=0.0922
# 	iters: 200, epoch: 1 | loss: 0.3390405
# 	speed: 0.0942s/iter; left time: 130.4608s
# [FORMULA_B_SEM step=200] val_norm=29.1392 | ordering_norm=0.6651 | temp_norm=7.5068 | x_bar=29.1392 | ordering/val=0.0228
# [FORMULA_B_SEM step=200] val_norm=11.7968 | ordering_norm=1.0918 | temp_norm=7.7311 | x_bar=11.7968 | ordering/val=0.0925
# Epoch: 1 cost time: 25.329272270202637
# Epoch: 1, Steps: 264 | Train Loss: 0.4125697 Vali Loss: 0.9541793 Test Loss: 0.7975203
# Validation loss decreased (inf --> 0.954179).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=28.6436 | ordering_norm=0.6434 | temp_norm=7.5415 | x_bar=28.6436 | ordering/val=0.0225
# [FORMULA_B_SEM step=300] val_norm=11.3290 | ordering_norm=1.0885 | temp_norm=7.7535 | x_bar=11.3290 | ordering/val=0.0961
# 	iters: 100, epoch: 2 | loss: 0.2643812
# 	speed: 0.2109s/iter; left time: 257.5186s
# [FORMULA_B_SEM step=400] val_norm=30.3821 | ordering_norm=0.6465 | temp_norm=7.6985 | x_bar=30.3821 | ordering/val=0.0213
# [FORMULA_B_SEM step=400] val_norm=12.1652 | ordering_norm=1.1000 | temp_norm=7.7820 | x_bar=12.1652 | ordering/val=0.0904
# 	iters: 200, epoch: 2 | loss: 0.2510646
# 	speed: 0.0943s/iter; left time: 105.6805s
# [FORMULA_B_SEM step=500] val_norm=31.3593 | ordering_norm=0.6126 | temp_norm=7.5122 | x_bar=31.3593 | ordering/val=0.0195
# [FORMULA_B_SEM step=500] val_norm=12.6531 | ordering_norm=1.1048 | temp_norm=7.7192 | x_bar=12.6531 | ordering/val=0.0873
# Epoch: 2 cost time: 24.885476112365723
# Epoch: 2, Steps: 264 | Train Loss: 0.2596632 Vali Loss: 1.0696851 Test Loss: 0.9464564
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=30.2437 | ordering_norm=0.6121 | temp_norm=7.6222 | x_bar=30.2437 | ordering/val=0.0202
# [FORMULA_B_SEM step=600] val_norm=11.9961 | ordering_norm=1.0953 | temp_norm=7.7525 | x_bar=11.9961 | ordering/val=0.0913
# 	iters: 100, epoch: 3 | loss: 0.2311000
# 	speed: 0.2074s/iter; left time: 198.5241s
# [FORMULA_B_SEM step=700] val_norm=29.8063 | ordering_norm=0.6223 | temp_norm=7.6141 | x_bar=29.8063 | ordering/val=0.0209
# [FORMULA_B_SEM step=700] val_norm=12.1099 | ordering_norm=1.0971 | temp_norm=7.7520 | x_bar=12.1099 | ordering/val=0.0906
# 	iters: 200, epoch: 3 | loss: 0.2128231
# 	speed: 0.0939s/iter; left time: 80.4796s
# Epoch: 3 cost time: 24.765862226486206
# Epoch: 3, Steps: 264 | Train Loss: 0.2179079 Vali Loss: 1.0813099 Test Loss: 0.9616658
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=28.9320 | ordering_norm=0.6292 | temp_norm=7.5422 | x_bar=28.9320 | ordering/val=0.0217
# [FORMULA_B_SEM step=800] val_norm=11.8887 | ordering_norm=1.0958 | temp_norm=7.7210 | x_bar=11.8887 | ordering/val=0.0922
# 	iters: 100, epoch: 4 | loss: 0.2008367
# 	speed: 0.2080s/iter; left time: 144.1146s
# [FORMULA_B_SEM step=900] val_norm=30.1088 | ordering_norm=0.6562 | temp_norm=7.5148 | x_bar=30.1088 | ordering/val=0.0218
# [FORMULA_B_SEM step=900] val_norm=12.2982 | ordering_norm=1.0960 | temp_norm=7.7393 | x_bar=12.2982 | ordering/val=0.0891
# 	iters: 200, epoch: 4 | loss: 0.1962232
# 	speed: 0.0943s/iter; left time: 55.9151s
# [FORMULA_B_SEM step=1000] val_norm=27.7420 | ordering_norm=0.6325 | temp_norm=7.5238 | x_bar=27.7420 | ordering/val=0.0228
# [FORMULA_B_SEM step=1000] val_norm=11.4944 | ordering_norm=1.0943 | temp_norm=7.7077 | x_bar=11.4944 | ordering/val=0.0952
# Epoch: 4 cost time: 24.841254234313965
# Epoch: 4, Steps: 264 | Train Loss: 0.2015497 Vali Loss: 1.0940039 Test Loss: 0.9761181
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.7975202798843384, mae:0.6957442164421082
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:29:34 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 7/12: formula_b_sem_ph2_ETTh1_pred192_seed2022
# pred_len=192 | seed=2022
# Start: Wed Aug  5 01:29:34 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred192_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_SEM step=0] val_norm=28.9891 | ordering_norm=0.6571 | temp_norm=7.5484 | x_bar=28.9891 | ordering/val=0.0227
# [FORMULA_B_SEM step=0] val_norm=8.2834 | ordering_norm=1.0511 | temp_norm=7.6051 | x_bar=8.2834 | ordering/val=0.1269
# 	iters: 100, epoch: 1 | loss: 0.3895812
# 	speed: 0.1375s/iter; left time: 201.6451s
# [FORMULA_B_SEM step=100] val_norm=30.4462 | ordering_norm=0.6419 | temp_norm=7.4754 | x_bar=30.4462 | ordering/val=0.0211
# [FORMULA_B_SEM step=100] val_norm=8.7223 | ordering_norm=1.0886 | temp_norm=7.5303 | x_bar=8.7223 | ordering/val=0.1248
# 	iters: 200, epoch: 1 | loss: 0.3141250
# 	speed: 0.1249s/iter; left time: 170.6989s
# [FORMULA_B_SEM step=200] val_norm=28.2027 | ordering_norm=0.6719 | temp_norm=7.5118 | x_bar=28.2027 | ordering/val=0.0238
# [FORMULA_B_SEM step=200] val_norm=7.8834 | ordering_norm=1.0247 | temp_norm=7.6093 | x_bar=7.8834 | ordering/val=0.1300
# Epoch: 1 cost time: 32.889633893966675
# Epoch: 1, Steps: 261 | Train Loss: 0.4080736 Vali Loss: 1.2562810 Test Loss: 1.0187780
# Validation loss decreased (inf --> 1.256281).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=29.5166 | ordering_norm=0.6876 | temp_norm=7.5299 | x_bar=29.5166 | ordering/val=0.0233
# [FORMULA_B_SEM step=300] val_norm=8.2982 | ordering_norm=1.0595 | temp_norm=7.5733 | x_bar=8.2982 | ordering/val=0.1277
# 	iters: 100, epoch: 2 | loss: 0.2836151
# 	speed: 0.2699s/iter; left time: 325.5008s
# [FORMULA_B_SEM step=400] val_norm=29.2515 | ordering_norm=0.6813 | temp_norm=7.5487 | x_bar=29.2515 | ordering/val=0.0233
# [FORMULA_B_SEM step=400] val_norm=8.2081 | ordering_norm=1.0683 | temp_norm=7.5960 | x_bar=8.2081 | ordering/val=0.1301
# 	iters: 200, epoch: 2 | loss: 0.2433077
# 	speed: 0.1241s/iter; left time: 137.2062s
# [FORMULA_B_SEM step=500] val_norm=30.6538 | ordering_norm=0.6527 | temp_norm=7.5023 | x_bar=30.6538 | ordering/val=0.0213
# [FORMULA_B_SEM step=500] val_norm=8.6332 | ordering_norm=1.0854 | temp_norm=7.6199 | x_bar=8.6332 | ordering/val=0.1257
# Epoch: 2 cost time: 32.35303592681885
# Epoch: 2, Steps: 261 | Train Loss: 0.2681034 Vali Loss: 1.2800967 Test Loss: 1.1361954
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=30.0769 | ordering_norm=0.6875 | temp_norm=7.5952 | x_bar=30.0769 | ordering/val=0.0229
# [FORMULA_B_SEM step=600] val_norm=8.4889 | ordering_norm=1.0617 | temp_norm=7.5805 | x_bar=8.4889 | ordering/val=0.1251
# 	iters: 100, epoch: 3 | loss: 0.2413491
# 	speed: 0.2674s/iter; left time: 252.7387s
# [FORMULA_B_SEM step=700] val_norm=29.6794 | ordering_norm=0.6677 | temp_norm=7.5361 | x_bar=29.6794 | ordering/val=0.0225
# [FORMULA_B_SEM step=700] val_norm=8.3129 | ordering_norm=1.0678 | temp_norm=7.6203 | x_bar=8.3129 | ordering/val=0.1285
# 	iters: 200, epoch: 3 | loss: 0.2089865
# 	speed: 0.1241s/iter; left time: 104.8671s
# Epoch: 3 cost time: 32.306198596954346
# Epoch: 3, Steps: 261 | Train Loss: 0.2243761 Vali Loss: 1.2887577 Test Loss: 1.0629091
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=30.5092 | ordering_norm=0.6276 | temp_norm=7.4940 | x_bar=30.5092 | ordering/val=0.0206
# [FORMULA_B_SEM step=800] val_norm=8.4581 | ordering_norm=1.0785 | temp_norm=7.5288 | x_bar=8.4581 | ordering/val=0.1275
# 	iters: 100, epoch: 4 | loss: 0.2047130
# 	speed: 0.2684s/iter; left time: 183.5678s
# [FORMULA_B_SEM step=900] val_norm=28.3354 | ordering_norm=0.6376 | temp_norm=7.5850 | x_bar=28.3354 | ordering/val=0.0225
# [FORMULA_B_SEM step=900] val_norm=8.0350 | ordering_norm=1.0507 | temp_norm=7.6737 | x_bar=8.0350 | ordering/val=0.1308
# 	iters: 200, epoch: 4 | loss: 0.2024951
# 	speed: 0.1247s/iter; left time: 72.8069s
# [FORMULA_B_SEM step=1000] val_norm=29.3694 | ordering_norm=0.6590 | temp_norm=7.4349 | x_bar=29.3694 | ordering/val=0.0224
# [FORMULA_B_SEM step=1000] val_norm=8.3679 | ordering_norm=1.0690 | temp_norm=7.5240 | x_bar=8.3679 | ordering/val=0.1277
# Epoch: 4 cost time: 32.45708179473877
# Epoch: 4, Steps: 261 | Train Loss: 0.2043696 Vali Loss: 1.3536214 Test Loss: 1.1197017
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:1.0187780857086182, mae:0.8290572166442871
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:32:20 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 8/12: formula_b_sem_ph2_ETTh1_pred336_seed2022
# pred_len=336 | seed=2022
# Start: Wed Aug  5 01:32:20 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred336_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [FORMULA_B_SEM step=0] val_norm=29.5836 | ordering_norm=0.7028 | temp_norm=7.4850 | x_bar=29.5836 | ordering/val=0.0238
# [FORMULA_B_SEM step=0] val_norm=6.2184 | ordering_norm=0.9527 | temp_norm=7.2982 | x_bar=6.2184 | ordering/val=0.1532
# 	iters: 100, epoch: 1 | loss: 0.4031233
# 	speed: 0.1938s/iter; left time: 278.4468s
# [FORMULA_B_SEM step=100] val_norm=31.5291 | ordering_norm=0.6067 | temp_norm=7.6125 | x_bar=31.5291 | ordering/val=0.0192
# [FORMULA_B_SEM step=100] val_norm=6.4399 | ordering_norm=0.9877 | temp_norm=7.3467 | x_bar=6.4399 | ordering/val=0.1534
# 	iters: 200, epoch: 1 | loss: 0.3697609
# 	speed: 0.1823s/iter; left time: 243.7887s
# [FORMULA_B_SEM step=200] val_norm=28.8800 | ordering_norm=0.6501 | temp_norm=7.5982 | x_bar=28.8800 | ordering/val=0.0225
# [FORMULA_B_SEM step=200] val_norm=6.0992 | ordering_norm=0.9463 | temp_norm=7.3515 | x_bar=6.0992 | ordering/val=0.1551
# Epoch: 1 cost time: 46.8496253490448
# Epoch: 1, Steps: 256 | Train Loss: 0.4314701 Vali Loss: 1.2479321 Test Loss: 0.9252650
# Validation loss decreased (inf --> 1.247932).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=31.4839 | ordering_norm=0.6331 | temp_norm=7.5873 | x_bar=31.4839 | ordering/val=0.0201
# [FORMULA_B_SEM step=300] val_norm=6.4608 | ordering_norm=0.9859 | temp_norm=7.3327 | x_bar=6.4608 | ordering/val=0.1526
# 	iters: 100, epoch: 2 | loss: 0.2951391
# 	speed: 0.3761s/iter; left time: 444.1493s
# [FORMULA_B_SEM step=400] val_norm=29.5576 | ordering_norm=0.6856 | temp_norm=7.6390 | x_bar=29.5576 | ordering/val=0.0232
# [FORMULA_B_SEM step=400] val_norm=6.2036 | ordering_norm=0.9489 | temp_norm=7.4593 | x_bar=6.2036 | ordering/val=0.1530
# 	iters: 200, epoch: 2 | loss: 0.2698753
# 	speed: 0.1807s/iter; left time: 195.3126s
# [FORMULA_B_SEM step=500] val_norm=31.9526 | ordering_norm=0.5980 | temp_norm=7.6685 | x_bar=31.9526 | ordering/val=0.0187
# [FORMULA_B_SEM step=500] val_norm=6.5343 | ordering_norm=1.0040 | temp_norm=7.4187 | x_bar=6.5343 | ordering/val=0.1537
# Epoch: 2 cost time: 46.189515352249146
# Epoch: 2, Steps: 256 | Train Loss: 0.2857946 Vali Loss: 1.3222252 Test Loss: 0.9361127
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=30.5881 | ordering_norm=0.6014 | temp_norm=7.6068 | x_bar=30.5881 | ordering/val=0.0197
# [FORMULA_B_SEM step=600] val_norm=6.4016 | ordering_norm=0.9862 | temp_norm=7.4863 | x_bar=6.4016 | ordering/val=0.1541
# 	iters: 100, epoch: 3 | loss: 0.2414410
# 	speed: 0.3774s/iter; left time: 349.1373s
# [FORMULA_B_SEM step=700] val_norm=28.8036 | ordering_norm=0.6403 | temp_norm=7.5530 | x_bar=28.8036 | ordering/val=0.0222
# [FORMULA_B_SEM step=700] val_norm=6.1088 | ordering_norm=0.9597 | temp_norm=7.3820 | x_bar=6.1088 | ordering/val=0.1571
# 	iters: 200, epoch: 3 | loss: 0.2316500
# 	speed: 0.1823s/iter; left time: 150.4339s
# Epoch: 3 cost time: 46.56011390686035
# Epoch: 3, Steps: 256 | Train Loss: 0.2401644 Vali Loss: 1.3248168 Test Loss: 0.9293649
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=30.2585 | ordering_norm=0.6245 | temp_norm=7.6203 | x_bar=30.2585 | ordering/val=0.0206
# [FORMULA_B_SEM step=800] val_norm=6.2399 | ordering_norm=0.9644 | temp_norm=7.4487 | x_bar=6.2399 | ordering/val=0.1546
# 	iters: 100, epoch: 4 | loss: 0.2158449
# 	speed: 0.3776s/iter; left time: 252.6263s
# [FORMULA_B_SEM step=900] val_norm=31.4209 | ordering_norm=0.5796 | temp_norm=7.6683 | x_bar=31.4209 | ordering/val=0.0184
# [FORMULA_B_SEM step=900] val_norm=6.4183 | ordering_norm=0.9946 | temp_norm=7.5120 | x_bar=6.4183 | ordering/val=0.1550
# 	iters: 200, epoch: 4 | loss: 0.2071622
# 	speed: 0.1822s/iter; left time: 103.6867s
# [FORMULA_B_SEM step=1000] val_norm=29.1357 | ordering_norm=0.6395 | temp_norm=7.6596 | x_bar=29.1357 | ordering/val=0.0219
# [FORMULA_B_SEM step=1000] val_norm=6.0616 | ordering_norm=0.9402 | temp_norm=7.4130 | x_bar=6.0616 | ordering/val=0.1551
# Epoch: 4 cost time: 46.5563645362854
# Epoch: 4, Steps: 256 | Train Loss: 0.2194999 Vali Loss: 1.3089417 Test Loss: 0.9321426
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:0.9252648949623108, mae:0.7778674960136414
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:36:15 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 9/12: formula_b_sem_ph2_ETTh1_pred48_seed2023
# pred_len=48 | seed=2023
# Start: Wed Aug  5 01:36:15 PM UTC 2026
# Args in experiment:
# ...
# [FORMULA_B_SEM step=400] val_norm=11.8904 | ordering_norm=1.1033 | temp_norm=7.5131 | x_bar=11.8904 | ordering/val=0.0928
# 	iters: 200, epoch: 2 | loss: 0.2708247
# 	speed: 0.0943s/iter; left time: 105.7556s
# [FORMULA_B_SEM step=500] val_norm=29.5543 | ordering_norm=0.6392 | temp_norm=7.6092 | x_bar=29.5543 | ordering/val=0.0216
# [FORMULA_B_SEM step=500] val_norm=11.3665 | ordering_norm=1.0843 | temp_norm=7.5070 | x_bar=11.3665 | ordering/val=0.0954
# Epoch: 2 cost time: 24.91289210319519
# Epoch: 2, Steps: 264 | Train Loss: 0.2606159 Vali Loss: 1.0777954 Test Loss: 0.8751889
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=29.9977 | ordering_norm=0.6244 | temp_norm=7.6820 | x_bar=29.9977 | ordering/val=0.0208
# [FORMULA_B_SEM step=600] val_norm=11.9277 | ordering_norm=1.1059 | temp_norm=7.5540 | x_bar=11.9277 | ordering/val=0.0927
# 	iters: 100, epoch: 3 | loss: 0.2288625
# 	speed: 0.2078s/iter; left time: 198.8419s
# [FORMULA_B_SEM step=700] val_norm=30.8524 | ordering_norm=0.5437 | temp_norm=7.6256 | x_bar=30.8524 | ordering/val=0.0176
# [FORMULA_B_SEM step=700] val_norm=12.0969 | ordering_norm=1.1026 | temp_norm=7.5317 | x_bar=12.0969 | ordering/val=0.0911
# 	iters: 200, epoch: 3 | loss: 0.1997793
# 	speed: 0.0940s/iter; left time: 80.5520s
# Epoch: 3 cost time: 24.772388458251953
# Epoch: 3, Steps: 264 | Train Loss: 0.2154023 Vali Loss: 1.0686460 Test Loss: 0.8532530
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=29.8362 | ordering_norm=0.6273 | temp_norm=7.6810 | x_bar=29.8362 | ordering/val=0.0210
# [FORMULA_B_SEM step=800] val_norm=11.6888 | ordering_norm=1.0988 | temp_norm=7.5205 | x_bar=11.6888 | ordering/val=0.0940
# 	iters: 100, epoch: 4 | loss: 0.1896542
# 	speed: 0.2079s/iter; left time: 144.0499s
# [FORMULA_B_SEM step=900] val_norm=28.3930 | ordering_norm=0.6299 | temp_norm=7.6377 | x_bar=28.3930 | ordering/val=0.0222
# [FORMULA_B_SEM step=900] val_norm=11.0942 | ordering_norm=1.0856 | temp_norm=7.5280 | x_bar=11.0942 | ordering/val=0.0979
# 	iters: 200, epoch: 4 | loss: 0.2013960
# 	speed: 0.0943s/iter; left time: 55.9332s
# [FORMULA_B_SEM step=1000] val_norm=29.2059 | ordering_norm=0.6414 | temp_norm=7.7046 | x_bar=29.2059 | ordering/val=0.0220
# [FORMULA_B_SEM step=1000] val_norm=11.4665 | ordering_norm=1.0906 | temp_norm=7.5144 | x_bar=11.4665 | ordering/val=0.0951
# Epoch: 4 cost time: 24.838891983032227
# Epoch: 4, Steps: 264 | Train Loss: 0.1976557 Vali Loss: 1.0813259 Test Loss: 0.8857937
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8614110946655273, mae:0.7358465194702148
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:40:13 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 11/12: formula_b_sem_ph2_ETTh1_pred192_seed2023
# pred_len=192 | seed=2023
# Start: Wed Aug  5 01:40:13 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred192_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_SEM step=0] val_norm=30.4297 | ordering_norm=0.6506 | temp_norm=7.6062 | x_bar=30.4297 | ordering/val=0.0214
# [FORMULA_B_SEM step=0] val_norm=8.4034 | ordering_norm=1.0605 | temp_norm=7.8336 | x_bar=8.4034 | ordering/val=0.1262
# 	iters: 100, epoch: 1 | loss: 0.4355145
# 	speed: 0.1376s/iter; left time: 201.9160s
# [FORMULA_B_SEM step=100] val_norm=29.6376 | ordering_norm=0.6605 | temp_norm=7.7283 | x_bar=29.6376 | ordering/val=0.0223
# [FORMULA_B_SEM step=100] val_norm=8.1415 | ordering_norm=1.0496 | temp_norm=7.8061 | x_bar=8.1415 | ordering/val=0.1289
# 	iters: 200, epoch: 1 | loss: 0.3150391
# 	speed: 0.1250s/iter; left time: 170.9088s
# [FORMULA_B_SEM step=200] val_norm=31.5836 | ordering_norm=0.6078 | temp_norm=7.6051 | x_bar=31.5836 | ordering/val=0.0192
# [FORMULA_B_SEM step=200] val_norm=8.6312 | ordering_norm=1.0809 | temp_norm=7.7661 | x_bar=8.6312 | ordering/val=0.1252
# Epoch: 1 cost time: 32.94054055213928
# Epoch: 1, Steps: 261 | Train Loss: 0.4218448 Vali Loss: 1.1222785 Test Loss: 0.9102250
# Validation loss decreased (inf --> 1.122278).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=31.3435 | ordering_norm=0.5673 | temp_norm=7.7255 | x_bar=31.3435 | ordering/val=0.0181
# [FORMULA_B_SEM step=300] val_norm=8.6348 | ordering_norm=1.0864 | temp_norm=7.8547 | x_bar=8.6348 | ordering/val=0.1258
# 	iters: 100, epoch: 2 | loss: 0.2888945
# 	speed: 0.2702s/iter; left time: 325.8729s
# [FORMULA_B_SEM step=400] val_norm=31.3737 | ordering_norm=0.5984 | temp_norm=7.5821 | x_bar=31.3737 | ordering/val=0.0191
# [FORMULA_B_SEM step=400] val_norm=8.5271 | ordering_norm=1.0851 | temp_norm=7.7328 | x_bar=8.5271 | ordering/val=0.1272
# 	iters: 200, epoch: 2 | loss: 0.2391379
# 	speed: 0.1237s/iter; left time: 136.8204s
# [FORMULA_B_SEM step=500] val_norm=29.2127 | ordering_norm=0.6239 | temp_norm=7.5756 | x_bar=29.2127 | ordering/val=0.0214
# [FORMULA_B_SEM step=500] val_norm=8.0084 | ordering_norm=1.0563 | temp_norm=7.7824 | x_bar=8.0084 | ordering/val=0.1319
# Epoch: 2 cost time: 32.273300647735596
# Epoch: 2, Steps: 261 | Train Loss: 0.2742592 Vali Loss: 1.2508707 Test Loss: 1.0488830
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=30.3673 | ordering_norm=0.6329 | temp_norm=7.7337 | x_bar=30.3673 | ordering/val=0.0208
# [FORMULA_B_SEM step=600] val_norm=8.3058 | ordering_norm=1.0591 | temp_norm=7.9068 | x_bar=8.3058 | ordering/val=0.1275
# 	iters: 100, epoch: 3 | loss: 0.2539270
# 	speed: 0.2672s/iter; left time: 252.4594s
# [FORMULA_B_SEM step=700] val_norm=30.0789 | ordering_norm=0.6329 | temp_norm=7.5784 | x_bar=30.0789 | ordering/val=0.0210
# [FORMULA_B_SEM step=700] val_norm=8.1828 | ordering_norm=1.0423 | temp_norm=7.7057 | x_bar=8.1828 | ordering/val=0.1274
# 	iters: 200, epoch: 3 | loss: 0.2230386
# 	speed: 0.1240s/iter; left time: 104.7969s
# Epoch: 3 cost time: 32.280089378356934
# Epoch: 3, Steps: 261 | Train Loss: 0.2305974 Vali Loss: 1.2703359 Test Loss: 1.0656672
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=29.8469 | ordering_norm=0.6422 | temp_norm=7.7068 | x_bar=29.8469 | ordering/val=0.0215
# [FORMULA_B_SEM step=800] val_norm=8.2463 | ordering_norm=1.0500 | temp_norm=7.8611 | x_bar=8.2463 | ordering/val=0.1273
# 	iters: 100, epoch: 4 | loss: 0.1915366
# 	speed: 0.2680s/iter; left time: 183.3271s
# [FORMULA_B_SEM step=900] val_norm=30.8908 | ordering_norm=0.6019 | temp_norm=7.6834 | x_bar=30.8908 | ordering/val=0.0195
# [FORMULA_B_SEM step=900] val_norm=8.2632 | ordering_norm=1.0655 | temp_norm=7.8737 | x_bar=8.2632 | ordering/val=0.1289
# 	iters: 200, epoch: 4 | loss: 0.1959739
# 	speed: 0.1244s/iter; left time: 72.6485s
# [FORMULA_B_SEM step=1000] val_norm=29.5849 | ordering_norm=0.6623 | temp_norm=7.6315 | x_bar=29.5849 | ordering/val=0.0224
# [FORMULA_B_SEM step=1000] val_norm=8.1314 | ordering_norm=1.0569 | temp_norm=7.7424 | x_bar=8.1314 | ordering/val=0.1300
# Epoch: 4 cost time: 32.3986873626709
# Epoch: 4, Steps: 261 | Train Loss: 0.2096027 Vali Loss: 1.2924414 Test Loss: 1.0412712
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.910224974155426, mae:0.7555420398712158
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:42:59 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 12/12: formula_b_sem_ph2_ETTh1_pred336_seed2023
# pred_len=336 | seed=2023
# Start: Wed Aug  5 01:42:59 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred336_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [FORMULA_B_SEM step=0] val_norm=30.0335 | ordering_norm=0.6996 | temp_norm=7.5184 | x_bar=30.0335 | ordering/val=0.0233
# [FORMULA_B_SEM step=0] val_norm=6.3346 | ordering_norm=0.9588 | temp_norm=7.7074 | x_bar=6.3346 | ordering/val=0.1514
# 	iters: 100, epoch: 1 | loss: 0.4535947
# 	speed: 0.1950s/iter; left time: 280.2841s
# [FORMULA_B_SEM step=100] val_norm=29.6838 | ordering_norm=0.6269 | temp_norm=7.4625 | x_bar=29.6838 | ordering/val=0.0211
# [FORMULA_B_SEM step=100] val_norm=6.2440 | ordering_norm=0.9584 | temp_norm=7.7422 | x_bar=6.2440 | ordering/val=0.1535
# 	iters: 200, epoch: 1 | loss: 0.3726221
# 	speed: 0.1821s/iter; left time: 243.4651s
# [FORMULA_B_SEM step=200] val_norm=29.5851 | ordering_norm=0.6124 | temp_norm=7.6257 | x_bar=29.5851 | ordering/val=0.0207
# [FORMULA_B_SEM step=200] val_norm=6.2936 | ordering_norm=0.9703 | temp_norm=7.8545 | x_bar=6.2936 | ordering/val=0.1542
# Epoch: 1 cost time: 46.902421951293945
# Epoch: 1, Steps: 256 | Train Loss: 0.4358178 Vali Loss: 1.2809323 Test Loss: 1.0116866
# Validation loss decreased (inf --> 1.280932).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=29.7880 | ordering_norm=0.6258 | temp_norm=7.4705 | x_bar=29.7880 | ordering/val=0.0210
# [FORMULA_B_SEM step=300] val_norm=6.1672 | ordering_norm=0.9454 | temp_norm=7.7915 | x_bar=6.1672 | ordering/val=0.1533
# 	iters: 100, epoch: 2 | loss: 0.2995124
# 	speed: 0.3786s/iter; left time: 447.0963s
# [FORMULA_B_SEM step=400] val_norm=27.6781 | ordering_norm=0.6870 | temp_norm=7.6234 | x_bar=27.6781 | ordering/val=0.0248
# [FORMULA_B_SEM step=400] val_norm=5.9447 | ordering_norm=0.9225 | temp_norm=7.7728 | x_bar=5.9447 | ordering/val=0.1552
# 	iters: 200, epoch: 2 | loss: 0.2712137
# 	speed: 0.1820s/iter; left time: 196.7648s
# [FORMULA_B_SEM step=500] val_norm=29.6933 | ordering_norm=0.6405 | temp_norm=7.4786 | x_bar=29.6933 | ordering/val=0.0216
# [FORMULA_B_SEM step=500] val_norm=6.1885 | ordering_norm=0.9543 | temp_norm=7.7804 | x_bar=6.1885 | ordering/val=0.1542
# Epoch: 2 cost time: 46.43592548370361
# Epoch: 2, Steps: 256 | Train Loss: 0.2826122 Vali Loss: 1.3324399 Test Loss: 1.1321894
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=31.9268 | ordering_norm=0.6108 | temp_norm=7.5369 | x_bar=31.9268 | ordering/val=0.0191
# [FORMULA_B_SEM step=600] val_norm=6.4987 | ordering_norm=0.9941 | temp_norm=7.7826 | x_bar=6.4987 | ordering/val=0.1530
# 	iters: 100, epoch: 3 | loss: 0.2353114
# 	speed: 0.3781s/iter; left time: 349.7706s
# [FORMULA_B_SEM step=700] val_norm=30.7188 | ordering_norm=0.6372 | temp_norm=7.4259 | x_bar=30.7188 | ordering/val=0.0207
# [FORMULA_B_SEM step=700] val_norm=6.3254 | ordering_norm=0.9653 | temp_norm=7.7315 | x_bar=6.3254 | ordering/val=0.1526
# 	iters: 200, epoch: 3 | loss: 0.2362111
# 	speed: 0.1823s/iter; left time: 150.3566s
# Epoch: 3 cost time: 46.5715913772583
# Epoch: 3, Steps: 256 | Train Loss: 0.2376813 Vali Loss: 1.3532081 Test Loss: 1.1199231
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=33.2370 | ordering_norm=0.6011 | temp_norm=7.6176 | x_bar=33.2370 | ordering/val=0.0181
# [FORMULA_B_SEM step=800] val_norm=6.7301 | ordering_norm=1.0147 | temp_norm=7.7493 | x_bar=6.7301 | ordering/val=0.1508
# 	iters: 100, epoch: 4 | loss: 0.2141509
# 	speed: 0.3778s/iter; left time: 252.7260s
# [FORMULA_B_SEM step=900] val_norm=29.4742 | ordering_norm=0.6110 | temp_norm=7.6586 | x_bar=29.4742 | ordering/val=0.0207
# [FORMULA_B_SEM step=900] val_norm=6.1361 | ordering_norm=0.9636 | temp_norm=7.8349 | x_bar=6.1361 | ordering/val=0.1570
# 	iters: 200, epoch: 4 | loss: 0.2208289
# 	speed: 0.1824s/iter; left time: 103.7976s
# [FORMULA_B_SEM step=1000] val_norm=31.8907 | ordering_norm=0.6071 | temp_norm=7.4925 | x_bar=31.8907 | ordering/val=0.0190
# [FORMULA_B_SEM step=1000] val_norm=6.4941 | ordering_norm=0.9956 | temp_norm=7.7536 | x_bar=6.4941 | ordering/val=0.1533
# Epoch: 4 cost time: 46.57728123664856
# Epoch: 4, Steps: 256 | Train Loss: 0.2167783 Vali Loss: 1.3681571 Test Loss: 1.2037930
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.0116863250732422, mae:0.8093421459197998
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:46:54 PM UTC 2026
#
# ============================================================
#  PHASE 2 SUMMARY — Formula B (Semantic Space)
#  Total: 12 | Completed: 12 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
# Seed  | PredLen | MSE      | MAE
# ------|---------|----------|----------
# 2021  | 48      | 0.9602015018463135 | 0.7683544158935547
# 2021  | 96      | 0.7835373878479004 | 0.682116687297821
# 2021  | 192     | 0.9376522302627563 | 0.7857064008712769
# 2021  | 336     | 0.9643481969833374 | 0.7918732762336731
#
# 2022  | 48      | 0.8936455249786377 | 0.7376778721809387
# 2022  | 96      | 0.7975202798843384 | 0.6957442164421082
# 2022  | 192     | 1.0187780857086182 | 0.8290572166442871
# 2022  | 336     | 0.9252648949623108 | 0.7778674960136414
#
# 2023  | 48      | 0.9553710222244263 | 0.7777656316757202
# 2023  | 96      | 0.8614110946655273 | 0.7358465194702148
# 2023  | 192     | 0.910224974155426 | 0.7555420398712158
# 2023  | 336     | 1.0116863250732422 | 0.8093421459197998
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0:
#  seed=2021 | pred=96  MSE=0.8683
#  seed=2021 | pred=192 MSE=0.8463  ← Phase 1 target
#
#  DECISION GUIDE:
#    Consistent improvement across all 3 seeds → result is robust
#    Improvement only at seed=2021             → Phase 1 was a fluke, investigate
#    Mixed results across pred_lens            → horizon-dependent, report range
#    Regression vs Phase 1 at all seeds        → implementation issue, debug
# ============================================================
# End: Wed Aug  5 01:46:54 PM UTC 2026
