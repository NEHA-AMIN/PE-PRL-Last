# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

project_path = '/content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1'
os.chdir(project_path)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1

# %%
# !ls -la /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-pos/formula-B-pos-ph1.sh
# Out:
# -rw------- 1 root root 7763 Aug  5 11:14 /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-pos/formula-B-pos-ph1.sh

# %%
import os

# Set your Informer data directory
informer_path = f'{project_path}/Informer2020-original'
data_dir = f'{informer_path}/data/ETT'
os.makedirs(data_dir, exist_ok=True)

# File path
data_file = f'{data_dir}/ETTh1.csv'

# Download ETTh1 dataset
if not os.path.exists(data_file):
    print("Downloading ETTh1.csv...")
    os.system(
        f'wget -q "https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv" '
        f'-O "{data_file}"'
    )

# Verify
if os.path.exists(data_file):
    print(f"✅ Download successful: {data_file}")
else:
    print("❌ Download failed.")
# Out:
# ✅ Download successful: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/data/ETT/ETTh1.csv

# %%
# Fix np.Inf -> np.inf in tools.py (removed in NumPy 2.0)
tools_path = f'{project_path}/Informer2020-original/utils/tools.py'

with open(tools_path, 'r') as f:
    content = f.read()

content_fixed = content.replace('np.Inf', 'np.inf')

with open(tools_path, 'w') as f:
    f.write(content_fixed)

print("✅ Fixed np.Inf -> np.inf in utils/tools.py")
# Out:
# ✅ Fixed np.Inf -> np.inf in utils/tools.py

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-pos/formula-B-pos-ph1.sh
# Out:
# ============================================================
#  Formula B (Positional Space) — Phase 1: Legendre Global Mean Deviation
#  Date: Wed Aug  5 01:40:23 PM UTC 2026
# ------------------------------------------------------------
#  Formula:  X'_i = V_i + T_i + P_i + Ordering_i
#  Signal:   Ordering_i = (mu_p - P_i) / (p_bar + 1e-8)
#  pe_mode:  formula_b_pos
# ------------------------------------------------------------
#  Seed:       2021
#  Pred lens:  96, 192
#  Total runs: 2
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/2: formula_b_pos_ph1_ETTh1_pred96_seed2021
# Start: Wed Aug  5 01:40:29 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph1_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph1_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [FORMULA_B_POS step=0] val_norm=32.0545 | ordering_norm=0.7617 | temp_norm=7.5583 | p_bar=0.1737 | ordering/val=0.0238
# [FORMULA_B_POS step=0] val_norm=13.2074 | ordering_norm=0.7660 | temp_norm=7.6829 | p_bar=0.1576 | ordering/val=0.0580
# 	iters: 100, epoch: 1 | loss: 0.4073773
# 	speed: 0.1482s/iter; left time: 220.1390s
# [FORMULA_B_POS step=100] val_norm=30.4566 | ordering_norm=0.7617 | temp_norm=7.3793 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=100] val_norm=12.6934 | ordering_norm=0.7660 | temp_norm=7.5472 | p_bar=0.1576 | ordering/val=0.0603
# 	iters: 200, epoch: 1 | loss: 0.3034835
# 	speed: 0.0837s/iter; left time: 115.9289s
# [FORMULA_B_POS step=200] val_norm=27.9825 | ordering_norm=0.7617 | temp_norm=7.4933 | p_bar=0.1737 | ordering/val=0.0272
# [FORMULA_B_POS step=200] val_norm=11.7935 | ordering_norm=0.7660 | temp_norm=7.6715 | p_bar=0.1576 | ordering/val=0.0650
# Epoch: 1 cost time: 23.612860441207886
# Epoch: 1, Steps: 264 | Train Loss: 0.4146472 Vali Loss: 1.0140493 Test Loss: 0.8686856
# Validation loss decreased (inf --> 1.014049).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=30.7891 | ordering_norm=0.7617 | temp_norm=7.4489 | p_bar=0.1737 | ordering/val=0.0247
# [FORMULA_B_POS step=300] val_norm=12.7372 | ordering_norm=0.7660 | temp_norm=7.5644 | p_bar=0.1576 | ordering/val=0.0601
# 	iters: 100, epoch: 2 | loss: 0.2894295
# 	speed: 0.1912s/iter; left time: 233.4550s
# [FORMULA_B_POS step=400] val_norm=28.9470 | ordering_norm=0.7617 | temp_norm=7.4817 | p_bar=0.1737 | ordering/val=0.0263
# [FORMULA_B_POS step=400] val_norm=12.2496 | ordering_norm=0.7660 | temp_norm=7.5730 | p_bar=0.1576 | ordering/val=0.0625
# 	iters: 200, epoch: 2 | loss: 0.2385359
# 	speed: 0.0862s/iter; left time: 96.6012s
# [FORMULA_B_POS step=500] val_norm=29.7894 | ordering_norm=0.7617 | temp_norm=7.4671 | p_bar=0.1737 | ordering/val=0.0256
# [FORMULA_B_POS step=500] val_norm=12.2770 | ordering_norm=0.7660 | temp_norm=7.5326 | p_bar=0.1576 | ordering/val=0.0624
# Epoch: 2 cost time: 22.717103719711304
# Epoch: 2, Steps: 264 | Train Loss: 0.2622723 Vali Loss: 1.0225297 Test Loss: 1.0541961
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=28.0669 | ordering_norm=0.7617 | temp_norm=7.4710 | p_bar=0.1737 | ordering/val=0.0271
# [FORMULA_B_POS step=600] val_norm=11.9575 | ordering_norm=0.7660 | temp_norm=7.6098 | p_bar=0.1576 | ordering/val=0.0641
# 	iters: 100, epoch: 3 | loss: 0.2268226
# 	speed: 0.1952s/iter; left time: 186.7961s
# [FORMULA_B_POS step=700] val_norm=31.4117 | ordering_norm=0.7617 | temp_norm=7.5372 | p_bar=0.1737 | ordering/val=0.0242
# [FORMULA_B_POS step=700] val_norm=12.8503 | ordering_norm=0.7660 | temp_norm=7.6702 | p_bar=0.1576 | ordering/val=0.0596
# 	iters: 200, epoch: 3 | loss: 0.2202307
# 	speed: 0.0889s/iter; left time: 76.1534s
# Epoch: 3 cost time: 23.39442491531372
# Epoch: 3, Steps: 264 | Train Loss: 0.2198018 Vali Loss: 1.0588065 Test Loss: 1.0622134
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=29.4048 | ordering_norm=0.7617 | temp_norm=7.4867 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=800] val_norm=12.5691 | ordering_norm=0.7660 | temp_norm=7.6408 | p_bar=0.1576 | ordering/val=0.0609
# 	iters: 100, epoch: 4 | loss: 0.1976673
# 	speed: 0.2007s/iter; left time: 139.1054s
# [FORMULA_B_POS step=900] val_norm=29.0641 | ordering_norm=0.7617 | temp_norm=7.5155 | p_bar=0.1737 | ordering/val=0.0262
# [FORMULA_B_POS step=900] val_norm=12.2616 | ordering_norm=0.7660 | temp_norm=7.6083 | p_bar=0.1576 | ordering/val=0.0625
# 	iters: 200, epoch: 4 | loss: 0.1847005
# 	speed: 0.0911s/iter; left time: 54.0514s
# [FORMULA_B_POS step=1000] val_norm=29.9470 | ordering_norm=0.7617 | temp_norm=7.5184 | p_bar=0.1737 | ordering/val=0.0254
# [FORMULA_B_POS step=1000] val_norm=12.4685 | ordering_norm=0.7660 | temp_norm=7.6586 | p_bar=0.1576 | ordering/val=0.0614
# Epoch: 4 cost time: 24.01692008972168
# Epoch: 4, Steps: 264 | Train Loss: 0.2018319 Vali Loss: 1.0656250 Test Loss: 1.1307383
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph1_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8686856031417847, mae:0.7318677306175232
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:43:00 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/2: formula_b_pos_ph1_ETTh1_pred192_seed2021
# Start: Wed Aug  5 01:43:00 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph1_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph1_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_POS step=0] val_norm=30.4365 | ordering_norm=0.7617 | temp_norm=7.4507 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=0] val_norm=8.3340 | ordering_norm=0.7727 | temp_norm=7.6314 | p_bar=0.1400 | ordering/val=0.0927
# 	iters: 100, epoch: 1 | loss: 0.3855225
# 	speed: 0.1335s/iter; left time: 195.9010s
# [FORMULA_B_POS step=100] val_norm=30.5123 | ordering_norm=0.7617 | temp_norm=7.4097 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=100] val_norm=8.3780 | ordering_norm=0.7727 | temp_norm=7.5803 | p_bar=0.1400 | ordering/val=0.0922
# 	iters: 200, epoch: 1 | loss: 0.3308043
# 	speed: 0.1202s/iter; left time: 164.2779s
# [FORMULA_B_POS step=200] val_norm=29.4296 | ordering_norm=0.7617 | temp_norm=7.5226 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=200] val_norm=8.0954 | ordering_norm=0.7727 | temp_norm=7.6302 | p_bar=0.1400 | ordering/val=0.0954
# Epoch: 1 cost time: 31.6605064868927
# Epoch: 1, Steps: 261 | Train Loss: 0.4145280 Vali Loss: 1.2413789 Test Loss: 0.9443878
# Validation loss decreased (inf --> 1.241379).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=31.6704 | ordering_norm=0.7617 | temp_norm=7.4892 | p_bar=0.1737 | ordering/val=0.0241
# [FORMULA_B_POS step=300] val_norm=8.4241 | ordering_norm=0.7727 | temp_norm=7.5611 | p_bar=0.1400 | ordering/val=0.0917
# 	iters: 100, epoch: 2 | loss: 0.2692087
# 	speed: 0.2654s/iter; left time: 320.1094s
# [FORMULA_B_POS step=400] val_norm=29.4589 | ordering_norm=0.7617 | temp_norm=7.5893 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=400] val_norm=8.2804 | ordering_norm=0.7727 | temp_norm=7.6441 | p_bar=0.1400 | ordering/val=0.0933
# 	iters: 200, epoch: 2 | loss: 0.2565760
# 	speed: 0.1199s/iter; left time: 132.5854s
# [FORMULA_B_POS step=500] val_norm=29.3399 | ordering_norm=0.7617 | temp_norm=7.4815 | p_bar=0.1737 | ordering/val=0.0260
# [FORMULA_B_POS step=500] val_norm=8.2251 | ordering_norm=0.7727 | temp_norm=7.6587 | p_bar=0.1400 | ordering/val=0.0939
# Epoch: 2 cost time: 31.31469750404358
# Epoch: 2, Steps: 261 | Train Loss: 0.2701717 Vali Loss: 1.2330587 Test Loss: 0.9874746
# Validation loss decreased (1.241379 --> 1.233059).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=30.1356 | ordering_norm=0.7617 | temp_norm=7.4156 | p_bar=0.1737 | ordering/val=0.0253
# [FORMULA_B_POS step=600] val_norm=8.2918 | ordering_norm=0.7727 | temp_norm=7.5158 | p_bar=0.1400 | ordering/val=0.0932
# 	iters: 100, epoch: 3 | loss: 0.2424693
# 	speed: 0.2609s/iter; left time: 246.5561s
# [FORMULA_B_POS step=700] val_norm=29.2322 | ordering_norm=0.7617 | temp_norm=7.4649 | p_bar=0.1737 | ordering/val=0.0261
# [FORMULA_B_POS step=700] val_norm=8.1496 | ordering_norm=0.7727 | temp_norm=7.6061 | p_bar=0.1400 | ordering/val=0.0948
# 	iters: 200, epoch: 3 | loss: 0.2159561
# 	speed: 0.1196s/iter; left time: 101.1008s
# Epoch: 3 cost time: 31.140751600265503
# Epoch: 3, Steps: 261 | Train Loss: 0.2266192 Vali Loss: 1.2768025 Test Loss: 1.0664446
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=28.3915 | ordering_norm=0.7617 | temp_norm=7.4877 | p_bar=0.1737 | ordering/val=0.0268
# [FORMULA_B_POS step=800] val_norm=8.0545 | ordering_norm=0.7727 | temp_norm=7.6278 | p_bar=0.1400 | ordering/val=0.0959
# 	iters: 100, epoch: 4 | loss: 0.2017349
# 	speed: 0.2624s/iter; left time: 179.4567s
# [FORMULA_B_POS step=900] val_norm=29.3051 | ordering_norm=0.7617 | temp_norm=7.4752 | p_bar=0.1737 | ordering/val=0.0260
# [FORMULA_B_POS step=900] val_norm=8.1351 | ordering_norm=0.7727 | temp_norm=7.6126 | p_bar=0.1400 | ordering/val=0.0950
# 	iters: 200, epoch: 4 | loss: 0.2000673
# 	speed: 0.1203s/iter; left time: 70.2437s
# [FORMULA_B_POS step=1000] val_norm=30.1429 | ordering_norm=0.7617 | temp_norm=7.4729 | p_bar=0.1737 | ordering/val=0.0253
# [FORMULA_B_POS step=1000] val_norm=8.1677 | ordering_norm=0.7727 | temp_norm=7.5621 | p_bar=0.1400 | ordering/val=0.0946
# Epoch: 4 cost time: 31.37119698524475
# Epoch: 4, Steps: 261 | Train Loss: 0.2051823 Vali Loss: 1.2694641 Test Loss: 1.0262524
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# [FORMULA_B_POS step=1100] val_norm=28.1484 | ordering_norm=0.7617 | temp_norm=7.5826 | p_bar=0.1737 | ordering/val=0.0271
# [FORMULA_B_POS step=1100] val_norm=7.9227 | ordering_norm=0.7727 | temp_norm=7.7002 | p_bar=0.1400 | ordering/val=0.0975
# 	iters: 100, epoch: 5 | loss: 0.1971872
# 	speed: 0.2606s/iter; left time: 110.2489s
# [FORMULA_B_POS step=1200] val_norm=29.0378 | ordering_norm=0.7617 | temp_norm=7.4254 | p_bar=0.1737 | ordering/val=0.0262
# [FORMULA_B_POS step=1200] val_norm=8.0368 | ordering_norm=0.7727 | temp_norm=7.5738 | p_bar=0.1400 | ordering/val=0.0961
# 	iters: 200, epoch: 5 | loss: 0.1905783
# 	speed: 0.1198s/iter; left time: 38.6905s
# [FORMULA_B_POS step=1300] val_norm=29.0911 | ordering_norm=0.7617 | temp_norm=7.4477 | p_bar=0.1737 | ordering/val=0.0262
# [FORMULA_B_POS step=1300] val_norm=8.2493 | ordering_norm=0.7727 | temp_norm=7.6432 | p_bar=0.1400 | ordering/val=0.0937
# Epoch: 5 cost time: 31.17002034187317
# Epoch: 5, Steps: 261 | Train Loss: 0.1948888 Vali Loss: 1.2741810 Test Loss: 1.0745630
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph1_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.9874743819236755, mae:0.7753885984420776
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:46:31 PM UTC 2026
#
# ============================================================
#  PHASE 1 SUMMARY — Formula B (Positional Space)
#  Total: 2 | Completed: 2 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
#  RUN_ID                                                         MSE        MAE
#  ------------------------------------------------------- ---------- ----------
#  formula_b_pos_ph1_ETTh1_pred96_seed2021                 0.8686856031417847 0.7318677306175232
#  formula_b_pos_ph1_ETTh1_pred192_seed2021                0.9874743819236755 0.7753885984420776
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0 (seed=2021):
#    pred=96  MSE=0.8683
#    pred=192 MSE=0.8463  ← target to beat
#
#  DECISION GUIDE:
#    Formula-B-pos wins BOTH vs Exp1-Pre → proceed to Phase 2
#    Formula-B-pos wins ONE  vs Exp1-Pre → Phase 2 to confirm
#    Formula-B-pos loses BOTH            → document, stop
# ============================================================
# End: Wed Aug  5 01:46:31 PM UTC 2026

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-pos/formula-B-pos-ph2.sh
# Out:
# ============================================================
#  Formula B (Positional Space) — Phase 2: Legendre Global Mean Deviation
#  Date: Tue Aug 11 06:29:07 AM UTC 2026
# ------------------------------------------------------------
#  Formula:  X'_i = V_i + T_i + P_i + Ordering_i
#  Signal:   Ordering_i = (mu_p - P_i) / (p_bar + 1e-8)
#  pe_mode:  formula_b_pos
# ------------------------------------------------------------
#  Seeds:      2021, 2022, 2023
#  Pred lens:  48, 96, 192, 336
#  Total runs: 12
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/12: formula_b_pos_ph2_ETTh1_pred48_seed2021
# pred_len=48 | seed=2021
# Start: Tue Aug 11 06:29:11 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred48_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred48_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# [FORMULA_B_POS step=0] val_norm=28.4798 | ordering_norm=0.7617 | temp_norm=7.5064 | p_bar=0.1737 | ordering/val=0.0267
# [FORMULA_B_POS step=0] val_norm=16.5681 | ordering_norm=0.7617 | temp_norm=7.6405 | p_bar=0.1737 | ordering/val=0.0460
# 	iters: 100, epoch: 1 | loss: 0.4258510
# 	speed: 0.1538s/iter; left time: 229.2761s
# [FORMULA_B_POS step=100] val_norm=30.5416 | ordering_norm=0.7617 | temp_norm=7.5548 | p_bar=0.1737 | ordering/val=0.0249
# [FORMULA_B_POS step=100] val_norm=17.3531 | ordering_norm=0.7617 | temp_norm=7.6547 | p_bar=0.1737 | ordering/val=0.0439
# 	iters: 200, epoch: 1 | loss: 0.3108952
# 	speed: 0.0721s/iter; left time: 100.2713s
# [FORMULA_B_POS step=200] val_norm=30.1828 | ordering_norm=0.7617 | temp_norm=7.4230 | p_bar=0.1737 | ordering/val=0.0252
# [FORMULA_B_POS step=200] val_norm=17.0447 | ordering_norm=0.7617 | temp_norm=7.6085 | p_bar=0.1737 | ordering/val=0.0447
# Epoch: 1 cost time: 20.605146408081055
# Epoch: 1, Steps: 265 | Train Loss: 0.3976476 Vali Loss: 0.8268783 Test Loss: 0.7086888
# Validation loss decreased (inf --> 0.826878).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=31.5386 | ordering_norm=0.7617 | temp_norm=7.5832 | p_bar=0.1737 | ordering/val=0.0242
# [FORMULA_B_POS step=300] val_norm=17.6516 | ordering_norm=0.7617 | temp_norm=7.7005 | p_bar=0.1737 | ordering/val=0.0432
# 	iters: 100, epoch: 2 | loss: 0.2300673
# 	speed: 0.1663s/iter; left time: 203.8423s
# [FORMULA_B_POS step=400] val_norm=30.1768 | ordering_norm=0.7617 | temp_norm=7.4714 | p_bar=0.1737 | ordering/val=0.0252
# [FORMULA_B_POS step=400] val_norm=17.1423 | ordering_norm=0.7617 | temp_norm=7.5592 | p_bar=0.1737 | ordering/val=0.0444
# 	iters: 200, epoch: 2 | loss: 0.2733065
# 	speed: 0.0757s/iter; left time: 85.2889s
# [FORMULA_B_POS step=500] val_norm=28.4077 | ordering_norm=0.7617 | temp_norm=7.5871 | p_bar=0.1737 | ordering/val=0.0268
# [FORMULA_B_POS step=500] val_norm=16.3353 | ordering_norm=0.7617 | temp_norm=7.5796 | p_bar=0.1737 | ordering/val=0.0466
# Epoch: 2 cost time: 19.91140341758728
# Epoch: 2, Steps: 265 | Train Loss: 0.2567784 Vali Loss: 0.9459894 Test Loss: 0.8549531
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=28.7181 | ordering_norm=0.7617 | temp_norm=7.5479 | p_bar=0.1737 | ordering/val=0.0265
# [FORMULA_B_POS step=600] val_norm=16.2722 | ordering_norm=0.7617 | temp_norm=7.6364 | p_bar=0.1737 | ordering/val=0.0468
# 	iters: 100, epoch: 3 | loss: 0.2091484
# 	speed: 0.1730s/iter; left time: 166.2411s
# [FORMULA_B_POS step=700] val_norm=31.3749 | ordering_norm=0.7617 | temp_norm=7.4500 | p_bar=0.1737 | ordering/val=0.0243
# [FORMULA_B_POS step=700] val_norm=18.0348 | ordering_norm=0.7617 | temp_norm=7.5464 | p_bar=0.1737 | ordering/val=0.0422
# 	iters: 200, epoch: 3 | loss: 0.1915747
# 	speed: 0.0796s/iter; left time: 68.5133s
# Epoch: 3 cost time: 21.027793645858765
# Epoch: 3, Steps: 265 | Train Loss: 0.2092043 Vali Loss: 0.9496920 Test Loss: 0.8542162
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=31.5364 | ordering_norm=0.7617 | temp_norm=7.5964 | p_bar=0.1737 | ordering/val=0.0242
# [FORMULA_B_POS step=800] val_norm=17.6513 | ordering_norm=0.7617 | temp_norm=7.6088 | p_bar=0.1737 | ordering/val=0.0432
# 	iters: 100, epoch: 4 | loss: 0.1891412
# 	speed: 0.1853s/iter; left time: 128.9513s
# [FORMULA_B_POS step=900] val_norm=30.6792 | ordering_norm=0.7617 | temp_norm=7.5003 | p_bar=0.1737 | ordering/val=0.0248
# [FORMULA_B_POS step=900] val_norm=17.0035 | ordering_norm=0.7617 | temp_norm=7.5749 | p_bar=0.1737 | ordering/val=0.0448
# 	iters: 200, epoch: 4 | loss: 0.1834201
# 	speed: 0.0883s/iter; left time: 52.6197s
# [FORMULA_B_POS step=1000] val_norm=29.9725 | ordering_norm=0.7617 | temp_norm=7.5183 | p_bar=0.1737 | ordering/val=0.0254
# [FORMULA_B_POS step=1000] val_norm=17.0612 | ordering_norm=0.7617 | temp_norm=7.5775 | p_bar=0.1737 | ordering/val=0.0446
# Epoch: 4 cost time: 23.102635145187378
# Epoch: 4, Steps: 265 | Train Loss: 0.1904238 Vali Loss: 0.9957936 Test Loss: 0.9396082
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred48_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.7086886167526245, mae:0.6460009217262268
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 06:31:30 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/12: formula_b_pos_ph2_ETTh1_pred96_seed2021
# pred_len=96 | seed=2021
# Start: Tue Aug 11 06:31:30 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [FORMULA_B_POS step=0] val_norm=27.7925 | ordering_norm=0.7617 | temp_norm=7.6013 | p_bar=0.1737 | ordering/val=0.0274
# [FORMULA_B_POS step=0] val_norm=11.4645 | ordering_norm=0.7660 | temp_norm=7.7068 | p_bar=0.1576 | ordering/val=0.0668
# 	iters: 100, epoch: 1 | loss: 0.4317533
# 	speed: 0.1122s/iter; left time: 166.6849s
# [FORMULA_B_POS step=100] val_norm=29.7378 | ordering_norm=0.7617 | temp_norm=7.5779 | p_bar=0.1737 | ordering/val=0.0256
# [FORMULA_B_POS step=100] val_norm=12.4105 | ordering_norm=0.7660 | temp_norm=7.6584 | p_bar=0.1576 | ordering/val=0.0617
# 	iters: 200, epoch: 1 | loss: 0.3207609
# 	speed: 0.1009s/iter; left time: 139.7973s
# [FORMULA_B_POS step=200] val_norm=30.2345 | ordering_norm=0.7617 | temp_norm=7.5207 | p_bar=0.1737 | ordering/val=0.0252
# [FORMULA_B_POS step=200] val_norm=12.3510 | ordering_norm=0.7660 | temp_norm=7.5912 | p_bar=0.1576 | ordering/val=0.0620
# Epoch: 1 cost time: 26.86266541481018
# Epoch: 1, Steps: 264 | Train Loss: 0.4068857 Vali Loss: 0.9856502 Test Loss: 0.9209664
# Validation loss decreased (inf --> 0.985650).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=30.2489 | ordering_norm=0.7617 | temp_norm=7.5799 | p_bar=0.1737 | ordering/val=0.0252
# [FORMULA_B_POS step=300] val_norm=12.2462 | ordering_norm=0.7660 | temp_norm=7.6866 | p_bar=0.1576 | ordering/val=0.0626
# 	iters: 100, epoch: 2 | loss: 0.2744876
# 	speed: 0.2451s/iter; left time: 299.2163s
# [FORMULA_B_POS step=400] val_norm=31.1693 | ordering_norm=0.7617 | temp_norm=7.6075 | p_bar=0.1737 | ordering/val=0.0244
# [FORMULA_B_POS step=400] val_norm=12.4974 | ordering_norm=0.7660 | temp_norm=7.7104 | p_bar=0.1576 | ordering/val=0.0613
# 	iters: 200, epoch: 2 | loss: 0.2303314
# 	speed: 0.1064s/iter; left time: 119.2845s
# [FORMULA_B_POS step=500] val_norm=29.0155 | ordering_norm=0.7617 | temp_norm=7.4893 | p_bar=0.1737 | ordering/val=0.0263
# [FORMULA_B_POS step=500] val_norm=11.9914 | ordering_norm=0.7660 | temp_norm=7.5642 | p_bar=0.1576 | ordering/val=0.0639
# Epoch: 2 cost time: 28.245933294296265
# Epoch: 2, Steps: 264 | Train Loss: 0.2594496 Vali Loss: 1.0673715 Test Loss: 0.9761400
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=28.3999 | ordering_norm=0.7617 | temp_norm=7.6238 | p_bar=0.1737 | ordering/val=0.0268
# [FORMULA_B_POS step=600] val_norm=11.9051 | ordering_norm=0.7660 | temp_norm=7.6620 | p_bar=0.1576 | ordering/val=0.0643
# 	iters: 100, epoch: 3 | loss: 0.2134050
# 	speed: 0.2257s/iter; left time: 215.9850s
# [FORMULA_B_POS step=700] val_norm=30.5811 | ordering_norm=0.7617 | temp_norm=7.6433 | p_bar=0.1737 | ordering/val=0.0249
# [FORMULA_B_POS step=700] val_norm=12.4441 | ordering_norm=0.7660 | temp_norm=7.6624 | p_bar=0.1576 | ordering/val=0.0616
# 	iters: 200, epoch: 3 | loss: 0.2276009
# 	speed: 0.0998s/iter; left time: 85.4870s
# Epoch: 3 cost time: 26.448257446289062
# Epoch: 3, Steps: 264 | Train Loss: 0.2158359 Vali Loss: 1.0629531 Test Loss: 1.0546184
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=27.6020 | ordering_norm=0.7617 | temp_norm=7.5294 | p_bar=0.1737 | ordering/val=0.0276
# [FORMULA_B_POS step=800] val_norm=11.4692 | ordering_norm=0.7660 | temp_norm=7.6393 | p_bar=0.1576 | ordering/val=0.0668
# 	iters: 100, epoch: 4 | loss: 0.2098494
# 	speed: 0.2244s/iter; left time: 155.5420s
# [FORMULA_B_POS step=900] val_norm=30.0828 | ordering_norm=0.7617 | temp_norm=7.5090 | p_bar=0.1737 | ordering/val=0.0253
# [FORMULA_B_POS step=900] val_norm=12.2346 | ordering_norm=0.7660 | temp_norm=7.6031 | p_bar=0.1576 | ordering/val=0.0626
# 	iters: 200, epoch: 4 | loss: 0.1846274
# 	speed: 0.1021s/iter; left time: 60.5602s
# [FORMULA_B_POS step=1000] val_norm=30.5102 | ordering_norm=0.7617 | temp_norm=7.5720 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=1000] val_norm=12.6113 | ordering_norm=0.7660 | temp_norm=7.6675 | p_bar=0.1576 | ordering/val=0.0607
# Epoch: 4 cost time: 26.900843620300293
# Epoch: 4, Steps: 264 | Train Loss: 0.1992073 Vali Loss: 1.0653737 Test Loss: 1.0347643
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.9209663271903992, mae:0.7743777632713318
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 06:34:03 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 3/12: formula_b_pos_ph2_ETTh1_pred192_seed2021
# pred_len=192 | seed=2021
# Start: Tue Aug 11 06:34:03 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_POS step=0] val_norm=28.2998 | ordering_norm=0.7617 | temp_norm=7.5834 | p_bar=0.1737 | ordering/val=0.0269
# [FORMULA_B_POS step=0] val_norm=7.9825 | ordering_norm=0.7727 | temp_norm=7.7282 | p_bar=0.1400 | ordering/val=0.0968
# 	iters: 100, epoch: 1 | loss: 0.4260065
# 	speed: 0.1503s/iter; left time: 220.5314s
# [FORMULA_B_POS step=100] val_norm=31.4016 | ordering_norm=0.7617 | temp_norm=7.4754 | p_bar=0.1737 | ordering/val=0.0243
# [FORMULA_B_POS step=100] val_norm=8.7429 | ordering_norm=0.7727 | temp_norm=7.6495 | p_bar=0.1400 | ordering/val=0.0884
# 	iters: 200, epoch: 1 | loss: 0.3609994
# 	speed: 0.1438s/iter; left time: 196.6099s
# [FORMULA_B_POS step=200] val_norm=30.0783 | ordering_norm=0.7617 | temp_norm=7.4871 | p_bar=0.1737 | ordering/val=0.0253
# [FORMULA_B_POS step=200] val_norm=8.4023 | ordering_norm=0.7727 | temp_norm=7.6291 | p_bar=0.1400 | ordering/val=0.0920
# Epoch: 1 cost time: 37.29619288444519
# Epoch: 1, Steps: 261 | Train Loss: 0.4169011 Vali Loss: 1.2369211 Test Loss: 1.0836326
# Validation loss decreased (inf --> 1.236921).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=28.2783 | ordering_norm=0.7617 | temp_norm=7.5152 | p_bar=0.1737 | ordering/val=0.0269
# [FORMULA_B_POS step=300] val_norm=8.0247 | ordering_norm=0.7727 | temp_norm=7.7055 | p_bar=0.1400 | ordering/val=0.0963
# 	iters: 100, epoch: 2 | loss: 0.2788109
# 	speed: 0.3195s/iter; left time: 385.3156s
# [FORMULA_B_POS step=400] val_norm=29.6608 | ordering_norm=0.7617 | temp_norm=7.4931 | p_bar=0.1737 | ordering/val=0.0257
# [FORMULA_B_POS step=400] val_norm=8.2432 | ordering_norm=0.7727 | temp_norm=7.6686 | p_bar=0.1400 | ordering/val=0.0937
# 	iters: 200, epoch: 2 | loss: 0.2521451
# 	speed: 0.1345s/iter; left time: 148.8084s
# [FORMULA_B_POS step=500] val_norm=29.4689 | ordering_norm=0.7617 | temp_norm=7.5345 | p_bar=0.1737 | ordering/val=0.0258
# [FORMULA_B_POS step=500] val_norm=8.1592 | ordering_norm=0.7727 | temp_norm=7.6487 | p_bar=0.1400 | ordering/val=0.0947
# Epoch: 2 cost time: 35.55734181404114
# Epoch: 2, Steps: 261 | Train Loss: 0.2740869 Vali Loss: 1.2314715 Test Loss: 1.1172216
# Validation loss decreased (1.236921 --> 1.231472).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=30.6902 | ordering_norm=0.7617 | temp_norm=7.5479 | p_bar=0.1737 | ordering/val=0.0248
# [FORMULA_B_POS step=600] val_norm=8.3911 | ordering_norm=0.7727 | temp_norm=7.6880 | p_bar=0.1400 | ordering/val=0.0921
# 	iters: 100, epoch: 3 | loss: 0.2284070
# 	speed: 0.2929s/iter; left time: 276.7875s
# [FORMULA_B_POS step=700] val_norm=29.9789 | ordering_norm=0.7617 | temp_norm=7.5312 | p_bar=0.1737 | ordering/val=0.0254
# [FORMULA_B_POS step=700] val_norm=8.3686 | ordering_norm=0.7727 | temp_norm=7.6304 | p_bar=0.1400 | ordering/val=0.0923
# 	iters: 200, epoch: 3 | loss: 0.2179741
# 	speed: 0.1403s/iter; left time: 118.5662s
# Epoch: 3 cost time: 36.16722345352173
# Epoch: 3, Steps: 261 | Train Loss: 0.2304403 Vali Loss: 1.2855303 Test Loss: 1.2032588
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=31.2625 | ordering_norm=0.7617 | temp_norm=7.5668 | p_bar=0.1737 | ordering/val=0.0244
# [FORMULA_B_POS step=800] val_norm=8.6293 | ordering_norm=0.7727 | temp_norm=7.7232 | p_bar=0.1400 | ordering/val=0.0895
# 	iters: 100, epoch: 4 | loss: 0.1911743
# 	speed: 0.3075s/iter; left time: 210.3087s
# [FORMULA_B_POS step=900] val_norm=29.2804 | ordering_norm=0.7617 | temp_norm=7.5265 | p_bar=0.1737 | ordering/val=0.0260
# [FORMULA_B_POS step=900] val_norm=8.2001 | ordering_norm=0.7727 | temp_norm=7.6767 | p_bar=0.1400 | ordering/val=0.0942
# 	iters: 200, epoch: 4 | loss: 0.2096443
# 	speed: 0.1381s/iter; left time: 80.6769s
# [FORMULA_B_POS step=1000] val_norm=28.7580 | ordering_norm=0.7617 | temp_norm=7.6333 | p_bar=0.1737 | ordering/val=0.0265
# [FORMULA_B_POS step=1000] val_norm=7.9968 | ordering_norm=0.7727 | temp_norm=7.7638 | p_bar=0.1400 | ordering/val=0.0966
# Epoch: 4 cost time: 36.19580435752869
# Epoch: 4, Steps: 261 | Train Loss: 0.2121645 Vali Loss: 1.2627722 Test Loss: 1.1859983
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# [FORMULA_B_POS step=1100] val_norm=29.8515 | ordering_norm=0.7617 | temp_norm=7.5748 | p_bar=0.1737 | ordering/val=0.0255
# [FORMULA_B_POS step=1100] val_norm=8.2624 | ordering_norm=0.7727 | temp_norm=7.6512 | p_bar=0.1400 | ordering/val=0.0935
# 	iters: 100, epoch: 5 | loss: 0.1899783
# 	speed: 0.2985s/iter; left time: 126.2683s
# [FORMULA_B_POS step=1200] val_norm=28.6904 | ordering_norm=0.7617 | temp_norm=7.6828 | p_bar=0.1737 | ordering/val=0.0265
# [FORMULA_B_POS step=1200] val_norm=8.0273 | ordering_norm=0.7727 | temp_norm=7.7926 | p_bar=0.1400 | ordering/val=0.0963
# 	iters: 200, epoch: 5 | loss: 0.1870479
# 	speed: 0.1391s/iter; left time: 44.9246s
# [FORMULA_B_POS step=1300] val_norm=27.4742 | ordering_norm=0.7617 | temp_norm=7.6655 | p_bar=0.1737 | ordering/val=0.0277
# [FORMULA_B_POS step=1300] val_norm=7.8607 | ordering_norm=0.7727 | temp_norm=7.7881 | p_bar=0.1400 | ordering/val=0.0983
# Epoch: 5 cost time: 36.157355070114136
# Epoch: 5, Steps: 261 | Train Loss: 0.2027565 Vali Loss: 1.2821227 Test Loss: 1.1603755
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:1.1172220706939697, mae:0.8468191027641296
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 06:38:06 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 4/12: formula_b_pos_ph2_ETTh1_pred336_seed2021
# pred_len=336 | seed=2021
# Start: Tue Aug 11 06:38:06 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred336_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred336_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [FORMULA_B_POS step=0] val_norm=28.2768 | ordering_norm=0.7617 | temp_norm=7.8833 | p_bar=0.1737 | ordering/val=0.0269
# [FORMULA_B_POS step=0] val_norm=6.0776 | ordering_norm=0.7796 | temp_norm=7.7171 | p_bar=0.1260 | ordering/val=0.1283
# 	iters: 100, epoch: 1 | loss: 0.4287992
# 	speed: 0.2081s/iter; left time: 299.0358s
# [FORMULA_B_POS step=100] val_norm=29.1954 | ordering_norm=0.7617 | temp_norm=7.8519 | p_bar=0.1737 | ordering/val=0.0261
# [FORMULA_B_POS step=100] val_norm=6.1597 | ordering_norm=0.7796 | temp_norm=7.7002 | p_bar=0.1260 | ordering/val=0.1266
# 	iters: 200, epoch: 1 | loss: 0.3729262
# 	speed: 0.2152s/iter; left time: 287.7850s
# [FORMULA_B_POS step=200] val_norm=29.7092 | ordering_norm=0.7617 | temp_norm=7.9039 | p_bar=0.1737 | ordering/val=0.0256
# [FORMULA_B_POS step=200] val_norm=6.3017 | ordering_norm=0.7796 | temp_norm=7.7240 | p_bar=0.1260 | ordering/val=0.1237
# Epoch: 1 cost time: 52.75253081321716
# Epoch: 1, Steps: 256 | Train Loss: 0.4330048 Vali Loss: 1.3452257 Test Loss: 0.8889532
# Validation loss decreased (inf --> 1.345226).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=29.8675 | ordering_norm=0.7617 | temp_norm=7.8890 | p_bar=0.1737 | ordering/val=0.0255
# [FORMULA_B_POS step=300] val_norm=6.2901 | ordering_norm=0.7796 | temp_norm=7.7393 | p_bar=0.1260 | ordering/val=0.1239
# 	iters: 100, epoch: 2 | loss: 0.2867581
# 	speed: 0.4136s/iter; left time: 488.5117s
# [FORMULA_B_POS step=400] val_norm=29.0051 | ordering_norm=0.7617 | temp_norm=7.9055 | p_bar=0.1737 | ordering/val=0.0263
# [FORMULA_B_POS step=400] val_norm=6.1279 | ordering_norm=0.7796 | temp_norm=7.7590 | p_bar=0.1260 | ordering/val=0.1272
# 	iters: 200, epoch: 2 | loss: 0.2527103
# 	speed: 0.1938s/iter; left time: 209.5385s
# [FORMULA_B_POS step=500] val_norm=30.0275 | ordering_norm=0.7617 | temp_norm=7.9617 | p_bar=0.1737 | ordering/val=0.0254
# [FORMULA_B_POS step=500] val_norm=6.2351 | ordering_norm=0.7796 | temp_norm=7.7766 | p_bar=0.1260 | ordering/val=0.1250
# Epoch: 2 cost time: 49.64765977859497
# Epoch: 2, Steps: 256 | Train Loss: 0.2840724 Vali Loss: 1.3371342 Test Loss: 1.0347873
# Validation loss decreased (1.345226 --> 1.337134).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=29.4083 | ordering_norm=0.7617 | temp_norm=8.0367 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=600] val_norm=6.0739 | ordering_norm=0.7796 | temp_norm=7.8303 | p_bar=0.1260 | ordering/val=0.1283
# 	iters: 100, epoch: 3 | loss: 0.2416161
# 	speed: 0.4242s/iter; left time: 392.3575s
# [FORMULA_B_POS step=700] val_norm=30.6081 | ordering_norm=0.7617 | temp_norm=7.8874 | p_bar=0.1737 | ordering/val=0.0249
# [FORMULA_B_POS step=700] val_norm=6.3010 | ordering_norm=0.7796 | temp_norm=7.6741 | p_bar=0.1260 | ordering/val=0.1237
# 	iters: 200, epoch: 3 | loss: 0.2317501
# 	speed: 0.1994s/iter; left time: 164.5125s
# Epoch: 3 cost time: 51.066065073013306
# Epoch: 3, Steps: 256 | Train Loss: 0.2388141 Vali Loss: 1.3460691 Test Loss: 1.1452975
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=26.8255 | ordering_norm=0.7617 | temp_norm=7.9438 | p_bar=0.1737 | ordering/val=0.0284
# [FORMULA_B_POS step=800] val_norm=5.8978 | ordering_norm=0.7796 | temp_norm=7.7396 | p_bar=0.1260 | ordering/val=0.1322
# 	iters: 100, epoch: 4 | loss: 0.1983194
# 	speed: 0.4146s/iter; left time: 277.3755s
# [FORMULA_B_POS step=900] val_norm=30.0655 | ordering_norm=0.7617 | temp_norm=8.0789 | p_bar=0.1737 | ordering/val=0.0253
# [FORMULA_B_POS step=900] val_norm=6.3224 | ordering_norm=0.7796 | temp_norm=7.8123 | p_bar=0.1260 | ordering/val=0.1233
# 	iters: 200, epoch: 4 | loss: 0.1947214
# 	speed: 0.2015s/iter; left time: 114.6775s
# [FORMULA_B_POS step=1000] val_norm=29.8317 | ordering_norm=0.7617 | temp_norm=7.8014 | p_bar=0.1737 | ordering/val=0.0255
# [FORMULA_B_POS step=1000] val_norm=6.3327 | ordering_norm=0.7796 | temp_norm=7.6572 | p_bar=0.1260 | ordering/val=0.1231
# Epoch: 4 cost time: 51.27303457260132
# Epoch: 4, Steps: 256 | Train Loss: 0.2173430 Vali Loss: 1.3266777 Test Loss: 1.1496708
# Validation loss decreased (1.337134 --> 1.326678).  Saving model ...
# Updating learning rate to 1.25e-05
# [FORMULA_B_POS step=1100] val_norm=30.2448 | ordering_norm=0.7617 | temp_norm=7.8186 | p_bar=0.1737 | ordering/val=0.0252
# [FORMULA_B_POS step=1100] val_norm=6.2767 | ordering_norm=0.7796 | temp_norm=7.6949 | p_bar=0.1260 | ordering/val=0.1242
# 	iters: 100, epoch: 5 | loss: 0.2113311
# 	speed: 0.4199s/iter; left time: 173.4182s
# [FORMULA_B_POS step=1200] val_norm=30.8331 | ordering_norm=0.7617 | temp_norm=7.8332 | p_bar=0.1737 | ordering/val=0.0247
# [FORMULA_B_POS step=1200] val_norm=6.3935 | ordering_norm=0.7796 | temp_norm=7.6919 | p_bar=0.1260 | ordering/val=0.1219
# 	iters: 200, epoch: 5 | loss: 0.2111039
# 	speed: 0.1980s/iter; left time: 61.9607s
# Epoch: 5 cost time: 50.685681104660034
# Epoch: 5, Steps: 256 | Train Loss: 0.2071128 Vali Loss: 1.3374507 Test Loss: 1.1637717
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# [FORMULA_B_POS step=1300] val_norm=28.2100 | ordering_norm=0.7617 | temp_norm=7.9243 | p_bar=0.1737 | ordering/val=0.0270
# [FORMULA_B_POS step=1300] val_norm=6.0474 | ordering_norm=0.7796 | temp_norm=7.7724 | p_bar=0.1260 | ordering/val=0.1289
# 	iters: 100, epoch: 6 | loss: 0.1949196
# 	speed: 0.4160s/iter; left time: 65.3133s
# [FORMULA_B_POS step=1400] val_norm=28.6510 | ordering_norm=0.7617 | temp_norm=7.9390 | p_bar=0.1737 | ordering/val=0.0266
# [FORMULA_B_POS step=1400] val_norm=6.0962 | ordering_norm=0.7796 | temp_norm=7.7559 | p_bar=0.1260 | ordering/val=0.1279
# 	iters: 200, epoch: 6 | loss: 0.2077847
# 	speed: 0.1998s/iter; left time: 11.3888s
# [FORMULA_B_POS step=1500] val_norm=29.2072 | ordering_norm=0.7617 | temp_norm=7.8641 | p_bar=0.1737 | ordering/val=0.0261
# [FORMULA_B_POS step=1500] val_norm=6.1053 | ordering_norm=0.7796 | temp_norm=7.7238 | p_bar=0.1260 | ordering/val=0.1277
# Epoch: 6 cost time: 51.01724076271057
# Epoch: 6, Steps: 256 | Train Loss: 0.2019676 Vali Loss: 1.3305433 Test Loss: 1.1477785
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred336_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.1496708393096924, mae:0.8536968231201172
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 06:44:39 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 5/12: formula_b_pos_ph2_ETTh1_pred48_seed2022
# pred_len=48 | seed=2022
# Start: Tue Aug 11 06:44:39 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred48_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred48_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# [FORMULA_B_POS step=0] val_norm=31.2205 | ordering_norm=0.7617 | temp_norm=7.6023 | p_bar=0.1737 | ordering/val=0.0244
# [FORMULA_B_POS step=0] val_norm=17.0385 | ordering_norm=0.7617 | temp_norm=7.6115 | p_bar=0.1737 | ordering/val=0.0447
# 	iters: 100, epoch: 1 | loss: 0.4731371
# 	speed: 0.0990s/iter; left time: 147.5715s
# [FORMULA_B_POS step=100] val_norm=29.9420 | ordering_norm=0.7617 | temp_norm=7.6558 | p_bar=0.1737 | ordering/val=0.0254
# [FORMULA_B_POS step=100] val_norm=16.2793 | ordering_norm=0.7617 | temp_norm=7.5358 | p_bar=0.1737 | ordering/val=0.0468
# 	iters: 200, epoch: 1 | loss: 0.2704013
# 	speed: 0.0828s/iter; left time: 115.1074s
# [FORMULA_B_POS step=200] val_norm=27.7795 | ordering_norm=0.7617 | temp_norm=7.6099 | p_bar=0.1737 | ordering/val=0.0274
# [FORMULA_B_POS step=200] val_norm=15.5684 | ordering_norm=0.7617 | temp_norm=7.5635 | p_bar=0.1737 | ordering/val=0.0489
# Epoch: 1 cost time: 22.383296251296997
# Epoch: 1, Steps: 265 | Train Loss: 0.3930518 Vali Loss: 0.8796051 Test Loss: 0.8566447
# Validation loss decreased (inf --> 0.879605).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=29.9572 | ordering_norm=0.7617 | temp_norm=7.6770 | p_bar=0.1737 | ordering/val=0.0254
# [FORMULA_B_POS step=300] val_norm=16.0321 | ordering_norm=0.7617 | temp_norm=7.5511 | p_bar=0.1737 | ordering/val=0.0475
# 	iters: 100, epoch: 2 | loss: 0.2568222
# 	speed: 0.2015s/iter; left time: 247.0615s
# [FORMULA_B_POS step=400] val_norm=30.8609 | ordering_norm=0.7617 | temp_norm=7.7923 | p_bar=0.1737 | ordering/val=0.0247
# [FORMULA_B_POS step=400] val_norm=16.8176 | ordering_norm=0.7617 | temp_norm=7.7141 | p_bar=0.1737 | ordering/val=0.0453
# 	iters: 200, epoch: 2 | loss: 0.2577113
# 	speed: 0.0900s/iter; left time: 101.2845s
# [FORMULA_B_POS step=500] val_norm=29.3488 | ordering_norm=0.7617 | temp_norm=7.6714 | p_bar=0.1737 | ordering/val=0.0260
# [FORMULA_B_POS step=500] val_norm=16.0650 | ordering_norm=0.7617 | temp_norm=7.5572 | p_bar=0.1737 | ordering/val=0.0474
# Epoch: 2 cost time: 23.689045429229736
# Epoch: 2, Steps: 265 | Train Loss: 0.2576951 Vali Loss: 0.9916247 Test Loss: 1.1515379
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=28.8519 | ordering_norm=0.7617 | temp_norm=7.7043 | p_bar=0.1737 | ordering/val=0.0264
# [FORMULA_B_POS step=600] val_norm=15.7538 | ordering_norm=0.7617 | temp_norm=7.5171 | p_bar=0.1737 | ordering/val=0.0484
# 	iters: 100, epoch: 3 | loss: 0.2119473
# 	speed: 0.1880s/iter; left time: 180.6374s
# [FORMULA_B_POS step=700] val_norm=30.1499 | ordering_norm=0.7617 | temp_norm=7.6697 | p_bar=0.1737 | ordering/val=0.0253
# [FORMULA_B_POS step=700] val_norm=16.8208 | ordering_norm=0.7617 | temp_norm=7.5125 | p_bar=0.1737 | ordering/val=0.0453
# 	iters: 200, epoch: 3 | loss: 0.2102782
# 	speed: 0.0810s/iter; left time: 69.6989s
# Epoch: 3 cost time: 21.51410722732544
# Epoch: 3, Steps: 265 | Train Loss: 0.2115796 Vali Loss: 0.9660692 Test Loss: 1.1160055
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=29.6621 | ordering_norm=0.7617 | temp_norm=7.6965 | p_bar=0.1737 | ordering/val=0.0257
# [FORMULA_B_POS step=800] val_norm=16.2667 | ordering_norm=0.7617 | temp_norm=7.5579 | p_bar=0.1737 | ordering/val=0.0468
# 	iters: 100, epoch: 4 | loss: 0.2025598
# 	speed: 0.1816s/iter; left time: 126.3708s
# [FORMULA_B_POS step=900] val_norm=28.3653 | ordering_norm=0.7617 | temp_norm=7.8371 | p_bar=0.1737 | ordering/val=0.0269
# [FORMULA_B_POS step=900] val_norm=15.3827 | ordering_norm=0.7617 | temp_norm=7.7042 | p_bar=0.1737 | ordering/val=0.0495
# 	iters: 200, epoch: 4 | loss: 0.1826777
# 	speed: 0.0813s/iter; left time: 48.4571s
# [FORMULA_B_POS step=1000] val_norm=30.7490 | ordering_norm=0.7617 | temp_norm=7.6317 | p_bar=0.1737 | ordering/val=0.0248
# [FORMULA_B_POS step=1000] val_norm=16.7174 | ordering_norm=0.7617 | temp_norm=7.4636 | p_bar=0.1737 | ordering/val=0.0456
# Epoch: 4 cost time: 21.51506280899048
# Epoch: 4, Steps: 265 | Train Loss: 0.1909620 Vali Loss: 1.0079367 Test Loss: 1.0559533
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred48_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.8566449284553528, mae:0.7472320199012756
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 06:46:48 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 6/12: formula_b_pos_ph2_ETTh1_pred96_seed2022
# pred_len=96 | seed=2022
# Start: Tue Aug 11 06:46:48 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred96_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred96_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [FORMULA_B_POS step=0] val_norm=28.2853 | ordering_norm=0.7617 | temp_norm=7.8306 | p_bar=0.1737 | ordering/val=0.0269
# [FORMULA_B_POS step=0] val_norm=11.9106 | ordering_norm=0.7660 | temp_norm=7.5434 | p_bar=0.1576 | ordering/val=0.0643
# 	iters: 100, epoch: 1 | loss: 0.4187529
# 	speed: 0.1155s/iter; left time: 171.5014s
# [FORMULA_B_POS step=100] val_norm=29.5381 | ordering_norm=0.7617 | temp_norm=7.8503 | p_bar=0.1737 | ordering/val=0.0258
# [FORMULA_B_POS step=100] val_norm=12.1366 | ordering_norm=0.7660 | temp_norm=7.4842 | p_bar=0.1576 | ordering/val=0.0631
# 	iters: 200, epoch: 1 | loss: 0.3482878
# 	speed: 0.1016s/iter; left time: 140.6560s
# [FORMULA_B_POS step=200] val_norm=30.6217 | ordering_norm=0.7617 | temp_norm=7.8007 | p_bar=0.1737 | ordering/val=0.0249
# [FORMULA_B_POS step=200] val_norm=12.6040 | ordering_norm=0.7660 | temp_norm=7.5134 | p_bar=0.1576 | ordering/val=0.0608
# Epoch: 1 cost time: 27.24787211418152
# Epoch: 1, Steps: 264 | Train Loss: 0.4056534 Vali Loss: 1.0112013 Test Loss: 1.0201861
# Validation loss decreased (inf --> 1.011201).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=30.6186 | ordering_norm=0.7617 | temp_norm=7.7213 | p_bar=0.1737 | ordering/val=0.0249
# [FORMULA_B_POS step=300] val_norm=12.3675 | ordering_norm=0.7660 | temp_norm=7.4526 | p_bar=0.1576 | ordering/val=0.0619
# 	iters: 100, epoch: 2 | loss: 0.2582499
# 	speed: 0.2467s/iter; left time: 301.2772s
# [FORMULA_B_POS step=400] val_norm=29.8830 | ordering_norm=0.7617 | temp_norm=7.8808 | p_bar=0.1737 | ordering/val=0.0255
# [FORMULA_B_POS step=400] val_norm=11.9799 | ordering_norm=0.7660 | temp_norm=7.5464 | p_bar=0.1576 | ordering/val=0.0639
# 	iters: 200, epoch: 2 | loss: 0.2449555
# 	speed: 0.1054s/iter; left time: 118.1868s
# [FORMULA_B_POS step=500] val_norm=29.3936 | ordering_norm=0.7617 | temp_norm=7.8179 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=500] val_norm=12.3375 | ordering_norm=0.7660 | temp_norm=7.5297 | p_bar=0.1576 | ordering/val=0.0621
# Epoch: 2 cost time: 28.04852795600891
# Epoch: 2, Steps: 264 | Train Loss: 0.2574149 Vali Loss: 1.0639532 Test Loss: 0.9904666
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=31.4428 | ordering_norm=0.7617 | temp_norm=7.7469 | p_bar=0.1737 | ordering/val=0.0242
# [FORMULA_B_POS step=600] val_norm=12.8245 | ordering_norm=0.7660 | temp_norm=7.5567 | p_bar=0.1576 | ordering/val=0.0597
# 	iters: 100, epoch: 3 | loss: 0.1990064
# 	speed: 0.2249s/iter; left time: 215.2267s
# [FORMULA_B_POS step=700] val_norm=27.4255 | ordering_norm=0.7617 | temp_norm=7.9764 | p_bar=0.1737 | ordering/val=0.0278
# [FORMULA_B_POS step=700] val_norm=11.2943 | ordering_norm=0.7660 | temp_norm=7.5949 | p_bar=0.1576 | ordering/val=0.0678
# 	iters: 200, epoch: 3 | loss: 0.2192994
# 	speed: 0.1002s/iter; left time: 85.8350s
# Epoch: 3 cost time: 26.46767258644104
# Epoch: 3, Steps: 264 | Train Loss: 0.2138551 Vali Loss: 1.0512406 Test Loss: 1.0149047
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=29.6149 | ordering_norm=0.7617 | temp_norm=7.8155 | p_bar=0.1737 | ordering/val=0.0257
# [FORMULA_B_POS step=800] val_norm=11.8696 | ordering_norm=0.7660 | temp_norm=7.4507 | p_bar=0.1576 | ordering/val=0.0645
# 	iters: 100, epoch: 4 | loss: 0.2023381
# 	speed: 0.2288s/iter; left time: 158.5402s
# [FORMULA_B_POS step=900] val_norm=30.4493 | ordering_norm=0.7617 | temp_norm=7.7873 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=900] val_norm=12.4789 | ordering_norm=0.7660 | temp_norm=7.5425 | p_bar=0.1576 | ordering/val=0.0614
# 	iters: 200, epoch: 4 | loss: 0.1976761
# 	speed: 0.1066s/iter; left time: 63.1932s
# [FORMULA_B_POS step=1000] val_norm=29.6680 | ordering_norm=0.7617 | temp_norm=7.8589 | p_bar=0.1737 | ordering/val=0.0257
# [FORMULA_B_POS step=1000] val_norm=12.0672 | ordering_norm=0.7660 | temp_norm=7.5386 | p_bar=0.1576 | ordering/val=0.0635
# Epoch: 4 cost time: 27.70344829559326
# Epoch: 4, Steps: 264 | Train Loss: 0.1949534 Vali Loss: 1.0786721 Test Loss: 1.0428501
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred96_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:1.020186185836792, mae:0.8236838579177856
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 06:49:23 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 7/12: formula_b_pos_ph2_ETTh1_pred192_seed2022
# pred_len=192 | seed=2022
# Start: Tue Aug 11 06:49:23 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred192_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred192_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_POS step=0] val_norm=29.9239 | ordering_norm=0.7617 | temp_norm=7.8299 | p_bar=0.1737 | ordering/val=0.0255
# [FORMULA_B_POS step=0] val_norm=8.2318 | ordering_norm=0.7727 | temp_norm=7.6881 | p_bar=0.1400 | ordering/val=0.0939
# 	iters: 100, epoch: 1 | loss: 0.4118265
# 	speed: 0.1485s/iter; left time: 217.8362s
# [FORMULA_B_POS step=100] val_norm=29.5228 | ordering_norm=0.7617 | temp_norm=7.8809 | p_bar=0.1737 | ordering/val=0.0258
# [FORMULA_B_POS step=100] val_norm=8.1259 | ordering_norm=0.7727 | temp_norm=7.7710 | p_bar=0.1400 | ordering/val=0.0951
# 	iters: 200, epoch: 1 | loss: 0.3379314
# 	speed: 0.1411s/iter; left time: 192.8591s
# [FORMULA_B_POS step=200] val_norm=27.9765 | ordering_norm=0.7617 | temp_norm=7.8551 | p_bar=0.1737 | ordering/val=0.0272
# [FORMULA_B_POS step=200] val_norm=7.5448 | ordering_norm=0.7727 | temp_norm=7.6833 | p_bar=0.1400 | ordering/val=0.1024
# Epoch: 1 cost time: 36.552337646484375
# Epoch: 1, Steps: 261 | Train Loss: 0.4158594 Vali Loss: 1.1598445 Test Loss: 1.0320628
# Validation loss decreased (inf --> 1.159845).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=29.3704 | ordering_norm=0.7617 | temp_norm=7.8804 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=300] val_norm=8.1266 | ordering_norm=0.7727 | temp_norm=7.7202 | p_bar=0.1400 | ordering/val=0.0951
# 	iters: 100, epoch: 2 | loss: 0.2831916
# 	speed: 0.3180s/iter; left time: 383.4753s
# [FORMULA_B_POS step=400] val_norm=31.0874 | ordering_norm=0.7617 | temp_norm=7.7485 | p_bar=0.1737 | ordering/val=0.0245
# [FORMULA_B_POS step=400] val_norm=8.4419 | ordering_norm=0.7727 | temp_norm=7.6579 | p_bar=0.1400 | ordering/val=0.0915
# 	iters: 200, epoch: 2 | loss: 0.2758388
# 	speed: 0.1362s/iter; left time: 150.6146s
# [FORMULA_B_POS step=500] val_norm=29.6879 | ordering_norm=0.7617 | temp_norm=7.8256 | p_bar=0.1737 | ordering/val=0.0257
# [FORMULA_B_POS step=500] val_norm=8.1178 | ordering_norm=0.7727 | temp_norm=7.7477 | p_bar=0.1400 | ordering/val=0.0952
# Epoch: 2 cost time: 35.89213943481445
# Epoch: 2, Steps: 261 | Train Loss: 0.2722968 Vali Loss: 1.2163987 Test Loss: 1.2098837
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=32.0207 | ordering_norm=0.7617 | temp_norm=7.8890 | p_bar=0.1737 | ordering/val=0.0238
# [FORMULA_B_POS step=600] val_norm=8.6331 | ordering_norm=0.7727 | temp_norm=7.7376 | p_bar=0.1400 | ordering/val=0.0895
# 	iters: 100, epoch: 3 | loss: 0.2293959
# 	speed: 0.2966s/iter; left time: 280.2419s
# [FORMULA_B_POS step=700] val_norm=30.8525 | ordering_norm=0.7617 | temp_norm=7.9104 | p_bar=0.1737 | ordering/val=0.0247
# [FORMULA_B_POS step=700] val_norm=8.2669 | ordering_norm=0.7727 | temp_norm=7.8489 | p_bar=0.1400 | ordering/val=0.0935
# 	iters: 200, epoch: 3 | loss: 0.2322952
# 	speed: 0.1399s/iter; left time: 118.2382s
# Epoch: 3 cost time: 36.284504890441895
# Epoch: 3, Steps: 261 | Train Loss: 0.2314023 Vali Loss: 1.2528280 Test Loss: 1.1685517
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=30.4070 | ordering_norm=0.7617 | temp_norm=7.7776 | p_bar=0.1737 | ordering/val=0.0251
# [FORMULA_B_POS step=800] val_norm=8.4283 | ordering_norm=0.7727 | temp_norm=7.6700 | p_bar=0.1400 | ordering/val=0.0917
# 	iters: 100, epoch: 4 | loss: 0.1986198
# 	speed: 0.3046s/iter; left time: 208.3656s
# [FORMULA_B_POS step=900] val_norm=28.5996 | ordering_norm=0.7617 | temp_norm=7.6577 | p_bar=0.1737 | ordering/val=0.0266
# [FORMULA_B_POS step=900] val_norm=7.8981 | ordering_norm=0.7727 | temp_norm=7.6245 | p_bar=0.1400 | ordering/val=0.0978
# 	iters: 200, epoch: 4 | loss: 0.2003663
# 	speed: 0.1390s/iter; left time: 81.1951s
# [FORMULA_B_POS step=1000] val_norm=29.2645 | ordering_norm=0.7617 | temp_norm=7.8932 | p_bar=0.1737 | ordering/val=0.0260
# [FORMULA_B_POS step=1000] val_norm=8.0221 | ordering_norm=0.7727 | temp_norm=7.7895 | p_bar=0.1400 | ordering/val=0.0963
# Epoch: 4 cost time: 36.25190305709839
# Epoch: 4, Steps: 261 | Train Loss: 0.2117491 Vali Loss: 1.2794096 Test Loss: 1.2137204
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred192_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:1.0320625305175781, mae:0.8047327995300293
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 06:52:41 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 8/12: formula_b_pos_ph2_ETTh1_pred336_seed2022
# pred_len=336 | seed=2022
# Start: Tue Aug 11 06:52:41 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred336_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred336_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [FORMULA_B_POS step=0] val_norm=30.9150 | ordering_norm=0.7617 | temp_norm=7.5157 | p_bar=0.1737 | ordering/val=0.0246
# [FORMULA_B_POS step=0] val_norm=6.4614 | ordering_norm=0.7796 | temp_norm=7.4845 | p_bar=0.1260 | ordering/val=0.1206
# 	iters: 100, epoch: 1 | loss: 0.3847411
# 	speed: 0.2081s/iter; left time: 298.9791s
# [FORMULA_B_POS step=100] val_norm=29.5460 | ordering_norm=0.7617 | temp_norm=7.5596 | p_bar=0.1737 | ordering/val=0.0258
# [FORMULA_B_POS step=100] val_norm=6.2683 | ordering_norm=0.7796 | temp_norm=7.4215 | p_bar=0.1260 | ordering/val=0.1244
# 	iters: 200, epoch: 1 | loss: 0.3200998
# 	speed: 0.2160s/iter; left time: 288.7329s
# [FORMULA_B_POS step=200] val_norm=29.5096 | ordering_norm=0.7617 | temp_norm=7.4323 | p_bar=0.1737 | ordering/val=0.0258
# [FORMULA_B_POS step=200] val_norm=6.2551 | ordering_norm=0.7796 | temp_norm=7.4115 | p_bar=0.1260 | ordering/val=0.1246
# Epoch: 1 cost time: 52.72105002403259
# Epoch: 1, Steps: 256 | Train Loss: 0.4238512 Vali Loss: 1.3047011 Test Loss: 0.9520895
# Validation loss decreased (inf --> 1.304701).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=30.4420 | ordering_norm=0.7617 | temp_norm=7.4765 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=300] val_norm=6.4697 | ordering_norm=0.7796 | temp_norm=7.4198 | p_bar=0.1260 | ordering/val=0.1205
# 	iters: 100, epoch: 2 | loss: 0.2715939
# 	speed: 0.4111s/iter; left time: 485.4895s
# [FORMULA_B_POS step=400] val_norm=29.7976 | ordering_norm=0.7617 | temp_norm=7.4671 | p_bar=0.1737 | ordering/val=0.0256
# [FORMULA_B_POS step=400] val_norm=6.3047 | ordering_norm=0.7796 | temp_norm=7.4234 | p_bar=0.1260 | ordering/val=0.1236
# 	iters: 200, epoch: 2 | loss: 0.2569195
# 	speed: 0.1981s/iter; left time: 214.1533s
# [FORMULA_B_POS step=500] val_norm=31.2322 | ordering_norm=0.7617 | temp_norm=7.4712 | p_bar=0.1737 | ordering/val=0.0244
# [FORMULA_B_POS step=500] val_norm=6.4472 | ordering_norm=0.7796 | temp_norm=7.4340 | p_bar=0.1260 | ordering/val=0.1209
# Epoch: 2 cost time: 50.25327396392822
# Epoch: 2, Steps: 256 | Train Loss: 0.2827116 Vali Loss: 1.3122489 Test Loss: 1.0761920
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=27.9651 | ordering_norm=0.7617 | temp_norm=7.4652 | p_bar=0.1737 | ordering/val=0.0272
# [FORMULA_B_POS step=600] val_norm=6.0458 | ordering_norm=0.7796 | temp_norm=7.4328 | p_bar=0.1260 | ordering/val=0.1289
# 	iters: 100, epoch: 3 | loss: 0.2199858
# 	speed: 0.4213s/iter; left time: 389.7200s
# [FORMULA_B_POS step=700] val_norm=30.6427 | ordering_norm=0.7617 | temp_norm=7.5304 | p_bar=0.1737 | ordering/val=0.0249
# [FORMULA_B_POS step=700] val_norm=6.3451 | ordering_norm=0.7796 | temp_norm=7.4915 | p_bar=0.1260 | ordering/val=0.1229
# 	iters: 200, epoch: 3 | loss: 0.2178658
# 	speed: 0.1974s/iter; left time: 162.8777s
# Epoch: 3 cost time: 50.84752798080444
# Epoch: 3, Steps: 256 | Train Loss: 0.2357975 Vali Loss: 1.3392124 Test Loss: 1.1731108
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# ...
# 	iters: 100, epoch: 3 | loss: 0.2194107
# 	speed: 0.2220s/iter; left time: 212.4167s
# [FORMULA_B_POS step=700] val_norm=28.3685 | ordering_norm=0.7617 | temp_norm=7.6183 | p_bar=0.1737 | ordering/val=0.0269
# [FORMULA_B_POS step=700] val_norm=11.4112 | ordering_norm=0.7660 | temp_norm=7.5301 | p_bar=0.1576 | ordering/val=0.0671
# 	iters: 200, epoch: 3 | loss: 0.2148557
# 	speed: 0.1001s/iter; left time: 85.8269s
# Epoch: 3 cost time: 26.33002281188965
# Epoch: 3, Steps: 264 | Train Loss: 0.2174828 Vali Loss: 1.0636598 Test Loss: 0.9660189
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=31.2893 | ordering_norm=0.7617 | temp_norm=7.5650 | p_bar=0.1737 | ordering/val=0.0243
# [FORMULA_B_POS step=800] val_norm=12.4286 | ordering_norm=0.7660 | temp_norm=7.4182 | p_bar=0.1576 | ordering/val=0.0616
# 	iters: 100, epoch: 4 | loss: 0.2082447
# 	speed: 0.2330s/iter; left time: 161.4712s
# [FORMULA_B_POS step=900] val_norm=29.2350 | ordering_norm=0.7617 | temp_norm=7.5165 | p_bar=0.1737 | ordering/val=0.0261
# [FORMULA_B_POS step=900] val_norm=11.5110 | ordering_norm=0.7660 | temp_norm=7.4397 | p_bar=0.1576 | ordering/val=0.0665
# 	iters: 200, epoch: 4 | loss: 0.1920454
# 	speed: 0.1063s/iter; left time: 63.0493s
# [FORMULA_B_POS step=1000] val_norm=28.2983 | ordering_norm=0.7617 | temp_norm=7.5717 | p_bar=0.1737 | ordering/val=0.0269
# [FORMULA_B_POS step=1000] val_norm=11.1144 | ordering_norm=0.7660 | temp_norm=7.4556 | p_bar=0.1576 | ordering/val=0.0689
# Epoch: 4 cost time: 27.96260404586792
# Epoch: 4, Steps: 264 | Train Loss: 0.1972977 Vali Loss: 1.0544924 Test Loss: 0.9671091
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred96_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.9476919770240784, mae:0.7859644293785095
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 07:01:51 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 11/12: formula_b_pos_ph2_ETTh1_pred192_seed2023
# pred_len=192 | seed=2023
# Start: Tue Aug 11 07:01:51 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred192_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred192_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_POS step=0] val_norm=29.3653 | ordering_norm=0.7617 | temp_norm=7.6846 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=0] val_norm=8.0391 | ordering_norm=0.7727 | temp_norm=7.5656 | p_bar=0.1400 | ordering/val=0.0961
# 	iters: 100, epoch: 1 | loss: 0.4513569
# 	speed: 0.1436s/iter; left time: 210.6971s
# [FORMULA_B_POS step=100] val_norm=30.3271 | ordering_norm=0.7617 | temp_norm=7.5879 | p_bar=0.1737 | ordering/val=0.0251
# [FORMULA_B_POS step=100] val_norm=8.5694 | ordering_norm=0.7727 | temp_norm=7.4594 | p_bar=0.1400 | ordering/val=0.0902
# 	iters: 200, epoch: 1 | loss: 0.3158043
# 	speed: 0.1383s/iter; left time: 189.0801s
# [FORMULA_B_POS step=200] val_norm=31.2918 | ordering_norm=0.7617 | temp_norm=7.6222 | p_bar=0.1737 | ordering/val=0.0243
# [FORMULA_B_POS step=200] val_norm=8.4312 | ordering_norm=0.7727 | temp_norm=7.5044 | p_bar=0.1400 | ordering/val=0.0916
# Epoch: 1 cost time: 36.01186943054199
# Epoch: 1, Steps: 261 | Train Loss: 0.4223596 Vali Loss: 1.1588104 Test Loss: 0.8984140
# Validation loss decreased (inf --> 1.158810).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=29.1762 | ordering_norm=0.7617 | temp_norm=7.6174 | p_bar=0.1737 | ordering/val=0.0261
# [FORMULA_B_POS step=300] val_norm=8.1005 | ordering_norm=0.7727 | temp_norm=7.5821 | p_bar=0.1400 | ordering/val=0.0954
# 	iters: 100, epoch: 2 | loss: 0.2822222
# 	speed: 0.3207s/iter; left time: 386.7428s
# [FORMULA_B_POS step=400] val_norm=28.3553 | ordering_norm=0.7617 | temp_norm=7.6231 | p_bar=0.1737 | ordering/val=0.0269
# [FORMULA_B_POS step=400] val_norm=7.8125 | ordering_norm=0.7727 | temp_norm=7.5112 | p_bar=0.1400 | ordering/val=0.0989
# 	iters: 200, epoch: 2 | loss: 0.2483631
# 	speed: 0.1380s/iter; left time: 152.5891s
# [FORMULA_B_POS step=500] val_norm=28.2205 | ordering_norm=0.7617 | temp_norm=7.6840 | p_bar=0.1737 | ordering/val=0.0270
# [FORMULA_B_POS step=500] val_norm=7.9149 | ordering_norm=0.7727 | temp_norm=7.5699 | p_bar=0.1400 | ordering/val=0.0976
# Epoch: 2 cost time: 36.45467162132263
# Epoch: 2, Steps: 261 | Train Loss: 0.2754130 Vali Loss: 1.2578614 Test Loss: 0.9944728
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=28.0923 | ordering_norm=0.7617 | temp_norm=7.6399 | p_bar=0.1737 | ordering/val=0.0271
# [FORMULA_B_POS step=600] val_norm=7.7191 | ordering_norm=0.7727 | temp_norm=7.5255 | p_bar=0.1400 | ordering/val=0.1001
# 	iters: 100, epoch: 3 | loss: 0.2354586
# 	speed: 0.2942s/iter; left time: 277.9829s
# [FORMULA_B_POS step=700] val_norm=29.0866 | ordering_norm=0.7617 | temp_norm=7.6991 | p_bar=0.1737 | ordering/val=0.0262
# [FORMULA_B_POS step=700] val_norm=8.1141 | ordering_norm=0.7727 | temp_norm=7.5655 | p_bar=0.1400 | ordering/val=0.0952
# 	iters: 200, epoch: 3 | loss: 0.2185898
# 	speed: 0.1385s/iter; left time: 117.0355s
# Epoch: 3 cost time: 35.926151752471924
# Epoch: 3, Steps: 261 | Train Loss: 0.2318655 Vali Loss: 1.2980545 Test Loss: 1.0087481
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=26.3631 | ordering_norm=0.7617 | temp_norm=7.6728 | p_bar=0.1737 | ordering/val=0.0289
# [FORMULA_B_POS step=800] val_norm=7.5457 | ordering_norm=0.7727 | temp_norm=7.5396 | p_bar=0.1400 | ordering/val=0.1024
# 	iters: 100, epoch: 4 | loss: 0.2057469
# 	speed: 0.3046s/iter; left time: 208.3676s
# [FORMULA_B_POS step=900] val_norm=30.4333 | ordering_norm=0.7617 | temp_norm=7.6559 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=900] val_norm=8.5568 | ordering_norm=0.7727 | temp_norm=7.5340 | p_bar=0.1400 | ordering/val=0.0903
# 	iters: 200, epoch: 4 | loss: 0.2185467
# 	speed: 0.1385s/iter; left time: 80.8637s
# [FORMULA_B_POS step=1000] val_norm=29.2089 | ordering_norm=0.7617 | temp_norm=7.6137 | p_bar=0.1737 | ordering/val=0.0261
# [FORMULA_B_POS step=1000] val_norm=8.0986 | ordering_norm=0.7727 | temp_norm=7.4621 | p_bar=0.1400 | ordering/val=0.0954
# Epoch: 4 cost time: 36.20044994354248
# Epoch: 4, Steps: 261 | Train Loss: 0.2127240 Vali Loss: 1.3017931 Test Loss: 1.0222867
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred192_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.8984142541885376, mae:0.7349221110343933
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 07:05:08 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 12/12: formula_b_pos_ph2_ETTh1_pred336_seed2023
# pred_len=336 | seed=2023
# Start: Tue Aug 11 07:05:08 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph2_ETTh1_pred336_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred336_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [FORMULA_B_POS step=0] val_norm=30.2789 | ordering_norm=0.7617 | temp_norm=7.4117 | p_bar=0.1737 | ordering/val=0.0252
# [FORMULA_B_POS step=0] val_norm=6.1518 | ordering_norm=0.7796 | temp_norm=7.6386 | p_bar=0.1260 | ordering/val=0.1267
# 	iters: 100, epoch: 1 | loss: 0.4432410
# 	speed: 0.2056s/iter; left time: 295.3808s
# [FORMULA_B_POS step=100] val_norm=30.7337 | ordering_norm=0.7617 | temp_norm=7.4014 | p_bar=0.1737 | ordering/val=0.0248
# [FORMULA_B_POS step=100] val_norm=6.2449 | ordering_norm=0.7796 | temp_norm=7.6044 | p_bar=0.1260 | ordering/val=0.1248
# 	iters: 200, epoch: 1 | loss: 0.3570398
# 	speed: 0.2095s/iter; left time: 280.0667s
# [FORMULA_B_POS step=200] val_norm=32.3596 | ordering_norm=0.7617 | temp_norm=7.4474 | p_bar=0.1737 | ordering/val=0.0235
# [FORMULA_B_POS step=200] val_norm=6.5269 | ordering_norm=0.7796 | temp_norm=7.6414 | p_bar=0.1260 | ordering/val=0.1194
# Epoch: 1 cost time: 52.26309299468994
# Epoch: 1, Steps: 256 | Train Loss: 0.4351776 Vali Loss: 1.3273723 Test Loss: 0.9728872
# Validation loss decreased (inf --> 1.327372).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=29.3716 | ordering_norm=0.7617 | temp_norm=7.4978 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=300] val_norm=6.0744 | ordering_norm=0.7796 | temp_norm=7.6162 | p_bar=0.1260 | ordering/val=0.1283
# 	iters: 100, epoch: 2 | loss: 0.2815551
# 	speed: 0.4236s/iter; left time: 500.2642s
# [FORMULA_B_POS step=400] val_norm=29.8271 | ordering_norm=0.7617 | temp_norm=7.4876 | p_bar=0.1737 | ordering/val=0.0255
# [FORMULA_B_POS step=400] val_norm=6.3882 | ordering_norm=0.7796 | temp_norm=7.6168 | p_bar=0.1260 | ordering/val=0.1220
# 	iters: 200, epoch: 2 | loss: 0.2658072
# 	speed: 0.1954s/iter; left time: 211.1940s
# [FORMULA_B_POS step=500] val_norm=31.9980 | ordering_norm=0.7617 | temp_norm=7.7143 | p_bar=0.1737 | ordering/val=0.0238
# [FORMULA_B_POS step=500] val_norm=6.4854 | ordering_norm=0.7796 | temp_norm=7.7102 | p_bar=0.1260 | ordering/val=0.1202
# Epoch: 2 cost time: 50.196051597595215
# Epoch: 2, Steps: 256 | Train Loss: 0.2885263 Vali Loss: 1.2994908 Test Loss: 1.0577563
# Validation loss decreased (1.327372 --> 1.299491).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=27.7154 | ordering_norm=0.7617 | temp_norm=7.5943 | p_bar=0.1737 | ordering/val=0.0275
# [FORMULA_B_POS step=600] val_norm=5.9647 | ordering_norm=0.7796 | temp_norm=7.6768 | p_bar=0.1260 | ordering/val=0.1307
# 	iters: 100, epoch: 3 | loss: 0.2334000
# 	speed: 0.4229s/iter; left time: 391.1670s
# [FORMULA_B_POS step=700] val_norm=27.9198 | ordering_norm=0.7617 | temp_norm=7.6694 | p_bar=0.1737 | ordering/val=0.0273
# [FORMULA_B_POS step=700] val_norm=5.9512 | ordering_norm=0.7796 | temp_norm=7.6689 | p_bar=0.1260 | ordering/val=0.1310
# 	iters: 200, epoch: 3 | loss: 0.2476758
# 	speed: 0.2016s/iter; left time: 166.3280s
# Epoch: 3 cost time: 51.510852575302124
# Epoch: 3, Steps: 256 | Train Loss: 0.2454117 Vali Loss: 1.3298582 Test Loss: 1.0983986
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=29.2703 | ordering_norm=0.7617 | temp_norm=7.5733 | p_bar=0.1737 | ordering/val=0.0260
# [FORMULA_B_POS step=800] val_norm=6.1497 | ordering_norm=0.7796 | temp_norm=7.6803 | p_bar=0.1260 | ordering/val=0.1268
# 	iters: 100, epoch: 4 | loss: 0.2254548
# 	speed: 0.4212s/iter; left time: 281.7618s
# [FORMULA_B_POS step=900] val_norm=29.0656 | ordering_norm=0.7617 | temp_norm=7.5372 | p_bar=0.1737 | ordering/val=0.0262
# [FORMULA_B_POS step=900] val_norm=6.1147 | ordering_norm=0.7796 | temp_norm=7.6216 | p_bar=0.1260 | ordering/val=0.1275
# 	iters: 200, epoch: 4 | loss: 0.2199741
# 	speed: 0.2010s/iter; left time: 114.3416s
# [FORMULA_B_POS step=1000] val_norm=28.1902 | ordering_norm=0.7617 | temp_norm=7.6166 | p_bar=0.1737 | ordering/val=0.0270
# [FORMULA_B_POS step=1000] val_norm=5.9976 | ordering_norm=0.7796 | temp_norm=7.7696 | p_bar=0.1260 | ordering/val=0.1300
# Epoch: 4 cost time: 51.42669415473938
# Epoch: 4, Steps: 256 | Train Loss: 0.2263892 Vali Loss: 1.3470672 Test Loss: 1.0681984
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# [FORMULA_B_POS step=1100] val_norm=29.9224 | ordering_norm=0.7617 | temp_norm=7.5625 | p_bar=0.1737 | ordering/val=0.0255
# [FORMULA_B_POS step=1100] val_norm=6.1330 | ordering_norm=0.7796 | temp_norm=7.7019 | p_bar=0.1260 | ordering/val=0.1271
# 	iters: 100, epoch: 5 | loss: 0.2290515
# 	speed: 0.4177s/iter; left time: 172.5295s
# [FORMULA_B_POS step=1200] val_norm=28.8691 | ordering_norm=0.7617 | temp_norm=7.5920 | p_bar=0.1737 | ordering/val=0.0264
# [FORMULA_B_POS step=1200] val_norm=6.0531 | ordering_norm=0.7796 | temp_norm=7.7062 | p_bar=0.1260 | ordering/val=0.1288
# 	iters: 200, epoch: 5 | loss: 0.2168888
# 	speed: 0.2008s/iter; left time: 62.8413s
# Epoch: 5 cost time: 51.2160804271698
# Epoch: 5, Steps: 256 | Train Loss: 0.2161076 Vali Loss: 1.3576045 Test Loss: 1.0698160
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph2_ETTh1_pred336_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.0577560663223267, mae:0.8225201964378357
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Tue Aug 11 07:10:40 AM UTC 2026
#
# ============================================================
#  PHASE 2 SUMMARY — Formula B (Positional Space)
#  Total: 12 | Completed: 12 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
# Seed  | PredLen | MSE      | MAE
# ------|---------|----------|----------
# 2021  | 48      | 0.7086886167526245 | 0.6460009217262268
# 2021  | 96      | 0.9209663271903992 | 0.7743777632713318
# 2021  | 192     | 1.1172220706939697 | 0.8468191027641296
# 2021  | 336     | 1.1496708393096924 | 0.8536968231201172
#
# 2022  | 48      | 0.8566449284553528 | 0.7472320199012756
# 2022  | 96      | 1.020186185836792 | 0.8236838579177856
# 2022  | 192     | 1.0320625305175781 | 0.8047327995300293
# 2022  | 336     | 0.9520891308784485 | 0.7916182279586792
#
# 2023  | 48      | 0.901191234588623 | 0.7550432682037354
# 2023  | 96      | 0.9476919770240784 | 0.7859644293785095
# 2023  | 192     | 0.8984142541885376 | 0.7349221110343933
# 2023  | 336     | 1.0577560663223267 | 0.8225201964378357
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0:
#  seed=2021 | pred=96  MSE=0.8683
#  seed=2021 | pred=192 MSE=0.8463  ← Phase 1 target
#
#  DECISION GUIDE:
#    Consistent improvement across all 3 seeds → result is robust
#    Improvement only at seed=2021             → Phase 1 was a fluke, investigate
#    Mixed results across pred_lens            → horizon-dependent, report range
#    Regression vs Phase 1 at all seeds        → implementation issue, debug
# ============================================================
# End: Tue Aug 11 07:10:40 AM UTC 2026
