# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

project_path = '/content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1'
os.chdir(project_path)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1

# %%
# !ls -la /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-pos/formula-B-pos-ph1.sh
# Out:
# -rw------- 1 root root 7763 Aug  5 11:14 /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-pos/formula-B-pos-ph1.sh

# %%
import os

# Set your Informer data directory
informer_path = f'{project_path}/Informer2020-original'
data_dir = f'{informer_path}/data/ETT'
os.makedirs(data_dir, exist_ok=True)

# File path
data_file = f'{data_dir}/ETTh1.csv'

# Download ETTh1 dataset
if not os.path.exists(data_file):
    print("Downloading ETTh1.csv...")
    os.system(
        f'wget -q "https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv" '
        f'-O "{data_file}"'
    )

# Verify
if os.path.exists(data_file):
    print(f"✅ Download successful: {data_file}")
else:
    print("❌ Download failed.")
# Out:
# ✅ Download successful: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/data/ETT/ETTh1.csv

# %%
# Fix np.Inf -> np.inf in tools.py (removed in NumPy 2.0)
tools_path = f'{project_path}/Informer2020-original/utils/tools.py'

with open(tools_path, 'r') as f:
    content = f.read()

content_fixed = content.replace('np.Inf', 'np.inf')

with open(tools_path, 'w') as f:
    f.write(content_fixed)

print("✅ Fixed np.Inf -> np.inf in utils/tools.py")
# Out:
# ✅ Fixed np.Inf -> np.inf in utils/tools.py

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-pos/formula-B-pos-ph1.sh
# Out:
# ============================================================
#  Formula B (Positional Space) — Phase 1: Legendre Global Mean Deviation
#  Date: Wed Aug  5 01:40:23 PM UTC 2026
# ------------------------------------------------------------
#  Formula:  X'_i = V_i + T_i + P_i + Ordering_i
#  Signal:   Ordering_i = (mu_p - P_i) / (p_bar + 1e-8)
#  pe_mode:  formula_b_pos
# ------------------------------------------------------------
#  Seed:       2021
#  Pred lens:  96, 192
#  Total runs: 2
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/2: formula_b_pos_ph1_ETTh1_pred96_seed2021
# Start: Wed Aug  5 01:40:29 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph1_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph1_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [FORMULA_B_POS step=0] val_norm=32.0545 | ordering_norm=0.7617 | temp_norm=7.5583 | p_bar=0.1737 | ordering/val=0.0238
# [FORMULA_B_POS step=0] val_norm=13.2074 | ordering_norm=0.7660 | temp_norm=7.6829 | p_bar=0.1576 | ordering/val=0.0580
# 	iters: 100, epoch: 1 | loss: 0.4073773
# 	speed: 0.1482s/iter; left time: 220.1390s
# [FORMULA_B_POS step=100] val_norm=30.4566 | ordering_norm=0.7617 | temp_norm=7.3793 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=100] val_norm=12.6934 | ordering_norm=0.7660 | temp_norm=7.5472 | p_bar=0.1576 | ordering/val=0.0603
# 	iters: 200, epoch: 1 | loss: 0.3034835
# 	speed: 0.0837s/iter; left time: 115.9289s
# [FORMULA_B_POS step=200] val_norm=27.9825 | ordering_norm=0.7617 | temp_norm=7.4933 | p_bar=0.1737 | ordering/val=0.0272
# [FORMULA_B_POS step=200] val_norm=11.7935 | ordering_norm=0.7660 | temp_norm=7.6715 | p_bar=0.1576 | ordering/val=0.0650
# Epoch: 1 cost time: 23.612860441207886
# Epoch: 1, Steps: 264 | Train Loss: 0.4146472 Vali Loss: 1.0140493 Test Loss: 0.8686856
# Validation loss decreased (inf --> 1.014049).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=30.7891 | ordering_norm=0.7617 | temp_norm=7.4489 | p_bar=0.1737 | ordering/val=0.0247
# [FORMULA_B_POS step=300] val_norm=12.7372 | ordering_norm=0.7660 | temp_norm=7.5644 | p_bar=0.1576 | ordering/val=0.0601
# 	iters: 100, epoch: 2 | loss: 0.2894295
# 	speed: 0.1912s/iter; left time: 233.4550s
# [FORMULA_B_POS step=400] val_norm=28.9470 | ordering_norm=0.7617 | temp_norm=7.4817 | p_bar=0.1737 | ordering/val=0.0263
# [FORMULA_B_POS step=400] val_norm=12.2496 | ordering_norm=0.7660 | temp_norm=7.5730 | p_bar=0.1576 | ordering/val=0.0625
# 	iters: 200, epoch: 2 | loss: 0.2385359
# 	speed: 0.0862s/iter; left time: 96.6012s
# [FORMULA_B_POS step=500] val_norm=29.7894 | ordering_norm=0.7617 | temp_norm=7.4671 | p_bar=0.1737 | ordering/val=0.0256
# [FORMULA_B_POS step=500] val_norm=12.2770 | ordering_norm=0.7660 | temp_norm=7.5326 | p_bar=0.1576 | ordering/val=0.0624
# Epoch: 2 cost time: 22.717103719711304
# Epoch: 2, Steps: 264 | Train Loss: 0.2622723 Vali Loss: 1.0225297 Test Loss: 1.0541961
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=28.0669 | ordering_norm=0.7617 | temp_norm=7.4710 | p_bar=0.1737 | ordering/val=0.0271
# [FORMULA_B_POS step=600] val_norm=11.9575 | ordering_norm=0.7660 | temp_norm=7.6098 | p_bar=0.1576 | ordering/val=0.0641
# 	iters: 100, epoch: 3 | loss: 0.2268226
# 	speed: 0.1952s/iter; left time: 186.7961s
# [FORMULA_B_POS step=700] val_norm=31.4117 | ordering_norm=0.7617 | temp_norm=7.5372 | p_bar=0.1737 | ordering/val=0.0242
# [FORMULA_B_POS step=700] val_norm=12.8503 | ordering_norm=0.7660 | temp_norm=7.6702 | p_bar=0.1576 | ordering/val=0.0596
# 	iters: 200, epoch: 3 | loss: 0.2202307
# 	speed: 0.0889s/iter; left time: 76.1534s
# Epoch: 3 cost time: 23.39442491531372
# Epoch: 3, Steps: 264 | Train Loss: 0.2198018 Vali Loss: 1.0588065 Test Loss: 1.0622134
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=29.4048 | ordering_norm=0.7617 | temp_norm=7.4867 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=800] val_norm=12.5691 | ordering_norm=0.7660 | temp_norm=7.6408 | p_bar=0.1576 | ordering/val=0.0609
# 	iters: 100, epoch: 4 | loss: 0.1976673
# 	speed: 0.2007s/iter; left time: 139.1054s
# [FORMULA_B_POS step=900] val_norm=29.0641 | ordering_norm=0.7617 | temp_norm=7.5155 | p_bar=0.1737 | ordering/val=0.0262
# [FORMULA_B_POS step=900] val_norm=12.2616 | ordering_norm=0.7660 | temp_norm=7.6083 | p_bar=0.1576 | ordering/val=0.0625
# 	iters: 200, epoch: 4 | loss: 0.1847005
# 	speed: 0.0911s/iter; left time: 54.0514s
# [FORMULA_B_POS step=1000] val_norm=29.9470 | ordering_norm=0.7617 | temp_norm=7.5184 | p_bar=0.1737 | ordering/val=0.0254
# [FORMULA_B_POS step=1000] val_norm=12.4685 | ordering_norm=0.7660 | temp_norm=7.6586 | p_bar=0.1576 | ordering/val=0.0614
# Epoch: 4 cost time: 24.01692008972168
# Epoch: 4, Steps: 264 | Train Loss: 0.2018319 Vali Loss: 1.0656250 Test Loss: 1.1307383
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph1_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8686856031417847, mae:0.7318677306175232
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:43:00 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/2: formula_b_pos_ph1_ETTh1_pred192_seed2021
# Start: Wed Aug  5 01:43:00 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_pos_ph1_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph1_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_POS step=0] val_norm=30.4365 | ordering_norm=0.7617 | temp_norm=7.4507 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=0] val_norm=8.3340 | ordering_norm=0.7727 | temp_norm=7.6314 | p_bar=0.1400 | ordering/val=0.0927
# 	iters: 100, epoch: 1 | loss: 0.3855225
# 	speed: 0.1335s/iter; left time: 195.9010s
# [FORMULA_B_POS step=100] val_norm=30.5123 | ordering_norm=0.7617 | temp_norm=7.4097 | p_bar=0.1737 | ordering/val=0.0250
# [FORMULA_B_POS step=100] val_norm=8.3780 | ordering_norm=0.7727 | temp_norm=7.5803 | p_bar=0.1400 | ordering/val=0.0922
# 	iters: 200, epoch: 1 | loss: 0.3308043
# 	speed: 0.1202s/iter; left time: 164.2779s
# [FORMULA_B_POS step=200] val_norm=29.4296 | ordering_norm=0.7617 | temp_norm=7.5226 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=200] val_norm=8.0954 | ordering_norm=0.7727 | temp_norm=7.6302 | p_bar=0.1400 | ordering/val=0.0954
# Epoch: 1 cost time: 31.6605064868927
# Epoch: 1, Steps: 261 | Train Loss: 0.4145280 Vali Loss: 1.2413789 Test Loss: 0.9443878
# Validation loss decreased (inf --> 1.241379).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_POS step=300] val_norm=31.6704 | ordering_norm=0.7617 | temp_norm=7.4892 | p_bar=0.1737 | ordering/val=0.0241
# [FORMULA_B_POS step=300] val_norm=8.4241 | ordering_norm=0.7727 | temp_norm=7.5611 | p_bar=0.1400 | ordering/val=0.0917
# 	iters: 100, epoch: 2 | loss: 0.2692087
# 	speed: 0.2654s/iter; left time: 320.1094s
# [FORMULA_B_POS step=400] val_norm=29.4589 | ordering_norm=0.7617 | temp_norm=7.5893 | p_bar=0.1737 | ordering/val=0.0259
# [FORMULA_B_POS step=400] val_norm=8.2804 | ordering_norm=0.7727 | temp_norm=7.6441 | p_bar=0.1400 | ordering/val=0.0933
# 	iters: 200, epoch: 2 | loss: 0.2565760
# 	speed: 0.1199s/iter; left time: 132.5854s
# [FORMULA_B_POS step=500] val_norm=29.3399 | ordering_norm=0.7617 | temp_norm=7.4815 | p_bar=0.1737 | ordering/val=0.0260
# [FORMULA_B_POS step=500] val_norm=8.2251 | ordering_norm=0.7727 | temp_norm=7.6587 | p_bar=0.1400 | ordering/val=0.0939
# Epoch: 2 cost time: 31.31469750404358
# Epoch: 2, Steps: 261 | Train Loss: 0.2701717 Vali Loss: 1.2330587 Test Loss: 0.9874746
# Validation loss decreased (1.241379 --> 1.233059).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_POS step=600] val_norm=30.1356 | ordering_norm=0.7617 | temp_norm=7.4156 | p_bar=0.1737 | ordering/val=0.0253
# [FORMULA_B_POS step=600] val_norm=8.2918 | ordering_norm=0.7727 | temp_norm=7.5158 | p_bar=0.1400 | ordering/val=0.0932
# 	iters: 100, epoch: 3 | loss: 0.2424693
# 	speed: 0.2609s/iter; left time: 246.5561s
# [FORMULA_B_POS step=700] val_norm=29.2322 | ordering_norm=0.7617 | temp_norm=7.4649 | p_bar=0.1737 | ordering/val=0.0261
# [FORMULA_B_POS step=700] val_norm=8.1496 | ordering_norm=0.7727 | temp_norm=7.6061 | p_bar=0.1400 | ordering/val=0.0948
# 	iters: 200, epoch: 3 | loss: 0.2159561
# 	speed: 0.1196s/iter; left time: 101.1008s
# Epoch: 3 cost time: 31.140751600265503
# Epoch: 3, Steps: 261 | Train Loss: 0.2266192 Vali Loss: 1.2768025 Test Loss: 1.0664446
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_POS step=800] val_norm=28.3915 | ordering_norm=0.7617 | temp_norm=7.4877 | p_bar=0.1737 | ordering/val=0.0268
# [FORMULA_B_POS step=800] val_norm=8.0545 | ordering_norm=0.7727 | temp_norm=7.6278 | p_bar=0.1400 | ordering/val=0.0959
# 	iters: 100, epoch: 4 | loss: 0.2017349
# 	speed: 0.2624s/iter; left time: 179.4567s
# [FORMULA_B_POS step=900] val_norm=29.3051 | ordering_norm=0.7617 | temp_norm=7.4752 | p_bar=0.1737 | ordering/val=0.0260
# [FORMULA_B_POS step=900] val_norm=8.1351 | ordering_norm=0.7727 | temp_norm=7.6126 | p_bar=0.1400 | ordering/val=0.0950
# 	iters: 200, epoch: 4 | loss: 0.2000673
# 	speed: 0.1203s/iter; left time: 70.2437s
# [FORMULA_B_POS step=1000] val_norm=30.1429 | ordering_norm=0.7617 | temp_norm=7.4729 | p_bar=0.1737 | ordering/val=0.0253
# [FORMULA_B_POS step=1000] val_norm=8.1677 | ordering_norm=0.7727 | temp_norm=7.5621 | p_bar=0.1400 | ordering/val=0.0946
# Epoch: 4 cost time: 31.37119698524475
# Epoch: 4, Steps: 261 | Train Loss: 0.2051823 Vali Loss: 1.2694641 Test Loss: 1.0262524
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# [FORMULA_B_POS step=1100] val_norm=28.1484 | ordering_norm=0.7617 | temp_norm=7.5826 | p_bar=0.1737 | ordering/val=0.0271
# [FORMULA_B_POS step=1100] val_norm=7.9227 | ordering_norm=0.7727 | temp_norm=7.7002 | p_bar=0.1400 | ordering/val=0.0975
# 	iters: 100, epoch: 5 | loss: 0.1971872
# 	speed: 0.2606s/iter; left time: 110.2489s
# [FORMULA_B_POS step=1200] val_norm=29.0378 | ordering_norm=0.7617 | temp_norm=7.4254 | p_bar=0.1737 | ordering/val=0.0262
# [FORMULA_B_POS step=1200] val_norm=8.0368 | ordering_norm=0.7727 | temp_norm=7.5738 | p_bar=0.1400 | ordering/val=0.0961
# 	iters: 200, epoch: 5 | loss: 0.1905783
# 	speed: 0.1198s/iter; left time: 38.6905s
# [FORMULA_B_POS step=1300] val_norm=29.0911 | ordering_norm=0.7617 | temp_norm=7.4477 | p_bar=0.1737 | ordering/val=0.0262
# [FORMULA_B_POS step=1300] val_norm=8.2493 | ordering_norm=0.7727 | temp_norm=7.6432 | p_bar=0.1400 | ordering/val=0.0937
# Epoch: 5 cost time: 31.17002034187317
# Epoch: 5, Steps: 261 | Train Loss: 0.1948888 Vali Loss: 1.2741810 Test Loss: 1.0745630
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_pos_ph1_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.9874743819236755, mae:0.7753885984420776
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:46:31 PM UTC 2026
#
# ============================================================
#  PHASE 1 SUMMARY — Formula B (Positional Space)
#  Total: 2 | Completed: 2 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
#  RUN_ID                                                         MSE        MAE
#  ------------------------------------------------------- ---------- ----------
#  formula_b_pos_ph1_ETTh1_pred96_seed2021                 0.8686856031417847 0.7318677306175232
#  formula_b_pos_ph1_ETTh1_pred192_seed2021                0.9874743819236755 0.7753885984420776
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0 (seed=2021):
#    pred=96  MSE=0.8683
#    pred=192 MSE=0.8463  ← target to beat
#
#  DECISION GUIDE:
#    Formula-B-pos wins BOTH vs Exp1-Pre → proceed to Phase 2
#    Formula-B-pos wins ONE  vs Exp1-Pre → Phase 2 to confirm
#    Formula-B-pos loses BOTH            → document, stop
# ============================================================
# End: Wed Aug  5 01:46:31 PM UTC 2026

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-B-pos/formula-B-pos-ph2.sh
# Out:
# ============================================================
#  Formula B (Semantic Space) — Phase 2: Global Mean Deviation
#  Date: Wed Aug  5 01:55:23 PM UTC 2026
# ------------------------------------------------------------
#  Formula:  X'_i = V_i + T_i + Ordering_i
#  Signal:   Ordering_i = (mu - V_i) / (x_bar + 1e-8)
#  pe_mode:  formula_b_sem
# ------------------------------------------------------------
#  Seeds:      2021, 2022, 2023
#  Pred lens:  48, 96, 192, 336
#  Total runs: 12
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/12: formula_b_sem_ph2_ETTh1_pred48_seed2021
# pred_len=48 | seed=2021
# Start: Wed Aug  5 01:55:25 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred48_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred48_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# [FORMULA_B_SEM step=0] val_norm=28.2852 | ordering_norm=0.6293 | temp_norm=7.6865 | x_bar=28.2852 | ordering/val=0.0222
# [FORMULA_B_SEM step=0] val_norm=16.2060 | ordering_norm=1.0089 | temp_norm=7.9995 | x_bar=16.2060 | ordering/val=0.0623
# 	iters: 100, epoch: 1 | loss: 0.3840056
# 	speed: 0.0921s/iter; left time: 137.3116s
# [FORMULA_B_SEM step=100] val_norm=29.2476 | ordering_norm=0.6378 | temp_norm=7.6814 | x_bar=29.2476 | ordering/val=0.0218
# [FORMULA_B_SEM step=100] val_norm=16.6177 | ordering_norm=1.0004 | temp_norm=7.9317 | x_bar=16.6177 | ordering/val=0.0602
# 	iters: 200, epoch: 1 | loss: 0.2993760
# 	speed: 0.0714s/iter; left time: 99.2503s
# [FORMULA_B_SEM step=200] val_norm=29.2526 | ordering_norm=0.6698 | temp_norm=7.6339 | x_bar=29.2526 | ordering/val=0.0229
# [FORMULA_B_SEM step=200] val_norm=16.4529 | ordering_norm=1.0178 | temp_norm=7.8483 | x_bar=16.4529 | ordering/val=0.0619
# Epoch: 1 cost time: 19.663705348968506
# Epoch: 1, Steps: 265 | Train Loss: 0.3940150 Vali Loss: 0.8359542 Test Loss: 0.9173709
# Validation loss decreased (inf --> 0.835954).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=28.5914 | ordering_norm=0.6304 | temp_norm=7.7121 | x_bar=28.5914 | ordering/val=0.0221
# [FORMULA_B_SEM step=300] val_norm=16.0240 | ordering_norm=1.0065 | temp_norm=7.9735 | x_bar=16.0240 | ordering/val=0.0628
# 	iters: 100, epoch: 2 | loss: 0.2510142
# 	speed: 0.1613s/iter; left time: 197.7167s
# [FORMULA_B_SEM step=400] val_norm=28.0233 | ordering_norm=0.6266 | temp_norm=7.5354 | x_bar=28.0233 | ordering/val=0.0224
# [FORMULA_B_SEM step=400] val_norm=15.4571 | ordering_norm=1.0034 | temp_norm=7.7687 | x_bar=15.4571 | ordering/val=0.0649
# 	iters: 200, epoch: 2 | loss: 0.2317015
# 	speed: 0.0730s/iter; left time: 82.2076s
# [FORMULA_B_SEM step=500] val_norm=29.1619 | ordering_norm=0.6664 | temp_norm=7.5789 | x_bar=29.1619 | ordering/val=0.0229
# [FORMULA_B_SEM step=500] val_norm=16.7416 | ordering_norm=1.0215 | temp_norm=7.8090 | x_bar=16.7416 | ordering/val=0.0610
# Epoch: 2 cost time: 19.30694603919983
# Epoch: 2, Steps: 265 | Train Loss: 0.2572340 Vali Loss: 0.9268662 Test Loss: 0.9840783
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=30.0033 | ordering_norm=0.6437 | temp_norm=7.6199 | x_bar=30.0033 | ordering/val=0.0215
# [FORMULA_B_SEM step=600] val_norm=16.3000 | ordering_norm=1.0106 | temp_norm=7.8532 | x_bar=16.3000 | ordering/val=0.0620
# 	iters: 100, epoch: 3 | loss: 0.2209669
# 	speed: 0.1635s/iter; left time: 157.1071s
# [FORMULA_B_SEM step=700] val_norm=27.4335 | ordering_norm=0.6361 | temp_norm=7.7584 | x_bar=27.4335 | ordering/val=0.0232
# [FORMULA_B_SEM step=700] val_norm=15.2861 | ordering_norm=1.0072 | temp_norm=8.0099 | x_bar=15.2861 | ordering/val=0.0659
# 	iters: 200, epoch: 3 | loss: 0.2039026
# 	speed: 0.0749s/iter; left time: 64.4680s
# Epoch: 3 cost time: 19.73478078842163
# Epoch: 3, Steps: 265 | Train Loss: 0.2096047 Vali Loss: 0.9640180 Test Loss: 0.9832850
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=29.3087 | ordering_norm=0.6376 | temp_norm=7.6771 | x_bar=29.3087 | ordering/val=0.0218
# [FORMULA_B_SEM step=800] val_norm=16.1734 | ordering_norm=1.0039 | temp_norm=7.8577 | x_bar=16.1734 | ordering/val=0.0621
# 	iters: 100, epoch: 4 | loss: 0.2029304
# 	speed: 0.1683s/iter; left time: 117.1160s
# [FORMULA_B_SEM step=900] val_norm=29.5286 | ordering_norm=0.6343 | temp_norm=7.5854 | x_bar=29.5286 | ordering/val=0.0215
# [FORMULA_B_SEM step=900] val_norm=16.5655 | ordering_norm=1.0103 | temp_norm=7.8431 | x_bar=16.5655 | ordering/val=0.0610
# 	iters: 200, epoch: 4 | loss: 0.1774423
# 	speed: 0.0771s/iter; left time: 45.9499s
# [FORMULA_B_SEM step=1000] val_norm=27.2361 | ordering_norm=0.6557 | temp_norm=7.6872 | x_bar=27.2361 | ordering/val=0.0241
# [FORMULA_B_SEM step=1000] val_norm=15.5211 | ordering_norm=1.0159 | temp_norm=7.8741 | x_bar=15.5211 | ordering/val=0.0655
# Epoch: 4 cost time: 20.352971076965332
# Epoch: 4, Steps: 265 | Train Loss: 0.1906170 Vali Loss: 1.0133709 Test Loss: 1.0814295
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred48_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.9173708558082581, mae:0.7697590589523315
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:57:09 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/12: formula_b_sem_ph2_ETTh1_pred96_seed2021
# pred_len=96 | seed=2021
# Start: Wed Aug  5 01:57:09 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [FORMULA_B_SEM step=0] val_norm=29.4750 | ordering_norm=0.6508 | temp_norm=7.5243 | x_bar=29.4750 | ordering/val=0.0221
# [FORMULA_B_SEM step=0] val_norm=11.6864 | ordering_norm=1.0941 | temp_norm=7.5688 | x_bar=11.6864 | ordering/val=0.0936
# 	iters: 100, epoch: 1 | loss: 0.5178099
# 	speed: 0.1080s/iter; left time: 160.3900s
# [FORMULA_B_SEM step=100] val_norm=29.4680 | ordering_norm=0.6338 | temp_norm=7.5354 | x_bar=29.4680 | ordering/val=0.0215
# [FORMULA_B_SEM step=100] val_norm=11.6729 | ordering_norm=1.0940 | temp_norm=7.5816 | x_bar=11.6729 | ordering/val=0.0937
# 	iters: 200, epoch: 1 | loss: 0.2951690
# 	speed: 0.0935s/iter; left time: 129.5485s
# [FORMULA_B_SEM step=200] val_norm=27.6382 | ordering_norm=0.6965 | temp_norm=7.5418 | x_bar=27.6382 | ordering/val=0.0252
# [FORMULA_B_SEM step=200] val_norm=11.2245 | ordering_norm=1.0819 | temp_norm=7.5998 | x_bar=11.2245 | ordering/val=0.0964
# Epoch: 1 cost time: 25.18362545967102
# Epoch: 1, Steps: 264 | Train Loss: 0.3956684 Vali Loss: 1.0108229 Test Loss: 0.7664974
# Validation loss decreased (inf --> 1.010823).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=29.1931 | ordering_norm=0.6276 | temp_norm=7.5343 | x_bar=29.1931 | ordering/val=0.0215
# [FORMULA_B_SEM step=300] val_norm=12.0877 | ordering_norm=1.1050 | temp_norm=7.6199 | x_bar=12.0877 | ordering/val=0.0914
# 	iters: 100, epoch: 2 | loss: 0.2597533
# 	speed: 0.2078s/iter; left time: 253.6929s
# [FORMULA_B_SEM step=400] val_norm=28.7752 | ordering_norm=0.6795 | temp_norm=7.6460 | x_bar=28.7752 | ordering/val=0.0236
# [FORMULA_B_SEM step=400] val_norm=11.6563 | ordering_norm=1.0975 | temp_norm=7.6182 | x_bar=11.6563 | ordering/val=0.0942
# 	iters: 200, epoch: 2 | loss: 0.2487656
# 	speed: 0.0930s/iter; left time: 104.2142s
# [FORMULA_B_SEM step=500] val_norm=30.2579 | ordering_norm=0.6174 | temp_norm=7.6312 | x_bar=30.2579 | ordering/val=0.0204
# [FORMULA_B_SEM step=500] val_norm=11.9730 | ordering_norm=1.1011 | temp_norm=7.6644 | x_bar=11.9730 | ordering/val=0.0920
# Epoch: 2 cost time: 24.533946990966797
# Epoch: 2, Steps: 264 | Train Loss: 0.2537372 Vali Loss: 1.0481068 Test Loss: 0.7910167
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=29.4766 | ordering_norm=0.6310 | temp_norm=7.5435 | x_bar=29.4766 | ordering/val=0.0214
# [FORMULA_B_SEM step=600] val_norm=11.6561 | ordering_norm=1.0959 | temp_norm=7.5455 | x_bar=11.6561 | ordering/val=0.0940
# 	iters: 100, epoch: 3 | loss: 0.2085454
# 	speed: 0.2053s/iter; left time: 196.4771s
# [FORMULA_B_SEM step=700] val_norm=28.8531 | ordering_norm=0.6450 | temp_norm=7.5147 | x_bar=28.8531 | ordering/val=0.0224
# [FORMULA_B_SEM step=700] val_norm=11.6042 | ordering_norm=1.0926 | temp_norm=7.5908 | x_bar=11.6042 | ordering/val=0.0942
# 	iters: 200, epoch: 3 | loss: 0.2044576
# 	speed: 0.0931s/iter; left time: 79.7578s
# Epoch: 3 cost time: 24.55089020729065
# Epoch: 3, Steps: 264 | Train Loss: 0.2132372 Vali Loss: 1.0652525 Test Loss: 0.8061237
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=28.4442 | ordering_norm=0.6370 | temp_norm=7.5728 | x_bar=28.4442 | ordering/val=0.0224
# [FORMULA_B_SEM step=800] val_norm=11.3824 | ordering_norm=1.0973 | temp_norm=7.6410 | x_bar=11.3824 | ordering/val=0.0964
# 	iters: 100, epoch: 4 | loss: 0.2016761
# 	speed: 0.2066s/iter; left time: 143.1585s
# [FORMULA_B_SEM step=900] val_norm=29.9387 | ordering_norm=0.6203 | temp_norm=7.7689 | x_bar=29.9387 | ordering/val=0.0207
# [FORMULA_B_SEM step=900] val_norm=11.9450 | ordering_norm=1.0992 | temp_norm=7.7335 | x_bar=11.9450 | ordering/val=0.0920
# 	iters: 200, epoch: 4 | loss: 0.1937909
# 	speed: 0.0935s/iter; left time: 55.4741s
# [FORMULA_B_SEM step=1000] val_norm=31.6647 | ordering_norm=0.5639 | temp_norm=7.6311 | x_bar=31.6647 | ordering/val=0.0178
# [FORMULA_B_SEM step=1000] val_norm=12.5690 | ordering_norm=1.1089 | temp_norm=7.6602 | x_bar=12.5690 | ordering/val=0.0882
# Epoch: 4 cost time: 24.652608633041382
# Epoch: 4, Steps: 264 | Train Loss: 0.1957229 Vali Loss: 1.0689377 Test Loss: 0.7942086
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.7664976119995117, mae:0.6805901527404785
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:59:18 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 3/12: formula_b_sem_ph2_ETTh1_pred192_seed2021
# pred_len=192 | seed=2021
# Start: Wed Aug  5 01:59:18 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_SEM step=0] val_norm=28.9984 | ordering_norm=0.6546 | temp_norm=7.7207 | x_bar=28.9984 | ordering/val=0.0226
# [FORMULA_B_SEM step=0] val_norm=8.1542 | ordering_norm=1.0557 | temp_norm=7.5879 | x_bar=8.1542 | ordering/val=0.1295
# 	iters: 100, epoch: 1 | loss: 0.4246799
# 	speed: 0.1363s/iter; left time: 199.9411s
# [FORMULA_B_SEM step=100] val_norm=27.1302 | ordering_norm=0.7188 | temp_norm=7.7751 | x_bar=27.1302 | ordering/val=0.0265
# [FORMULA_B_SEM step=100] val_norm=7.8004 | ordering_norm=1.0266 | temp_norm=7.5088 | x_bar=7.8004 | ordering/val=0.1316
# 	iters: 200, epoch: 1 | loss: 0.3444170
# 	speed: 0.1222s/iter; left time: 167.0031s
# [FORMULA_B_SEM step=200] val_norm=28.1984 | ordering_norm=0.6300 | temp_norm=7.7612 | x_bar=28.1984 | ordering/val=0.0223
# [FORMULA_B_SEM step=200] val_norm=8.1745 | ordering_norm=1.0561 | temp_norm=7.5747 | x_bar=8.1745 | ordering/val=0.1292
# Epoch: 1 cost time: 32.355934143066406
# Epoch: 1, Steps: 261 | Train Loss: 0.4227691 Vali Loss: 1.2429119 Test Loss: 1.0634998
# Validation loss decreased (inf --> 1.242912).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=30.4407 | ordering_norm=0.6084 | temp_norm=7.7774 | x_bar=30.4407 | ordering/val=0.0200
# [FORMULA_B_SEM step=300] val_norm=8.5409 | ordering_norm=1.0842 | temp_norm=7.6457 | x_bar=8.5409 | ordering/val=0.1269
# 	iters: 100, epoch: 2 | loss: 0.3037417
# 	speed: 0.2664s/iter; left time: 321.2605s
# [FORMULA_B_SEM step=400] val_norm=29.2894 | ordering_norm=0.6231 | temp_norm=7.8433 | x_bar=29.2894 | ordering/val=0.0213
# [FORMULA_B_SEM step=400] val_norm=8.1810 | ordering_norm=1.0618 | temp_norm=7.6979 | x_bar=8.1810 | ordering/val=0.1298
# 	iters: 200, epoch: 2 | loss: 0.2621237
# 	speed: 0.1216s/iter; left time: 134.5002s
# [FORMULA_B_SEM step=500] val_norm=28.8775 | ordering_norm=0.6429 | temp_norm=7.7499 | x_bar=28.8775 | ordering/val=0.0223
# [FORMULA_B_SEM step=500] val_norm=8.2174 | ordering_norm=1.0490 | temp_norm=7.6281 | x_bar=8.2174 | ordering/val=0.1277
# Epoch: 2 cost time: 31.66891622543335
# Epoch: 2, Steps: 261 | Train Loss: 0.2764159 Vali Loss: 1.1997272 Test Loss: 1.0379965
# Validation loss decreased (1.242912 --> 1.199727).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=29.9243 | ordering_norm=0.6428 | temp_norm=7.7196 | x_bar=29.9243 | ordering/val=0.0215
# [FORMULA_B_SEM step=600] val_norm=8.2972 | ordering_norm=1.0698 | temp_norm=7.5287 | x_bar=8.2972 | ordering/val=0.1289
# 	iters: 100, epoch: 3 | loss: 0.2326693
# 	speed: 0.2649s/iter; left time: 250.3230s
# [FORMULA_B_SEM step=700] val_norm=27.8446 | ordering_norm=0.6459 | temp_norm=7.8283 | x_bar=27.8446 | ordering/val=0.0232
# [FORMULA_B_SEM step=700] val_norm=8.1511 | ordering_norm=1.0669 | temp_norm=7.6473 | x_bar=8.1511 | ordering/val=0.1309
# 	iters: 200, epoch: 3 | loss: 0.2484392
# 	speed: 0.1218s/iter; left time: 102.9542s
# Epoch: 3 cost time: 31.7330801486969
# Epoch: 3, Steps: 261 | Train Loss: 0.2329842 Vali Loss: 1.2549120 Test Loss: 1.1776720
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=28.3517 | ordering_norm=0.6308 | temp_norm=7.8200 | x_bar=28.3517 | ordering/val=0.0222
# [FORMULA_B_SEM step=800] val_norm=8.1991 | ordering_norm=1.0536 | temp_norm=7.6194 | x_bar=8.1991 | ordering/val=0.1285
# 	iters: 100, epoch: 4 | loss: 0.2189004
# 	speed: 0.2645s/iter; left time: 180.8924s
# [FORMULA_B_SEM step=900] val_norm=30.1821 | ordering_norm=0.5943 | temp_norm=7.8409 | x_bar=30.1821 | ordering/val=0.0197
# [FORMULA_B_SEM step=900] val_norm=8.3895 | ordering_norm=1.0749 | temp_norm=7.6515 | x_bar=8.3895 | ordering/val=0.1281
# 	iters: 200, epoch: 4 | loss: 0.2142600
# 	speed: 0.1216s/iter; left time: 71.0053s
# [FORMULA_B_SEM step=1000] val_norm=26.5007 | ordering_norm=0.6930 | temp_norm=7.8434 | x_bar=26.5007 | ordering/val=0.0262
# [FORMULA_B_SEM step=1000] val_norm=7.7287 | ordering_norm=1.0235 | temp_norm=7.6499 | x_bar=7.7287 | ordering/val=0.1324
# Epoch: 4 cost time: 31.714691162109375
# Epoch: 4, Steps: 261 | Train Loss: 0.2132129 Vali Loss: 1.2590449 Test Loss: 1.1578817
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# [FORMULA_B_SEM step=1100] val_norm=27.5812 | ordering_norm=0.6452 | temp_norm=7.7989 | x_bar=27.5812 | ordering/val=0.0234
# [FORMULA_B_SEM step=1100] val_norm=8.0048 | ordering_norm=1.0553 | temp_norm=7.6487 | x_bar=8.0048 | ordering/val=0.1318
# 	iters: 100, epoch: 5 | loss: 0.2206939
# 	speed: 0.2639s/iter; left time: 111.6414s
# [FORMULA_B_SEM step=1200] val_norm=29.5188 | ordering_norm=0.6063 | temp_norm=7.7952 | x_bar=29.5188 | ordering/val=0.0205
# [FORMULA_B_SEM step=1200] val_norm=8.3168 | ordering_norm=1.0707 | temp_norm=7.6248 | x_bar=8.3168 | ordering/val=0.1287
# 	iters: 200, epoch: 5 | loss: 0.2054604
# 	speed: 0.1218s/iter; left time: 39.3258s
# [FORMULA_B_SEM step=1300] val_norm=28.6296 | ordering_norm=0.6311 | temp_norm=7.7184 | x_bar=28.6296 | ordering/val=0.0220
# [FORMULA_B_SEM step=1300] val_norm=8.1037 | ordering_norm=1.0586 | temp_norm=7.6011 | x_bar=8.1037 | ordering/val=0.1306
# Epoch: 5 cost time: 31.708955764770508
# Epoch: 5, Steps: 261 | Train Loss: 0.2041379 Vali Loss: 1.2946448 Test Loss: 1.1934366
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:1.0379962921142578, mae:0.8093645572662354
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 02:02:41 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 4/12: formula_b_sem_ph2_ETTh1_pred336_seed2021
# pred_len=336 | seed=2021
# Start: Wed Aug  5 02:02:41 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred336_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [FORMULA_B_SEM step=0] val_norm=31.1351 | ordering_norm=0.5790 | temp_norm=7.7020 | x_bar=31.1351 | ordering/val=0.0186
# [FORMULA_B_SEM step=0] val_norm=6.3956 | ordering_norm=0.9892 | temp_norm=7.6893 | x_bar=6.3956 | ordering/val=0.1547
# 	iters: 100, epoch: 1 | loss: 0.4182929
# 	speed: 0.1890s/iter; left time: 271.5786s
# [FORMULA_B_SEM step=100] val_norm=29.2121 | ordering_norm=0.6453 | temp_norm=7.7860 | x_bar=29.2121 | ordering/val=0.0221
# [FORMULA_B_SEM step=100] val_norm=6.0998 | ordering_norm=0.9418 | temp_norm=7.5763 | x_bar=6.0998 | ordering/val=0.1544
# 	iters: 200, epoch: 1 | loss: 0.3396415
# 	speed: 0.1774s/iter; left time: 237.1380s
# [FORMULA_B_SEM step=200] val_norm=28.7724 | ordering_norm=0.6403 | temp_norm=7.6651 | x_bar=28.7724 | ordering/val=0.0223
# [FORMULA_B_SEM step=200] val_norm=6.2088 | ordering_norm=0.9545 | temp_norm=7.5904 | x_bar=6.2088 | ordering/val=0.1537
# Epoch: 1 cost time: 45.48286747932434
# Epoch: 1, Steps: 256 | Train Loss: 0.4267705 Vali Loss: 1.3181070 Test Loss: 0.9877496
# Validation loss decreased (inf --> 1.318107).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=29.9280 | ordering_norm=0.6302 | temp_norm=7.8015 | x_bar=29.9280 | ordering/val=0.0211
# [FORMULA_B_SEM step=300] val_norm=6.2004 | ordering_norm=0.9658 | temp_norm=7.6826 | x_bar=6.2004 | ordering/val=0.1558
# 	iters: 100, epoch: 2 | loss: 0.2931288
# 	speed: 0.3654s/iter; left time: 431.5708s
# [FORMULA_B_SEM step=400] val_norm=28.4481 | ordering_norm=0.6930 | temp_norm=7.7081 | x_bar=28.4481 | ordering/val=0.0244
# [FORMULA_B_SEM step=400] val_norm=6.0270 | ordering_norm=0.9258 | temp_norm=7.6316 | x_bar=6.0270 | ordering/val=0.1536
# 	iters: 200, epoch: 2 | loss: 0.2641693
# 	speed: 0.1750s/iter; left time: 189.2041s
# [FORMULA_B_SEM step=500] val_norm=27.1929 | ordering_norm=0.6904 | temp_norm=7.7109 | x_bar=27.1929 | ordering/val=0.0254
# [FORMULA_B_SEM step=500] val_norm=5.9535 | ordering_norm=0.9293 | temp_norm=7.6837 | x_bar=5.9535 | ordering/val=0.1561
# Epoch: 2 cost time: 44.682084798812866
# Epoch: 2, Steps: 256 | Train Loss: 0.2833042 Vali Loss: 1.2902524 Test Loss: 1.0280448
# Validation loss decreased (1.318107 --> 1.290252).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=28.9017 | ordering_norm=0.6865 | temp_norm=7.7405 | x_bar=28.9017 | ordering/val=0.0238
# [FORMULA_B_SEM step=600] val_norm=6.0141 | ordering_norm=0.9405 | temp_norm=7.6583 | x_bar=6.0141 | ordering/val=0.1564
# 	iters: 100, epoch: 3 | loss: 0.2374737
# 	speed: 0.3662s/iter; left time: 338.7709s
# [FORMULA_B_SEM step=700] val_norm=28.6632 | ordering_norm=0.6194 | temp_norm=7.8468 | x_bar=28.6632 | ordering/val=0.0216
# [FORMULA_B_SEM step=700] val_norm=6.0988 | ordering_norm=0.9611 | temp_norm=7.6915 | x_bar=6.0988 | ordering/val=0.1576
# 	iters: 200, epoch: 3 | loss: 0.2370199
# 	speed: 0.1748s/iter; left time: 144.1918s
# Epoch: 3 cost time: 44.74582529067993
# Epoch: 3, Steps: 256 | Train Loss: 0.2375376 Vali Loss: 1.3517081 Test Loss: 1.1133039
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=28.8263 | ordering_norm=0.6400 | temp_norm=7.8036 | x_bar=28.8263 | ordering/val=0.0222
# [FORMULA_B_SEM step=800] val_norm=6.1099 | ordering_norm=0.9554 | temp_norm=7.7167 | x_bar=6.1099 | ordering/val=0.1564
# 	iters: 100, epoch: 4 | loss: 0.2284777
# 	speed: 0.3640s/iter; left time: 243.5291s
# [FORMULA_B_SEM step=900] val_norm=30.5866 | ordering_norm=0.6129 | temp_norm=7.6908 | x_bar=30.5866 | ordering/val=0.0200
# [FORMULA_B_SEM step=900] val_norm=6.2430 | ordering_norm=0.9662 | temp_norm=7.6136 | x_bar=6.2430 | ordering/val=0.1548
# 	iters: 200, epoch: 4 | loss: 0.2325245
# 	speed: 0.1755s/iter; left time: 99.8569s
# [FORMULA_B_SEM step=1000] val_norm=28.5687 | ordering_norm=0.6857 | temp_norm=7.7292 | x_bar=28.5687 | ordering/val=0.0240
# [FORMULA_B_SEM step=1000] val_norm=5.8818 | ordering_norm=0.9173 | temp_norm=7.6336 | x_bar=5.8818 | ordering/val=0.1560
# Epoch: 4 cost time: 44.798770904541016
# Epoch: 4, Steps: 256 | Train Loss: 0.2176942 Vali Loss: 1.3422253 Test Loss: 1.1149025
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# [FORMULA_B_SEM step=1100] val_norm=29.1272 | ordering_norm=0.5933 | temp_norm=7.7135 | x_bar=29.1272 | ordering/val=0.0204
# [FORMULA_B_SEM step=1100] val_norm=6.1683 | ordering_norm=0.9757 | temp_norm=7.6057 | x_bar=6.1683 | ordering/val=0.1582
# 	iters: 100, epoch: 5 | loss: 0.2127982
# 	speed: 0.3641s/iter; left time: 150.3744s
# [FORMULA_B_SEM step=1200] val_norm=28.3989 | ordering_norm=0.6083 | temp_norm=7.8622 | x_bar=28.3989 | ordering/val=0.0214
# [FORMULA_B_SEM step=1200] val_norm=6.0116 | ordering_norm=0.9492 | temp_norm=7.7855 | x_bar=6.0116 | ordering/val=0.1579
# 	iters: 200, epoch: 5 | loss: 0.2106515
# 	speed: 0.1751s/iter; left time: 54.8016s
# Epoch: 5 cost time: 44.74823832511902
# Epoch: 5, Steps: 256 | Train Loss: 0.2077969 Vali Loss: 1.3555729 Test Loss: 1.1335630
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.0280449390411377, mae:0.8228479027748108
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 02:07:21 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 5/12: formula_b_sem_ph2_ETTh1_pred48_seed2022
# pred_len=48 | seed=2022
# Start: Wed Aug  5 02:07:21 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred48_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred48_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# [FORMULA_B_SEM step=0] val_norm=28.4435 | ordering_norm=0.6506 | temp_norm=7.7937 | x_bar=28.4435 | ordering/val=0.0229
# [FORMULA_B_SEM step=0] val_norm=16.1110 | ordering_norm=1.0078 | temp_norm=7.6348 | x_bar=16.1110 | ordering/val=0.0626
# 	iters: 100, epoch: 1 | loss: 0.4367654
# 	speed: 0.0916s/iter; left time: 136.6335s
# [FORMULA_B_SEM step=100] val_norm=31.3271 | ordering_norm=0.5797 | temp_norm=7.6639 | x_bar=31.3271 | ordering/val=0.0185
# [FORMULA_B_SEM step=100] val_norm=17.8337 | ordering_norm=1.0018 | temp_norm=7.5189 | x_bar=17.8337 | ordering/val=0.0562
# 	iters: 200, epoch: 1 | loss: 0.3308046
# 	speed: 0.0773s/iter; left time: 107.4749s
# [FORMULA_B_SEM step=200] val_norm=28.7336 | ordering_norm=0.6589 | temp_norm=7.7352 | x_bar=28.7336 | ordering/val=0.0229
# [FORMULA_B_SEM step=200] val_norm=15.9666 | ordering_norm=1.0059 | temp_norm=7.6418 | x_bar=15.9666 | ordering/val=0.0630
# Epoch: 1 cost time: 20.965828895568848
# Epoch: 1, Steps: 265 | Train Loss: 0.4037468 Vali Loss: 0.8818946 Test Loss: 0.8116507
# Validation loss decreased (inf --> 0.881895).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=28.9608 | ordering_norm=0.6049 | temp_norm=7.6763 | x_bar=28.9608 | ordering/val=0.0209
# [FORMULA_B_SEM step=300] val_norm=15.7483 | ordering_norm=0.9933 | temp_norm=7.5860 | x_bar=15.7483 | ordering/val=0.0631
# 	iters: 100, epoch: 2 | loss: 0.2794745
# 	speed: 0.1752s/iter; left time: 214.7865s
# [FORMULA_B_SEM step=400] val_norm=30.5695 | ordering_norm=0.6249 | temp_norm=7.6748 | x_bar=30.5695 | ordering/val=0.0204
# [FORMULA_B_SEM step=400] val_norm=16.6630 | ordering_norm=1.0028 | temp_norm=7.5798 | x_bar=16.6630 | ordering/val=0.0602
# 	iters: 200, epoch: 2 | loss: 0.2374666
# 	speed: 0.0781s/iter; left time: 87.9262s
# [FORMULA_B_SEM step=500] val_norm=28.1364 | ordering_norm=0.6493 | temp_norm=7.7625 | x_bar=28.1364 | ordering/val=0.0231
# [FORMULA_B_SEM step=500] val_norm=15.7432 | ordering_norm=0.9998 | temp_norm=7.6258 | x_bar=15.7432 | ordering/val=0.0635
# Epoch: 2 cost time: 20.64309334754944
# Epoch: 2, Steps: 265 | Train Loss: 0.2623911 Vali Loss: 0.8478510 Test Loss: 0.9168707
# Validation loss decreased (0.881895 --> 0.847851).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=30.3922 | ordering_norm=0.6302 | temp_norm=7.7495 | x_bar=30.3922 | ordering/val=0.0207
# [FORMULA_B_SEM step=600] val_norm=17.0256 | ordering_norm=1.0065 | temp_norm=7.5661 | x_bar=17.0256 | ordering/val=0.0591
# 	iters: 100, epoch: 3 | loss: 0.2046496
# 	speed: 0.1736s/iter; left time: 166.7996s
# [FORMULA_B_SEM step=700] val_norm=29.0299 | ordering_norm=0.6306 | temp_norm=7.6830 | x_bar=29.0299 | ordering/val=0.0217
# [FORMULA_B_SEM step=700] val_norm=16.3268 | ordering_norm=1.0009 | temp_norm=7.5369 | x_bar=16.3268 | ordering/val=0.0613
# 	iters: 200, epoch: 3 | loss: 0.2059343
# 	speed: 0.0772s/iter; left time: 66.5023s
# Epoch: 3 cost time: 20.418850421905518
# Epoch: 3, Steps: 265 | Train Loss: 0.2160218 Vali Loss: 0.9186731 Test Loss: 1.0021949
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=28.5322 | ordering_norm=0.6664 | temp_norm=7.7841 | x_bar=28.5322 | ordering/val=0.0234
# [FORMULA_B_SEM step=800] val_norm=15.9035 | ordering_norm=1.0068 | temp_norm=7.7143 | x_bar=15.9035 | ordering/val=0.0633
# 	iters: 100, epoch: 4 | loss: 0.1823440
# 	speed: 0.1708s/iter; left time: 118.8675s
# [FORMULA_B_SEM step=900] val_norm=28.7313 | ordering_norm=0.6058 | temp_norm=7.8267 | x_bar=28.7313 | ordering/val=0.0211
# [FORMULA_B_SEM step=900] val_norm=16.2557 | ordering_norm=0.9986 | temp_norm=7.7240 | x_bar=16.2557 | ordering/val=0.0614
# 	iters: 200, epoch: 4 | loss: 0.2010941
# 	speed: 0.0772s/iter; left time: 46.0199s
# [FORMULA_B_SEM step=1000] val_norm=26.9561 | ordering_norm=0.6722 | temp_norm=7.7178 | x_bar=26.9561 | ordering/val=0.0249
# [FORMULA_B_SEM step=1000] val_norm=15.2227 | ordering_norm=1.0063 | temp_norm=7.5598 | x_bar=15.2227 | ordering/val=0.0661
# Epoch: 4 cost time: 20.447990655899048
# Epoch: 4, Steps: 265 | Train Loss: 0.1964592 Vali Loss: 0.9208631 Test Loss: 0.9726774
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# [FORMULA_B_SEM step=1100] val_norm=29.8865 | ordering_norm=0.6345 | temp_norm=7.8423 | x_bar=29.8865 | ordering/val=0.0212
# [FORMULA_B_SEM step=1100] val_norm=16.6498 | ordering_norm=1.0097 | temp_norm=7.7240 | x_bar=16.6498 | ordering/val=0.0606
# 	iters: 100, epoch: 5 | loss: 0.1688954
# 	speed: 0.1719s/iter; left time: 74.0824s
# [FORMULA_B_SEM step=1200] val_norm=28.9022 | ordering_norm=0.6320 | temp_norm=7.8132 | x_bar=28.9022 | ordering/val=0.0219
# [FORMULA_B_SEM step=1200] val_norm=16.1708 | ordering_norm=1.0059 | temp_norm=7.7446 | x_bar=16.1708 | ordering/val=0.0622
# 	iters: 200, epoch: 5 | loss: 0.1842346
# 	speed: 0.0776s/iter; left time: 25.6709s
# [FORMULA_B_SEM step=1300] val_norm=29.6972 | ordering_norm=0.6205 | temp_norm=7.6948 | x_bar=29.6972 | ordering/val=0.0209
# [FORMULA_B_SEM step=1300] val_norm=16.7610 | ordering_norm=1.0074 | temp_norm=7.6293 | x_bar=16.7610 | ordering/val=0.0601
# Epoch: 5 cost time: 20.515995025634766
# Epoch: 5, Steps: 265 | Train Loss: 0.1863698 Vali Loss: 0.9244443 Test Loss: 1.0130981
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred48_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.9168705344200134, mae:0.765535295009613
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 02:09:34 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 6/12: formula_b_sem_ph2_ETTh1_pred96_seed2022
# pred_len=96 | seed=2022
# Start: Wed Aug  5 02:09:34 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred96_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [FORMULA_B_SEM step=0] val_norm=29.9585 | ordering_norm=0.5885 | temp_norm=7.5932 | x_bar=29.9585 | ordering/val=0.0196
# [FORMULA_B_SEM step=0] val_norm=12.1779 | ordering_norm=1.1022 | temp_norm=7.5527 | x_bar=12.1779 | ordering/val=0.0905
# 	iters: 100, epoch: 1 | loss: 0.4311901
# 	speed: 0.1084s/iter; left time: 160.9365s
# [FORMULA_B_SEM step=100] val_norm=29.7781 | ordering_norm=0.6415 | temp_norm=7.7237 | x_bar=29.7781 | ordering/val=0.0215
# [FORMULA_B_SEM step=100] val_norm=12.0507 | ordering_norm=1.1026 | temp_norm=7.6293 | x_bar=12.0507 | ordering/val=0.0915
# 	iters: 200, epoch: 1 | loss: 0.3423380
# 	speed: 0.0932s/iter; left time: 129.1380s
# [FORMULA_B_SEM step=200] val_norm=28.4058 | ordering_norm=0.6612 | temp_norm=7.7214 | x_bar=28.4058 | ordering/val=0.0233
# [FORMULA_B_SEM step=200] val_norm=11.5445 | ordering_norm=1.0927 | temp_norm=7.6342 | x_bar=11.5445 | ordering/val=0.0947
# Epoch: 1 cost time: 25.172332048416138
# Epoch: 1, Steps: 264 | Train Loss: 0.4014388 Vali Loss: 0.9990498 Test Loss: 0.8043522
# Validation loss decreased (inf --> 0.999050).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=30.0738 | ordering_norm=0.6724 | temp_norm=7.7921 | x_bar=30.0738 | ordering/val=0.0224
# [FORMULA_B_SEM step=300] val_norm=12.1646 | ordering_norm=1.1081 | temp_norm=7.6647 | x_bar=12.1646 | ordering/val=0.0911
# 	iters: 100, epoch: 2 | loss: 0.2583397
# 	speed: 0.2093s/iter; left time: 255.5813s
# [FORMULA_B_SEM step=400] val_norm=28.6588 | ordering_norm=0.6252 | temp_norm=7.5955 | x_bar=28.6588 | ordering/val=0.0218
# [FORMULA_B_SEM step=400] val_norm=11.3554 | ordering_norm=1.0907 | temp_norm=7.5486 | x_bar=11.3554 | ordering/val=0.0960
# 	iters: 200, epoch: 2 | loss: 0.2335460
# 	speed: 0.0936s/iter; left time: 104.9767s
# [FORMULA_B_SEM step=500] val_norm=31.1709 | ordering_norm=0.6337 | temp_norm=7.7084 | x_bar=31.1709 | ordering/val=0.0203
# [FORMULA_B_SEM step=500] val_norm=12.6038 | ordering_norm=1.1032 | temp_norm=7.6479 | x_bar=12.6038 | ordering/val=0.0875
# Epoch: 2 cost time: 24.663111686706543
# Epoch: 2, Steps: 264 | Train Loss: 0.2551960 Vali Loss: 1.0320272 Test Loss: 0.8674389
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=30.3244 | ordering_norm=0.6328 | temp_norm=7.6307 | x_bar=30.3245 | ordering/val=0.0209
# [FORMULA_B_SEM step=600] val_norm=12.2479 | ordering_norm=1.1004 | temp_norm=7.5748 | x_bar=12.2479 | ordering/val=0.0898
# 	iters: 100, epoch: 3 | loss: 0.2214608
# 	speed: 0.2057s/iter; left time: 196.9001s
# [FORMULA_B_SEM step=700] val_norm=29.6207 | ordering_norm=0.6642 | temp_norm=7.6123 | x_bar=29.6207 | ordering/val=0.0224
# [FORMULA_B_SEM step=700] val_norm=11.8940 | ordering_norm=1.0986 | temp_norm=7.5305 | x_bar=11.8940 | ordering/val=0.0924
# 	iters: 200, epoch: 3 | loss: 0.2081754
# 	speed: 0.0932s/iter; left time: 79.8640s
# Epoch: 3 cost time: 24.528552532196045
# Epoch: 3, Steps: 264 | Train Loss: 0.2115167 Vali Loss: 1.0472885 Test Loss: 0.8983958
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=28.4423 | ordering_norm=0.6825 | temp_norm=7.7433 | x_bar=28.4423 | ordering/val=0.0240
# [FORMULA_B_SEM step=800] val_norm=11.6860 | ordering_norm=1.0861 | temp_norm=7.6230 | x_bar=11.6860 | ordering/val=0.0929
# 	iters: 100, epoch: 4 | loss: 0.1839801
# 	speed: 0.2063s/iter; left time: 142.9900s
# [FORMULA_B_SEM step=900] val_norm=29.2322 | ordering_norm=0.6588 | temp_norm=7.6833 | x_bar=29.2322 | ordering/val=0.0225
# [FORMULA_B_SEM step=900] val_norm=11.9486 | ordering_norm=1.0981 | temp_norm=7.5968 | x_bar=11.9486 | ordering/val=0.0919
# 	iters: 200, epoch: 4 | loss: 0.1869348
# 	speed: 0.0934s/iter; left time: 55.4119s
# [FORMULA_B_SEM step=1000] val_norm=28.1698 | ordering_norm=0.6172 | temp_norm=7.7114 | x_bar=28.1698 | ordering/val=0.0219
# [FORMULA_B_SEM step=1000] val_norm=11.4769 | ordering_norm=1.0952 | temp_norm=7.6372 | x_bar=11.4769 | ordering/val=0.0954
# Epoch: 4 cost time: 24.58964467048645
# Epoch: 4, Steps: 264 | Train Loss: 0.1930070 Vali Loss: 1.0930383 Test Loss: 0.9020157
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8043519854545593, mae:0.7114629149436951
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 02:11:42 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 7/12: formula_b_sem_ph2_ETTh1_pred192_seed2022
# pred_len=192 | seed=2022
# Start: Wed Aug  5 02:11:42 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred192_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_SEM step=0] val_norm=30.8926 | ordering_norm=0.6481 | temp_norm=7.6659 | x_bar=30.8926 | ordering/val=0.0210
# [FORMULA_B_SEM step=0] val_norm=8.4694 | ordering_norm=1.0842 | temp_norm=7.5374 | x_bar=8.4694 | ordering/val=0.1280
# 	iters: 100, epoch: 1 | loss: 0.4134731
# 	speed: 0.1373s/iter; left time: 201.4545s
# [FORMULA_B_SEM step=100] val_norm=28.7711 | ordering_norm=0.6193 | temp_norm=7.6489 | x_bar=28.7711 | ordering/val=0.0215
# [FORMULA_B_SEM step=100] val_norm=7.8942 | ordering_norm=1.0769 | temp_norm=7.7016 | x_bar=7.8942 | ordering/val=0.1364
# 	iters: 200, epoch: 1 | loss: 0.3570112
# 	speed: 0.1221s/iter; left time: 166.8582s
# [FORMULA_B_SEM step=200] val_norm=30.0200 | ordering_norm=0.5980 | temp_norm=7.6809 | x_bar=30.0200 | ordering/val=0.0199
# [FORMULA_B_SEM step=200] val_norm=8.1441 | ordering_norm=1.0781 | temp_norm=7.5868 | x_bar=8.1441 | ordering/val=0.1324
# Epoch: 1 cost time: 32.39073348045349
# Epoch: 1, Steps: 261 | Train Loss: 0.4176895 Vali Loss: 1.1799966 Test Loss: 0.8547503
# Validation loss decreased (inf --> 1.179997).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=29.5723 | ordering_norm=0.6497 | temp_norm=7.6569 | x_bar=29.5723 | ordering/val=0.0220
# [FORMULA_B_SEM step=300] val_norm=8.0462 | ordering_norm=1.0720 | temp_norm=7.5946 | x_bar=8.0462 | ordering/val=0.1332
# 	iters: 100, epoch: 2 | loss: 0.2757786
# 	speed: 0.2656s/iter; left time: 320.3693s
# [FORMULA_B_SEM step=400] val_norm=29.6634 | ordering_norm=0.6573 | temp_norm=7.6998 | x_bar=29.6634 | ordering/val=0.0222
# [FORMULA_B_SEM step=400] val_norm=8.1907 | ordering_norm=1.0682 | temp_norm=7.5528 | x_bar=8.1907 | ordering/val=0.1304
# 	iters: 200, epoch: 2 | loss: 0.2492198
# 	speed: 0.1216s/iter; left time: 134.4934s
# [FORMULA_B_SEM step=500] val_norm=28.8098 | ordering_norm=0.6937 | temp_norm=7.6039 | x_bar=28.8098 | ordering/val=0.0241
# [FORMULA_B_SEM step=500] val_norm=7.7319 | ordering_norm=1.0388 | temp_norm=7.5814 | x_bar=7.7319 | ordering/val=0.1344
# Epoch: 2 cost time: 31.697837352752686
# Epoch: 2, Steps: 261 | Train Loss: 0.2741401 Vali Loss: 1.2804462 Test Loss: 0.9810404
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=28.9946 | ordering_norm=0.6362 | temp_norm=7.6321 | x_bar=28.9946 | ordering/val=0.0219
# [FORMULA_B_SEM step=600] val_norm=8.0234 | ordering_norm=1.0765 | temp_norm=7.5424 | x_bar=8.0234 | ordering/val=0.1342
# 	iters: 100, epoch: 3 | loss: 0.2293451
# 	speed: 0.2639s/iter; left time: 249.3928s
# [FORMULA_B_SEM step=700] val_norm=31.0139 | ordering_norm=0.5991 | temp_norm=7.7624 | x_bar=31.0139 | ordering/val=0.0193
# [FORMULA_B_SEM step=700] val_norm=8.2454 | ordering_norm=1.0912 | temp_norm=7.6540 | x_bar=8.2454 | ordering/val=0.1323
# 	iters: 200, epoch: 3 | loss: 0.2066578
# 	speed: 0.1218s/iter; left time: 102.9158s
# Epoch: 3 cost time: 31.721348524093628
# Epoch: 3, Steps: 261 | Train Loss: 0.2280635 Vali Loss: 1.2448809 Test Loss: 0.9454448
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=31.5920 | ordering_norm=0.6390 | temp_norm=7.6399 | x_bar=31.5920 | ordering/val=0.0202
# [FORMULA_B_SEM step=800] val_norm=8.5462 | ordering_norm=1.0943 | temp_norm=7.6156 | x_bar=8.5462 | ordering/val=0.1280
# 	iters: 100, epoch: 4 | loss: 0.2077114
# 	speed: 0.2641s/iter; left time: 180.6143s
# [FORMULA_B_SEM step=900] val_norm=30.5119 | ordering_norm=0.6072 | temp_norm=7.6607 | x_bar=30.5119 | ordering/val=0.0199
# [FORMULA_B_SEM step=900] val_norm=8.2965 | ordering_norm=1.1020 | temp_norm=7.6554 | x_bar=8.2965 | ordering/val=0.1328
# 	iters: 200, epoch: 4 | loss: 0.2140036
# 	speed: 0.1218s/iter; left time: 71.1325s
# [FORMULA_B_SEM step=1000] val_norm=28.7928 | ordering_norm=0.6558 | temp_norm=7.7096 | x_bar=28.7928 | ordering/val=0.0228
# [FORMULA_B_SEM step=1000] val_norm=7.8333 | ordering_norm=1.0509 | temp_norm=7.6119 | x_bar=7.8333 | ordering/val=0.1342
# Epoch: 4 cost time: 31.71034336090088
# Epoch: 4, Steps: 261 | Train Loss: 0.2090239 Vali Loss: 1.2468908 Test Loss: 0.9511650
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.8547497987747192, mae:0.7293984293937683
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 02:14:26 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 8/12: formula_b_sem_ph2_ETTh1_pred336_seed2022
# pred_len=336 | seed=2022
# Start: Wed Aug  5 02:14:26 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred336_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [FORMULA_B_SEM step=0] val_norm=28.5223 | ordering_norm=0.6314 | temp_norm=7.6136 | x_bar=28.5223 | ordering/val=0.0221
# [FORMULA_B_SEM step=0] val_norm=6.1073 | ordering_norm=0.9412 | temp_norm=7.8764 | x_bar=6.1073 | ordering/val=0.1541
# 	iters: 100, epoch: 1 | loss: 0.4340872
# 	speed: 0.1891s/iter; left time: 271.7078s
# [FORMULA_B_SEM step=100] val_norm=27.6091 | ordering_norm=0.6846 | temp_norm=7.6110 | x_bar=27.6091 | ordering/val=0.0248
# [FORMULA_B_SEM step=100] val_norm=6.0294 | ordering_norm=0.9175 | temp_norm=7.8394 | x_bar=6.0294 | ordering/val=0.1522
# 	iters: 200, epoch: 1 | loss: 0.3733856
# 	speed: 0.1769s/iter; left time: 236.4608s
# [FORMULA_B_SEM step=200] val_norm=30.0738 | ordering_norm=0.5880 | temp_norm=7.6115 | x_bar=30.0738 | ordering/val=0.0196
# [FORMULA_B_SEM step=200] val_norm=6.3065 | ordering_norm=0.9631 | temp_norm=7.8305 | x_bar=6.3065 | ordering/val=0.1527
# Epoch: 1 cost time: 45.4037561416626
# Epoch: 1, Steps: 256 | Train Loss: 0.4307893 Vali Loss: 1.3177269 Test Loss: 0.8943519
# Validation loss decreased (inf --> 1.317727).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=29.3137 | ordering_norm=0.7109 | temp_norm=7.5049 | x_bar=29.3137 | ordering/val=0.0243
# [FORMULA_B_SEM step=300] val_norm=6.2137 | ordering_norm=0.9278 | temp_norm=7.8120 | x_bar=6.2137 | ordering/val=0.1493
# 	iters: 100, epoch: 2 | loss: 0.2856270
# 	speed: 0.3654s/iter; left time: 431.5091s
# [FORMULA_B_SEM step=400] val_norm=29.5340 | ordering_norm=0.6242 | temp_norm=7.5756 | x_bar=29.5340 | ordering/val=0.0211
# [FORMULA_B_SEM step=400] val_norm=6.3126 | ordering_norm=0.9670 | temp_norm=7.9235 | x_bar=6.3126 | ordering/val=0.1532
# 	iters: 200, epoch: 2 | loss: 0.2619804
# 	speed: 0.1752s/iter; left time: 189.3978s
# [FORMULA_B_SEM step=500] val_norm=28.1424 | ordering_norm=0.6562 | temp_norm=7.5597 | x_bar=28.1424 | ordering/val=0.0233
# [FORMULA_B_SEM step=500] val_norm=6.0779 | ordering_norm=0.9351 | temp_norm=7.8705 | x_bar=6.0779 | ordering/val=0.1539
# Epoch: 2 cost time: 44.708691358566284
# Epoch: 2, Steps: 256 | Train Loss: 0.2868911 Vali Loss: 1.3692602 Test Loss: 1.0250511
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=27.7534 | ordering_norm=0.6731 | temp_norm=7.5426 | x_bar=27.7534 | ordering/val=0.0243
# [FORMULA_B_SEM step=600] val_norm=6.0253 | ordering_norm=0.9203 | temp_norm=7.8634 | x_bar=6.0253 | ordering/val=0.1527
# 	iters: 100, epoch: 3 | loss: 0.2540893
# 	speed: 0.3645s/iter; left time: 337.1572s
# [FORMULA_B_SEM step=700] val_norm=28.2366 | ordering_norm=0.6772 | temp_norm=7.5249 | x_bar=28.2366 | ordering/val=0.0240
# [FORMULA_B_SEM step=700] val_norm=6.0282 | ordering_norm=0.9234 | temp_norm=7.8753 | x_bar=6.0282 | ordering/val=0.1532
# 	iters: 200, epoch: 3 | loss: 0.2364742
# 	speed: 0.1751s/iter; left time: 144.4376s
# Epoch: 3 cost time: 44.72338676452637
# Epoch: 3, Steps: 256 | Train Loss: 0.2412769 Vali Loss: 1.3512926 Test Loss: 1.0948566
# ...
# 	iters: 100, epoch: 3 | loss: 0.2139343
# 	speed: 0.2053s/iter; left time: 196.4655s
# [FORMULA_B_SEM step=700] val_norm=31.6052 | ordering_norm=0.5883 | temp_norm=7.6661 | x_bar=31.6052 | ordering/val=0.0186
# [FORMULA_B_SEM step=700] val_norm=12.6205 | ordering_norm=1.1171 | temp_norm=7.4908 | x_bar=12.6205 | ordering/val=0.0885
# 	iters: 200, epoch: 3 | loss: 0.2138446
# 	speed: 0.0930s/iter; left time: 79.6769s
# Epoch: 3 cost time: 24.487070083618164
# Epoch: 3, Steps: 264 | Train Loss: 0.2155795 Vali Loss: 1.0732875 Test Loss: 0.9739470
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=28.6793 | ordering_norm=0.6255 | temp_norm=7.5529 | x_bar=28.6793 | ordering/val=0.0218
# [FORMULA_B_SEM step=800] val_norm=11.9115 | ordering_norm=1.1104 | temp_norm=7.5209 | x_bar=11.9115 | ordering/val=0.0932
# 	iters: 100, epoch: 4 | loss: 0.1895941
# 	speed: 0.2061s/iter; left time: 142.7989s
# [FORMULA_B_SEM step=900] val_norm=30.4463 | ordering_norm=0.6413 | temp_norm=7.6231 | x_bar=30.4463 | ordering/val=0.0211
# [FORMULA_B_SEM step=900] val_norm=12.0598 | ordering_norm=1.1038 | temp_norm=7.5634 | x_bar=12.0598 | ordering/val=0.0915
# 	iters: 200, epoch: 4 | loss: 0.1916599
# 	speed: 0.0933s/iter; left time: 55.3534s
# [FORMULA_B_SEM step=1000] val_norm=30.1430 | ordering_norm=0.6152 | temp_norm=7.6342 | x_bar=30.1430 | ordering/val=0.0204
# [FORMULA_B_SEM step=1000] val_norm=12.2361 | ordering_norm=1.1057 | temp_norm=7.5116 | x_bar=12.2361 | ordering/val=0.0904
# Epoch: 4 cost time: 24.607481718063354
# Epoch: 4, Steps: 264 | Train Loss: 0.1968759 Vali Loss: 1.0610496 Test Loss: 1.0088142
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred96_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.855341911315918, mae:0.7314738035202026
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 02:22:09 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 11/12: formula_b_sem_ph2_ETTh1_pred192_seed2023
# pred_len=192 | seed=2023
# Start: Wed Aug  5 02:22:09 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred192_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [FORMULA_B_SEM step=0] val_norm=28.5038 | ordering_norm=0.6276 | temp_norm=7.7458 | x_bar=28.5038 | ordering/val=0.0220
# [FORMULA_B_SEM step=0] val_norm=8.0748 | ordering_norm=1.0709 | temp_norm=7.7122 | x_bar=8.0748 | ordering/val=0.1326
# 	iters: 100, epoch: 1 | loss: 0.4509064
# 	speed: 0.1434s/iter; left time: 210.3254s
# [FORMULA_B_SEM step=100] val_norm=29.8034 | ordering_norm=0.6037 | temp_norm=7.6499 | x_bar=29.8034 | ordering/val=0.0203
# [FORMULA_B_SEM step=100] val_norm=8.1333 | ordering_norm=1.0706 | temp_norm=7.6954 | x_bar=8.1333 | ordering/val=0.1316
# 	iters: 200, epoch: 1 | loss: 0.3227926
# 	speed: 0.1221s/iter; left time: 166.9718s
# [FORMULA_B_SEM step=200] val_norm=29.2949 | ordering_norm=0.6336 | temp_norm=7.6643 | x_bar=29.2949 | ordering/val=0.0216
# [FORMULA_B_SEM step=200] val_norm=8.1107 | ordering_norm=1.0717 | temp_norm=7.7379 | x_bar=8.1107 | ordering/val=0.1321
# Epoch: 1 cost time: 32.550748109817505
# Epoch: 1, Steps: 261 | Train Loss: 0.4183975 Vali Loss: 1.1137879 Test Loss: 0.8189600
# Validation loss decreased (inf --> 1.113788).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=29.4043 | ordering_norm=0.6558 | temp_norm=7.6811 | x_bar=29.4043 | ordering/val=0.0223
# [FORMULA_B_SEM step=300] val_norm=8.1042 | ordering_norm=1.0605 | temp_norm=7.8752 | x_bar=8.1042 | ordering/val=0.1309
# 	iters: 100, epoch: 2 | loss: 0.2858310
# 	speed: 0.2657s/iter; left time: 320.4796s
# [FORMULA_B_SEM step=400] val_norm=29.5939 | ordering_norm=0.6536 | temp_norm=7.7860 | x_bar=29.5939 | ordering/val=0.0221
# [FORMULA_B_SEM step=400] val_norm=8.2982 | ordering_norm=1.0722 | temp_norm=7.6736 | x_bar=8.2982 | ordering/val=0.1292
# 	iters: 200, epoch: 2 | loss: 0.2773027
# 	speed: 0.1216s/iter; left time: 134.4996s
# [FORMULA_B_SEM step=500] val_norm=27.2692 | ordering_norm=0.6378 | temp_norm=7.6906 | x_bar=27.2692 | ordering/val=0.0234
# [FORMULA_B_SEM step=500] val_norm=7.6711 | ordering_norm=1.0370 | temp_norm=7.8423 | x_bar=7.6711 | ordering/val=0.1352
# Epoch: 2 cost time: 31.69068670272827
# Epoch: 2, Steps: 261 | Train Loss: 0.2751202 Vali Loss: 1.1712085 Test Loss: 0.9770816
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=28.3755 | ordering_norm=0.6403 | temp_norm=7.7823 | x_bar=28.3755 | ordering/val=0.0226
# [FORMULA_B_SEM step=600] val_norm=7.9238 | ordering_norm=1.0559 | temp_norm=7.8759 | x_bar=7.9238 | ordering/val=0.1333
# 	iters: 100, epoch: 3 | loss: 0.2127931
# 	speed: 0.2633s/iter; left time: 248.7987s
# [FORMULA_B_SEM step=700] val_norm=29.9115 | ordering_norm=0.6303 | temp_norm=7.7468 | x_bar=29.9115 | ordering/val=0.0211
# [FORMULA_B_SEM step=700] val_norm=8.3311 | ordering_norm=1.0801 | temp_norm=7.7380 | x_bar=8.3311 | ordering/val=0.1296
# 	iters: 200, epoch: 3 | loss: 0.2234058
# 	speed: 0.1218s/iter; left time: 102.9161s
# Epoch: 3 cost time: 31.704426527023315
# Epoch: 3, Steps: 261 | Train Loss: 0.2320069 Vali Loss: 1.2368879 Test Loss: 0.9558286
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=30.0316 | ordering_norm=0.6534 | temp_norm=7.6936 | x_bar=30.0316 | ordering/val=0.0218
# [FORMULA_B_SEM step=800] val_norm=8.3505 | ordering_norm=1.0843 | temp_norm=7.7870 | x_bar=8.3505 | ordering/val=0.1299
# 	iters: 100, epoch: 4 | loss: 0.2248747
# 	speed: 0.2636s/iter; left time: 180.2959s
# [FORMULA_B_SEM step=900] val_norm=31.2677 | ordering_norm=0.6419 | temp_norm=7.6929 | x_bar=31.2677 | ordering/val=0.0205
# [FORMULA_B_SEM step=900] val_norm=8.4218 | ordering_norm=1.0806 | temp_norm=7.7335 | x_bar=8.4218 | ordering/val=0.1283
# 	iters: 200, epoch: 4 | loss: 0.1996416
# 	speed: 0.1217s/iter; left time: 71.0926s
# [FORMULA_B_SEM step=1000] val_norm=31.6208 | ordering_norm=0.5861 | temp_norm=7.6918 | x_bar=31.6208 | ordering/val=0.0185
# [FORMULA_B_SEM step=1000] val_norm=8.3791 | ordering_norm=1.0859 | temp_norm=7.8514 | x_bar=8.3791 | ordering/val=0.1296
# Epoch: 4 cost time: 31.69590735435486
# Epoch: 4, Steps: 261 | Train Loss: 0.2119656 Vali Loss: 1.1908487 Test Loss: 0.9667580
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred192_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.8189601302146912, mae:0.7169555425643921
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 02:24:53 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 12/12: formula_b_sem_ph2_ETTh1_pred336_seed2023
# pred_len=336 | seed=2023
# Start: Wed Aug  5 02:24:53 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_b_sem_ph2_ETTh1_pred336_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='formula_b_sem', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [FORMULA_B_SEM step=0] val_norm=29.5838 | ordering_norm=0.6580 | temp_norm=7.5832 | x_bar=29.5838 | ordering/val=0.0222
# [FORMULA_B_SEM step=0] val_norm=6.1707 | ordering_norm=0.8995 | temp_norm=7.4782 | x_bar=6.1707 | ordering/val=0.1458
# 	iters: 100, epoch: 1 | loss: 0.4012580
# 	speed: 0.1878s/iter; left time: 269.8841s
# [FORMULA_B_SEM step=100] val_norm=30.3057 | ordering_norm=0.6231 | temp_norm=7.5413 | x_bar=30.3057 | ordering/val=0.0206
# [FORMULA_B_SEM step=100] val_norm=6.2799 | ordering_norm=0.9313 | temp_norm=7.4920 | x_bar=6.2799 | ordering/val=0.1483
# 	iters: 200, epoch: 1 | loss: 0.3350086
# 	speed: 0.1766s/iter; left time: 236.0707s
# [FORMULA_B_SEM step=200] val_norm=29.5410 | ordering_norm=0.6367 | temp_norm=7.5171 | x_bar=29.5410 | ordering/val=0.0216
# [FORMULA_B_SEM step=200] val_norm=6.2414 | ordering_norm=0.9372 | temp_norm=7.5139 | x_bar=6.2414 | ordering/val=0.1502
# Epoch: 1 cost time: 45.28288674354553
# Epoch: 1, Steps: 256 | Train Loss: 0.4329733 Vali Loss: 1.3199714 Test Loss: 1.0083539
# Validation loss decreased (inf --> 1.319971).  Saving model ...
# Updating learning rate to 0.0001
# [FORMULA_B_SEM step=300] val_norm=27.6235 | ordering_norm=0.6954 | temp_norm=7.5251 | x_bar=27.6235 | ordering/val=0.0252
# [FORMULA_B_SEM step=300] val_norm=5.9475 | ordering_norm=0.8832 | temp_norm=7.5139 | x_bar=5.9475 | ordering/val=0.1485
# 	iters: 100, epoch: 2 | loss: 0.2844130
# 	speed: 0.3648s/iter; left time: 430.8796s
# [FORMULA_B_SEM step=400] val_norm=29.5828 | ordering_norm=0.6060 | temp_norm=7.6342 | x_bar=29.5828 | ordering/val=0.0205
# [FORMULA_B_SEM step=400] val_norm=6.1977 | ordering_norm=0.9210 | temp_norm=7.5670 | x_bar=6.1977 | ordering/val=0.1486
# 	iters: 200, epoch: 2 | loss: 0.2949425
# 	speed: 0.1752s/iter; left time: 189.4087s
# [FORMULA_B_SEM step=500] val_norm=32.1238 | ordering_norm=0.5890 | temp_norm=7.4731 | x_bar=32.1238 | ordering/val=0.0183
# [FORMULA_B_SEM step=500] val_norm=6.4304 | ordering_norm=0.9485 | temp_norm=7.4885 | x_bar=6.4304 | ordering/val=0.1475
# Epoch: 2 cost time: 44.6940381526947
# Epoch: 2, Steps: 256 | Train Loss: 0.2869388 Vali Loss: 1.2660776 Test Loss: 1.1362503
# Validation loss decreased (1.319971 --> 1.266078).  Saving model ...
# Updating learning rate to 5e-05
# [FORMULA_B_SEM step=600] val_norm=29.5381 | ordering_norm=0.6969 | temp_norm=7.5589 | x_bar=29.5381 | ordering/val=0.0236
# [FORMULA_B_SEM step=600] val_norm=6.2815 | ordering_norm=0.9218 | temp_norm=7.5403 | x_bar=6.2815 | ordering/val=0.1467
# 	iters: 100, epoch: 3 | loss: 0.2526897
# 	speed: 0.3667s/iter; left time: 339.1628s
# [FORMULA_B_SEM step=700] val_norm=29.1858 | ordering_norm=0.6640 | temp_norm=7.6238 | x_bar=29.1858 | ordering/val=0.0228
# [FORMULA_B_SEM step=700] val_norm=6.2576 | ordering_norm=0.9243 | temp_norm=7.5879 | x_bar=6.2576 | ordering/val=0.1477
# 	iters: 200, epoch: 3 | loss: 0.2275596
# 	speed: 0.1750s/iter; left time: 144.3988s
# Epoch: 3 cost time: 44.789236545562744
# Epoch: 3, Steps: 256 | Train Loss: 0.2411805 Vali Loss: 1.2889835 Test Loss: 1.1584861
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# [FORMULA_B_SEM step=800] val_norm=31.3493 | ordering_norm=0.6368 | temp_norm=7.5082 | x_bar=31.3493 | ordering/val=0.0203
# [FORMULA_B_SEM step=800] val_norm=6.3939 | ordering_norm=0.9446 | temp_norm=7.5006 | x_bar=6.3939 | ordering/val=0.1477
# 	iters: 100, epoch: 4 | loss: 0.2059326
# 	speed: 0.3628s/iter; left time: 242.7450s
# [FORMULA_B_SEM step=900] val_norm=29.0771 | ordering_norm=0.6859 | temp_norm=7.5625 | x_bar=29.0771 | ordering/val=0.0236
# [FORMULA_B_SEM step=900] val_norm=6.0766 | ordering_norm=0.9077 | temp_norm=7.5045 | x_bar=6.0766 | ordering/val=0.1494
# 	iters: 200, epoch: 4 | loss: 0.2147489
# 	speed: 0.1749s/iter; left time: 99.5326s
# [FORMULA_B_SEM step=1000] val_norm=30.7342 | ordering_norm=0.6451 | temp_norm=7.5077 | x_bar=30.7343 | ordering/val=0.0210
# [FORMULA_B_SEM step=1000] val_norm=6.2774 | ordering_norm=0.9295 | temp_norm=7.5156 | x_bar=6.2774 | ordering/val=0.1481
# Epoch: 4 cost time: 44.679216384887695
# Epoch: 4, Steps: 256 | Train Loss: 0.2217260 Vali Loss: 1.2879764 Test Loss: 1.1502022
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# [FORMULA_B_SEM step=1100] val_norm=32.4996 | ordering_norm=0.5735 | temp_norm=7.5422 | x_bar=32.4996 | ordering/val=0.0176
# [FORMULA_B_SEM step=1100] val_norm=6.6239 | ordering_norm=0.9791 | temp_norm=7.5485 | x_bar=6.6239 | ordering/val=0.1478
# 	iters: 100, epoch: 5 | loss: 0.2036460
# 	speed: 0.3640s/iter; left time: 150.3135s
# [FORMULA_B_SEM step=1200] val_norm=30.2071 | ordering_norm=0.6347 | temp_norm=7.5049 | x_bar=30.2071 | ordering/val=0.0210
# [FORMULA_B_SEM step=1200] val_norm=6.3535 | ordering_norm=0.9437 | temp_norm=7.4546 | x_bar=6.3535 | ordering/val=0.1485
# 	iters: 200, epoch: 5 | loss: 0.2098887
# 	speed: 0.1754s/iter; left time: 54.8926s
# Epoch: 5 cost time: 44.77933621406555
# Epoch: 5, Steps: 256 | Train Loss: 0.2111108 Vali Loss: 1.2876325 Test Loss: 1.1241864
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_b_sem_ph2_ETTh1_pred336_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.1362502574920654, mae:0.86090087890625
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 02:29:33 PM UTC 2026
#
# ============================================================
#  PHASE 2 SUMMARY — Formula B (Semantic Space)
#  Total: 12 | Completed: 12 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
# Seed  | PredLen | MSE      | MAE
# ------|---------|----------|----------
# 2021  | 48      | 0.9173708558082581 | 0.7697590589523315
# 2021  | 96      | 0.7664976119995117 | 0.6805901527404785
# 2021  | 192     | 1.0379962921142578 | 0.8093645572662354
# 2021  | 336     | 1.0280449390411377 | 0.8228479027748108
#
# 2022  | 48      | 0.9168705344200134 | 0.765535295009613
# 2022  | 96      | 0.8043519854545593 | 0.7114629149436951
# 2022  | 192     | 0.8547497987747192 | 0.7293984293937683
# 2022  | 336     | 0.8943517804145813 | 0.7555994391441345
#
# 2023  | 48      | 0.8920473456382751 | 0.747144341468811
# 2023  | 96      | 0.855341911315918 | 0.7314738035202026
# 2023  | 192     | 0.8189601302146912 | 0.7169555425643921
# 2023  | 336     | 1.1362502574920654 | 0.86090087890625
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0:
#  seed=2021 | pred=96  MSE=0.8683
#  seed=2021 | pred=192 MSE=0.8463  ← Phase 1 target
#
#  DECISION GUIDE:
#    Consistent improvement across all 3 seeds → result is robust
#    Improvement only at seed=2021             → Phase 1 was a fluke, investigate
#    Mixed results across pred_lens            → horizon-dependent, report range
#    Regression vs Phase 1 at all seeds        → implementation issue, debug
# ============================================================
# End: Wed Aug  5 02:29:34 PM UTC 2026
