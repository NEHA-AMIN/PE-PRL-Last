# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

project_path = '/content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1'
os.chdir(project_path)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1

# %%
# !ls -la /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-A-pos/formula-A-pos-ph1.sh
# Out:
# -rw------- 1 root root 7555 Aug  5 11:07 /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-A-pos/formula-A-pos-ph1.sh

# %%
import os

# Set your Informer data directory
informer_path = f'{project_path}/Informer2020-original'
data_dir = f'{informer_path}/data/ETT'
os.makedirs(data_dir, exist_ok=True)

# File path
data_file = f'{data_dir}/ETTh1.csv'

# Download ETTh1 dataset
if not os.path.exists(data_file):
    print("Downloading ETTh1.csv...")
    os.system(
        f'wget -q "https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv" '
        f'-O "{data_file}"'
    )

# Verify
if os.path.exists(data_file):
    print(f"✅ Download successful: {data_file}")
else:
    print("❌ Download failed.")
# Out:
# ✅ Download successful: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/data/ETT/ETTh1.csv

# %%
# Fix np.Inf -> np.inf in tools.py (removed in NumPy 2.0)
tools_path = f'{project_path}/Informer2020-original/utils/tools.py'

with open(tools_path, 'r') as f:
    content = f.read()

content_fixed = content.replace('np.Inf', 'np.inf')

with open(tools_path, 'w') as f:
    f.write(content_fixed)

print("✅ Fixed np.Inf -> np.inf in utils/tools.py")
# Out:
# ✅ Fixed np.Inf -> np.inf in utils/tools.py

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-A-pos/formula-A-pos-ph1.sh
# Out:
# ============================================================
#  Formula A (Positional Space) — Phase 1: Legendre Consecutive Delta
#  Date: Wed Aug  5 11:55:43 AM UTC 2026
# ------------------------------------------------------------
#  Formula:  X'_i = X_i + T_i + P_i + O_i^pos
#  Signal:   O_i^pos = (P_i - P_{i-1}) / p_bar  (zero-pad at i=0)
#  pe_mode:  ordering_pos
# ------------------------------------------------------------
#  Seed:       2021
#  Pred lens:  96, 192
#  Total runs: 2
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/2: formula_a_pos_ph1_ETTh1_pred96_seed2021
# Start: Wed Aug  5 11:55:48 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph1_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph1_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4480593
# 	speed: 0.1625s/iter; left time: 241.2733s
# 	iters: 200, epoch: 1 | loss: 0.3279569
# 	speed: 0.0865s/iter; left time: 119.7854s
# Epoch: 1 cost time: 24.35755228996277
# Epoch: 1, Steps: 264 | Train Loss: 0.4092697 Vali Loss: 0.9720877 Test Loss: 0.8909913
# Validation loss decreased (inf --> 0.972088).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2579738
# 	speed: 0.1992s/iter; left time: 243.1990s
# 	iters: 200, epoch: 2 | loss: 0.2289371
# 	speed: 0.0904s/iter; left time: 101.3430s
# Epoch: 2 cost time: 23.674890279769897
# Epoch: 2, Steps: 264 | Train Loss: 0.2622289 Vali Loss: 1.0097170 Test Loss: 1.0216577
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2115739
# 	speed: 0.2071s/iter; left time: 198.2164s
# 	iters: 200, epoch: 3 | loss: 0.2208288
# 	speed: 0.0958s/iter; left time: 82.1295s
# Epoch: 3 cost time: 25.290322065353394
# Epoch: 3, Steps: 264 | Train Loss: 0.2190294 Vali Loss: 1.0393189 Test Loss: 1.0443981
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2061621
# 	speed: 0.2251s/iter; left time: 155.9745s
# 	iters: 200, epoch: 4 | loss: 0.1970443
# 	speed: 0.1079s/iter; left time: 64.0078s
# Epoch: 4 cost time: 28.114549160003662
# Epoch: 4, Steps: 264 | Train Loss: 0.2012249 Vali Loss: 1.0506614 Test Loss: 1.0560480
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph1_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8909913301467896, mae:0.7516491413116455
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 11:58:28 AM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/2: formula_a_pos_ph1_ETTh1_pred192_seed2021
# Start: Wed Aug  5 11:58:28 AM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph1_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph1_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# 	iters: 100, epoch: 1 | loss: 0.4601611
# 	speed: 0.1468s/iter; left time: 215.3971s
# 	iters: 200, epoch: 1 | loss: 0.3346357
# 	speed: 0.1421s/iter; left time: 194.3089s
# Epoch: 1 cost time: 36.98011875152588
# Epoch: 1, Steps: 261 | Train Loss: 0.4219825 Vali Loss: 1.1742537 Test Loss: 0.8714471
# Validation loss decreased (inf --> 1.174254).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3001634
# 	speed: 0.3291s/iter; left time: 396.8825s
# 	iters: 200, epoch: 2 | loss: 0.2479993
# 	speed: 0.1404s/iter; left time: 155.2882s
# Epoch: 2 cost time: 37.10290193557739
# Epoch: 2, Steps: 261 | Train Loss: 0.2723889 Vali Loss: 1.2891300 Test Loss: 1.0041707
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2404112
# 	speed: 0.3030s/iter; left time: 286.2923s
# 	iters: 200, epoch: 3 | loss: 0.2223398
# 	speed: 0.1448s/iter; left time: 122.3867s
# Epoch: 3 cost time: 37.38756728172302
# Epoch: 3, Steps: 261 | Train Loss: 0.2273864 Vali Loss: 1.2630408 Test Loss: 1.0145335
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2138234
# 	speed: 0.3159s/iter; left time: 216.0677s
# 	iters: 200, epoch: 4 | loss: 0.1969030
# 	speed: 0.1420s/iter; left time: 82.9244s
# Epoch: 4 cost time: 37.14938688278198
# Epoch: 4, Steps: 261 | Train Loss: 0.2069050 Vali Loss: 1.2922891 Test Loss: 0.9936278
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph1_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.8714473843574524, mae:0.74016934633255
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:01:50 PM UTC 2026
#
# ============================================================
#  PHASE 1 SUMMARY — Formula A (Positional Space)
#  Total: 2 | Completed: 2 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
#  RUN_ID                                                         MSE        MAE
#  ------------------------------------------------------- ---------- ----------
#  formula_a_pos_ph1_ETTh1_pred96_seed2021                 0.8909913301467896 0.7516491413116455
#  formula_a_pos_ph1_ETTh1_pred192_seed2021                0.8714473843574524 0.74016934633255
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0 (seed=2021):
#    pred=96  MSE=0.8683
#    pred=192 MSE=0.8463  ← target to beat
#
#  DECISION GUIDE:
#    Formula-A-pos wins BOTH vs Exp1-Pre → proceed to Phase 2
#    Formula-A-pos wins ONE  vs Exp1-Pre → Phase 2 to confirm
#    Formula-A-pos loses BOTH            → document, stop
# ============================================================
# End: Wed Aug  5 12:01:51 PM UTC 2026

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/Formula-A-pos/formula-A-pos-ph2.sh
# Out:
# ============================================================
#  Formula A (Positional Space) — Phase 2: Legendre Consecutive Delta
#  Date: Wed Aug  5 12:46:16 PM UTC 2026
# ------------------------------------------------------------
#  Formula:  X'_i = X_i + T_i + P_i + O_i^pos
#  Signal:   O_i^pos = (P_i - P_{i-1}) / p_bar  (zero-pad at i=0)
#  pe_mode:  ordering_pos
# ------------------------------------------------------------
#  Seeds:      2021, 2022, 2023
#  Pred lens:  48, 96, 192, 336
#  Total runs: 12
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/12: formula_a_pos_ph2_ETTh1_pred48_seed2021
# pred_len=48 | seed=2021
# Start: Wed Aug  5 12:46:16 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred48_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred48_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# 	iters: 100, epoch: 1 | loss: 0.4599267
# 	speed: 0.0846s/iter; left time: 126.0896s
# 	iters: 200, epoch: 1 | loss: 0.3413482
# 	speed: 0.0700s/iter; left time: 97.3006s
# Epoch: 1 cost time: 18.951085805892944
# Epoch: 1, Steps: 265 | Train Loss: 0.4037481 Vali Loss: 0.8369564 Test Loss: 0.8837065
# Validation loss decreased (inf --> 0.836956).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2601874
# 	speed: 0.1597s/iter; left time: 195.8195s
# 	iters: 200, epoch: 2 | loss: 0.2337994
# 	speed: 0.0721s/iter; left time: 81.1652s
# Epoch: 2 cost time: 18.991649866104126
# Epoch: 2, Steps: 265 | Train Loss: 0.2592136 Vali Loss: 0.8819672 Test Loss: 0.9549115
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.1977722
# 	speed: 0.1627s/iter; left time: 156.3546s
# 	iters: 200, epoch: 3 | loss: 0.1982006
# 	speed: 0.0739s/iter; left time: 63.6032s
# Epoch: 3 cost time: 19.537707567214966
# Epoch: 3, Steps: 265 | Train Loss: 0.2112178 Vali Loss: 0.9638964 Test Loss: 0.9230198
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.1872880
# 	speed: 0.1677s/iter; left time: 116.7074s
# 	iters: 200, epoch: 4 | loss: 0.2060017
# 	speed: 0.0762s/iter; left time: 45.3866s
# Epoch: 4 cost time: 20.107094049453735
# Epoch: 4, Steps: 265 | Train Loss: 0.1931487 Vali Loss: 0.9996746 Test Loss: 0.9074081
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred48_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.8837067484855652, mae:0.742670476436615
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:48:10 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/12: formula_a_pos_ph2_ETTh1_pred96_seed2021
# pred_len=96 | seed=2021
# Start: Wed Aug  5 12:48:10 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4339118
# 	speed: 0.1090s/iter; left time: 161.8715s
# 	iters: 200, epoch: 1 | loss: 0.3223074
# 	speed: 0.0965s/iter; left time: 133.6271s
# Epoch: 1 cost time: 25.84031629562378
# Epoch: 1, Steps: 264 | Train Loss: 0.4106275 Vali Loss: 0.9629577 Test Loss: 0.8045599
# Validation loss decreased (inf --> 0.962958).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2346263
# 	speed: 0.2264s/iter; left time: 276.4400s
# 	iters: 200, epoch: 2 | loss: 0.2586300
# 	speed: 0.1057s/iter; left time: 118.5283s
# Epoch: 2 cost time: 27.653210163116455
# Epoch: 2, Steps: 264 | Train Loss: 0.2616223 Vali Loss: 0.9888106 Test Loss: 0.9084105
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2075231
# 	speed: 0.2481s/iter; left time: 237.3933s
# 	iters: 200, epoch: 3 | loss: 0.2102003
# 	speed: 0.1079s/iter; left time: 92.4316s
# Epoch: 3 cost time: 28.564063549041748
# Epoch: 3, Steps: 264 | Train Loss: 0.2174673 Vali Loss: 1.0262668 Test Loss: 0.9844097
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.1935591
# 	speed: 0.2305s/iter; left time: 159.7526s
# 	iters: 200, epoch: 4 | loss: 0.1973092
# 	speed: 0.1012s/iter; left time: 60.0288s
# Epoch: 4 cost time: 26.76014018058777
# Epoch: 4, Steps: 264 | Train Loss: 0.2000435 Vali Loss: 1.0404515 Test Loss: 1.0058677
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8045598864555359, mae:0.7026992440223694
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:50:44 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 3/12: formula_a_pos_ph2_ETTh1_pred192_seed2021
# pred_len=192 | seed=2021
# Start: Wed Aug  5 12:50:44 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# 	iters: 100, epoch: 1 | loss: 0.4491270
# 	speed: 0.1571s/iter; left time: 230.5266s
# 	iters: 200, epoch: 1 | loss: 0.3529307
# 	speed: 0.1489s/iter; left time: 203.5009s
# Epoch: 1 cost time: 38.604164838790894
# Epoch: 1, Steps: 261 | Train Loss: 0.4302963 Vali Loss: 1.2551926 Test Loss: 0.9127899
# Validation loss decreased (inf --> 1.255193).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2652983
# 	speed: 0.3219s/iter; left time: 388.2660s
# 	iters: 200, epoch: 2 | loss: 0.2574582
# 	speed: 0.1374s/iter; left time: 152.0001s
# Epoch: 2 cost time: 36.16851782798767
# Epoch: 2, Steps: 261 | Train Loss: 0.2758363 Vali Loss: 1.3351178 Test Loss: 1.0657861
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2201069
# 	speed: 0.3102s/iter; left time: 293.1130s
# 	iters: 200, epoch: 3 | loss: 0.2229675
# 	speed: 0.1466s/iter; left time: 123.8756s
# Epoch: 3 cost time: 37.87436032295227
# Epoch: 3, Steps: 261 | Train Loss: 0.2304474 Vali Loss: 1.3147081 Test Loss: 1.0118772
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2267456
# 	speed: 0.3095s/iter; left time: 211.6935s
# 	iters: 200, epoch: 4 | loss: 0.2021163
# 	speed: 0.1417s/iter; left time: 82.7767s
# Epoch: 4 cost time: 36.992700815200806
# Epoch: 4, Steps: 261 | Train Loss: 0.2091131 Vali Loss: 1.3025591 Test Loss: 0.9569556
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.9127898812294006, mae:0.7710499167442322
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:54:07 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 4/12: formula_a_pos_ph2_ETTh1_pred336_seed2021
# pred_len=336 | seed=2021
# Start: Wed Aug  5 12:54:07 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred336_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred336_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# 	iters: 100, epoch: 1 | loss: 0.4443704
# 	speed: 0.2109s/iter; left time: 303.0925s
# 	iters: 200, epoch: 1 | loss: 0.3638719
# 	speed: 0.2146s/iter; left time: 286.9034s
# Epoch: 1 cost time: 53.69530534744263
# Epoch: 1, Steps: 256 | Train Loss: 0.4321903 Vali Loss: 1.2705499 Test Loss: 1.0232153
# Validation loss decreased (inf --> 1.270550).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3099495
# 	speed: 0.4367s/iter; left time: 515.6998s
# 	iters: 200, epoch: 2 | loss: 0.2636147
# 	speed: 0.2017s/iter; left time: 217.9989s
# Epoch: 2 cost time: 51.62755990028381
# Epoch: 2, Steps: 256 | Train Loss: 0.2882035 Vali Loss: 1.2736109 Test Loss: 1.2346187
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2523578
# 	speed: 0.4344s/iter; left time: 401.8554s
# 	iters: 200, epoch: 3 | loss: 0.2385408
# 	speed: 0.2030s/iter; left time: 167.4651s
# Epoch: 3 cost time: 52.33438181877136
# Epoch: 3, Steps: 256 | Train Loss: 0.2431494 Vali Loss: 1.3258127 Test Loss: 1.2687489
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2431281
# 	speed: 0.4285s/iter; left time: 286.6577s
# 	iters: 200, epoch: 4 | loss: 0.2169589
# 	speed: 0.2062s/iter; left time: 117.3497s
# Epoch: 4 cost time: 52.525697469711304
# Epoch: 4, Steps: 256 | Train Loss: 0.2234150 Vali Loss: 1.3482662 Test Loss: 1.3045136
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred336_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.0232146978378296, mae:0.8233616948127747
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:58:43 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 5/12: formula_a_pos_ph2_ETTh1_pred48_seed2022
# pred_len=48 | seed=2022
# Start: Wed Aug  5 12:58:43 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred48_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred48_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# 	iters: 100, epoch: 1 | loss: 0.4776303
# 	speed: 0.0986s/iter; left time: 147.0609s
# 	iters: 200, epoch: 1 | loss: 0.3374672
# 	speed: 0.0829s/iter; left time: 115.3479s
# Epoch: 1 cost time: 22.401776790618896
# Epoch: 1, Steps: 265 | Train Loss: 0.4046260 Vali Loss: 0.9106917 Test Loss: 0.8641099
# Validation loss decreased (inf --> 0.910692).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3033994
# 	speed: 0.2019s/iter; left time: 247.5367s
# 	iters: 200, epoch: 2 | loss: 0.2215182
# 	speed: 0.0948s/iter; left time: 106.7793s
# Epoch: 2 cost time: 24.572427988052368
# Epoch: 2, Steps: 265 | Train Loss: 0.2617910 Vali Loss: 0.9377806 Test Loss: 1.0379688
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2234644
# 	speed: 0.1960s/iter; left time: 188.3382s
# 	iters: 200, epoch: 3 | loss: 0.2042715
# 	speed: 0.0828s/iter; left time: 71.2674s
# Epoch: 3 cost time: 22.086898803710938
# Epoch: 3, Steps: 265 | Train Loss: 0.2102471 Vali Loss: 1.0262529 Test Loss: 1.1430951
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.1842584
# 	speed: 0.1847s/iter; left time: 128.5344s
# 	iters: 200, epoch: 4 | loss: 0.1815253
# 	speed: 0.0861s/iter; left time: 51.3383s
# Epoch: 4 cost time: 22.680450439453125
# Epoch: 4, Steps: 265 | Train Loss: 0.1903736 Vali Loss: 1.0076420 Test Loss: 1.0495799
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred48_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.8641096353530884, mae:0.7387957572937012
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:00:54 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 6/12: formula_a_pos_ph2_ETTh1_pred96_seed2022
# pred_len=96 | seed=2022
# Start: Wed Aug  5 01:00:54 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred96_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred96_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4568964
# 	speed: 0.1159s/iter; left time: 172.0387s
# 	iters: 200, epoch: 1 | loss: 0.3040484
# 	speed: 0.1077s/iter; left time: 149.2128s
# Epoch: 1 cost time: 28.52864170074463
# Epoch: 1, Steps: 264 | Train Loss: 0.4072673 Vali Loss: 0.9823623 Test Loss: 0.8698859
# Validation loss decreased (inf --> 0.982362).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2889863
# 	speed: 0.2565s/iter; left time: 313.2389s
# 	iters: 200, epoch: 2 | loss: 0.2364625
# 	speed: 0.1064s/iter; left time: 119.2759s
# Epoch: 2 cost time: 28.322592735290527
# Epoch: 2, Steps: 264 | Train Loss: 0.2583318 Vali Loss: 1.0394554 Test Loss: 0.9984060
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2134242
# 	speed: 0.2277s/iter; left time: 217.9410s
# 	iters: 200, epoch: 3 | loss: 0.1964141
# 	speed: 0.1026s/iter; left time: 87.9306s
# Epoch: 3 cost time: 27.048879623413086
# Epoch: 3, Steps: 264 | Train Loss: 0.2144360 Vali Loss: 1.0277662 Test Loss: 0.9152901
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.1920331
# 	speed: 0.2381s/iter; left time: 165.0033s
# 	iters: 200, epoch: 4 | loss: 0.2036107
# 	speed: 0.1083s/iter; left time: 64.2495s
# Epoch: 4 cost time: 28.452025175094604
# Epoch: 4, Steps: 264 | Train Loss: 0.1962696 Vali Loss: 1.0374560 Test Loss: 0.9215713
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred96_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8698857426643372, mae:0.7494027614593506
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:03:32 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 7/12: formula_a_pos_ph2_ETTh1_pred192_seed2022
# pred_len=192 | seed=2022
# Start: Wed Aug  5 01:03:32 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred192_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred192_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# 	iters: 100, epoch: 1 | loss: 0.4824877
# 	speed: 0.1480s/iter; left time: 217.1611s
# 	iters: 200, epoch: 1 | loss: 0.3241405
# 	speed: 0.1447s/iter; left time: 197.8316s
# Epoch: 1 cost time: 37.65658473968506
# Epoch: 1, Steps: 261 | Train Loss: 0.4188711 Vali Loss: 1.1898569 Test Loss: 0.8873397
# Validation loss decreased (inf --> 1.189857).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2926336
# 	speed: 0.3298s/iter; left time: 397.7889s
# 	iters: 200, epoch: 2 | loss: 0.2643922
# 	speed: 0.1390s/iter; left time: 153.7038s
# Epoch: 2 cost time: 36.686193227767944
# Epoch: 2, Steps: 261 | Train Loss: 0.2751109 Vali Loss: 1.2362489 Test Loss: 1.0239835
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2424786
# 	speed: 0.3033s/iter; left time: 286.6496s
# 	iters: 200, epoch: 3 | loss: 0.2228225
# 	speed: 0.1452s/iter; left time: 122.7318s
# Epoch: 3 cost time: 37.444830894470215
# Epoch: 3, Steps: 261 | Train Loss: 0.2315732 Vali Loss: 1.2704400 Test Loss: 0.9938055
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2220626
# 	speed: 0.3078s/iter; left time: 210.5419s
# 	iters: 200, epoch: 4 | loss: 0.2058106
# 	speed: 0.1344s/iter; left time: 78.4791s
# Epoch: 4 cost time: 35.336260080337524
# Epoch: 4, Steps: 261 | Train Loss: 0.2128454 Vali Loss: 1.2543907 Test Loss: 0.9805797
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred192_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.8873394131660461, mae:0.7371362447738647
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:06:51 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 8/12: formula_a_pos_ph2_ETTh1_pred336_seed2022
# pred_len=336 | seed=2022
# Start: Wed Aug  5 01:06:51 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred336_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred336_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# 	iters: 100, epoch: 1 | loss: 0.4195085
# 	speed: 0.1974s/iter; left time: 283.6051s
# 	iters: 200, epoch: 1 | loss: 0.3288490
# 	speed: 0.1828s/iter; left time: 244.3951s
# Epoch: 1 cost time: 47.212690114974976
# Epoch: 1, Steps: 256 | Train Loss: 0.4249906 Vali Loss: 1.3685442 Test Loss: 1.2001387
# Validation loss decreased (inf --> 1.368544).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2808104
# 	speed: 0.3832s/iter; left time: 452.5159s
# 	iters: 200, epoch: 2 | loss: 0.2786419
# 	speed: 0.1837s/iter; left time: 198.5499s
# Epoch: 2 cost time: 46.832390785217285
# Epoch: 2, Steps: 256 | Train Loss: 0.2846269 Vali Loss: 1.3733658 Test Loss: 1.0686212
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2276902
# 	speed: 0.4058s/iter; left time: 375.4102s
# 	iters: 200, epoch: 3 | loss: 0.2363164
# 	speed: 0.2195s/iter; left time: 181.0708s
# Epoch: 3 cost time: 53.6723108291626
# Epoch: 3, Steps: 256 | Train Loss: 0.2372437 Vali Loss: 1.3842454 Test Loss: 1.1531000
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2201835
# 	speed: 0.4215s/iter; left time: 281.9930s
# 	iters: 200, epoch: 4 | loss: 0.2115861
# 	speed: 0.2038s/iter; left time: 115.9467s
# Epoch: 4 cost time: 51.81362748146057
# Epoch: 4, Steps: 256 | Train Loss: 0.2152067 Vali Loss: 1.4141120 Test Loss: 1.1859776
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred336_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.200138807296753, mae:0.8784056305885315
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:11:14 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 9/12: formula_a_pos_ph2_ETTh1_pred48_seed2023
# pred_len=48 | seed=2023
# Start: Wed Aug  5 01:11:14 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred48_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred48_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# 	iters: 100, epoch: 1 | loss: 0.4208062
# 	speed: 0.0958s/iter; left time: 142.9052s
# 	iters: 200, epoch: 1 | loss: 0.3312323
# 	speed: 0.0841s/iter; left time: 116.9357s
# Epoch: 1 cost time: 22.596551179885864
# Epoch: 1, Steps: 265 | Train Loss: 0.3992631 Vali Loss: 0.8087070 Test Loss: 0.8290920
# Validation loss decreased (inf --> 0.808707).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2693371
# 	speed: 0.2025s/iter; left time: 248.2592s
# 	iters: 200, epoch: 2 | loss: 0.2467116
# 	speed: 0.0870s/iter; left time: 97.9684s
# Epoch: 2 cost time: 23.18905019760132
# Epoch: 2, Steps: 265 | Train Loss: 0.2595526 Vali Loss: 0.9054099 Test Loss: 0.9299036
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2292652
# 	speed: 0.1828s/iter; left time: 175.6307s
# 	iters: 200, epoch: 3 | loss: 0.1840867
# 	speed: 0.0795s/iter; left time: 68.4528s
# Epoch: 3 cost time: 21.167156219482422
# Epoch: 3, Steps: 265 | Train Loss: 0.2118958 Vali Loss: 0.9177607 Test Loss: 0.9163523
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.1942839
# 	speed: 0.1789s/iter; left time: 124.5425s
# 	iters: 200, epoch: 4 | loss: 0.1834064
# 	speed: 0.0814s/iter; left time: 48.4966s
# Epoch: 4 cost time: 21.532140970230103
# Epoch: 4, Steps: 265 | Train Loss: 0.1923794 Vali Loss: 0.9526545 Test Loss: 1.0345496
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred48_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.8290919661521912, mae:0.7213220596313477
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:13:20 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 10/12: formula_a_pos_ph2_ETTh1_pred96_seed2023
# pred_len=96 | seed=2023
# Start: Wed Aug  5 01:13:20 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred96_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred96_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4530404
# 	speed: 0.1086s/iter; left time: 161.2482s
# 	iters: 200, epoch: 1 | loss: 0.3211627
# 	speed: 0.0934s/iter; left time: 129.4053s
# Epoch: 1 cost time: 25.13441777229309
# Epoch: 1, Steps: 264 | Train Loss: 0.4116717 Vali Loss: 1.0297853 Test Loss: 0.7605790
# Validation loss decreased (inf --> 1.029785).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2441168
# 	speed: 0.2104s/iter; left time: 256.9225s
# 	iters: 200, epoch: 2 | loss: 0.2502237
# 	speed: 0.0944s/iter; left time: 105.8645s
# Epoch: 2 cost time: 24.88437795639038
# Epoch: 2, Steps: 264 | Train Loss: 0.2616969 Vali Loss: 1.0835382 Test Loss: 0.8274031
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2085214
# 	speed: 0.2132s/iter; left time: 204.0474s
# 	iters: 200, epoch: 3 | loss: 0.2335685
# 	speed: 0.0962s/iter; left time: 82.4126s
# Epoch: 3 cost time: 25.30602192878723
# Epoch: 3, Steps: 264 | Train Loss: 0.2161555 Vali Loss: 1.0832654 Test Loss: 0.8998697
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2119331
# 	speed: 0.2135s/iter; left time: 147.9225s
# 	iters: 200, epoch: 4 | loss: 0.1973016
# 	speed: 0.0952s/iter; left time: 56.4453s
# Epoch: 4 cost time: 25.090506553649902
# Epoch: 4, Steps: 264 | Train Loss: 0.1994697 Vali Loss: 1.1231234 Test Loss: 0.9212632
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred96_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.7605789303779602, mae:0.6719040870666504
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:15:41 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 11/12: formula_a_pos_ph2_ETTh1_pred192_seed2023
# pred_len=192 | seed=2023
# Start: Wed Aug  5 01:15:42 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred192_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred192_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# 	iters: 100, epoch: 1 | loss: 0.3765568
# 	speed: 0.1369s/iter; left time: 200.8283s
# 	iters: 200, epoch: 1 | loss: 0.3293464
# 	speed: 0.1244s/iter; left time: 170.0165s
# Epoch: 1 cost time: 32.7045214176178
# Epoch: 1, Steps: 261 | Train Loss: 0.4248711 Vali Loss: 1.2062956 Test Loss: 0.9974828
# Validation loss decreased (inf --> 1.206296).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2858208
# 	speed: 0.2772s/iter; left time: 334.2704s
# 	iters: 200, epoch: 2 | loss: 0.2718025
# 	speed: 0.1372s/iter; left time: 151.7144s
# Epoch: 2 cost time: 35.379055976867676
# Epoch: 2, Steps: 261 | Train Loss: 0.2770933 Vali Loss: 1.2683439 Test Loss: 1.2261289
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2219417
# 	speed: 0.3253s/iter; left time: 307.4297s
# 	iters: 200, epoch: 3 | loss: 0.2262526
# 	speed: 0.1430s/iter; left time: 120.8511s
# Epoch: 3 cost time: 37.853004455566406
# Epoch: 3, Steps: 261 | Train Loss: 0.2311830 Vali Loss: 1.2904623 Test Loss: 1.3340713
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2174821
# 	speed: 0.3024s/iter; left time: 206.8160s
# 	iters: 200, epoch: 4 | loss: 0.2042955
# 	speed: 0.1423s/iter; left time: 83.1154s
# Epoch: 4 cost time: 36.93263864517212
# Epoch: 4, Steps: 261 | Train Loss: 0.2097677 Vali Loss: 1.2781907 Test Loss: 1.3115928
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred192_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.9974824786186218, mae:0.7885332703590393
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:18:56 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 12/12: formula_a_pos_ph2_ETTh1_pred336_seed2023
# pred_len=336 | seed=2023
# Start: Wed Aug  5 01:18:56 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_pos_ph2_ETTh1_pred336_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='ordering_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred336_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# 	iters: 100, epoch: 1 | loss: 0.4047128
# 	speed: 0.2107s/iter; left time: 302.7882s
# 	iters: 200, epoch: 1 | loss: 0.3419383
# 	speed: 0.2193s/iter; left time: 293.1453s
# Epoch: 1 cost time: 53.82672190666199
# Epoch: 1, Steps: 256 | Train Loss: 0.4295311 Vali Loss: 1.3656539 Test Loss: 1.0384620
# Validation loss decreased (inf --> 1.365654).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2910804
# 	speed: 0.4275s/iter; left time: 504.8556s
# 	iters: 200, epoch: 2 | loss: 0.2556919
# 	speed: 0.2022s/iter; left time: 218.6298s
# Epoch: 2 cost time: 51.56797933578491
# Epoch: 2, Steps: 256 | Train Loss: 0.2852393 Vali Loss: 1.2774073 Test Loss: 1.1193408
# Validation loss decreased (1.365654 --> 1.277407).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.2302547
# 	speed: 0.4355s/iter; left time: 402.8133s
# 	iters: 200, epoch: 3 | loss: 0.2259424
# 	speed: 0.2026s/iter; left time: 167.1447s
# Epoch: 3 cost time: 52.0332772731781
# Epoch: 3, Steps: 256 | Train Loss: 0.2388509 Vali Loss: 1.2818203 Test Loss: 1.0980577
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.2251265
# 	speed: 0.4270s/iter; left time: 285.6587s
# 	iters: 200, epoch: 4 | loss: 0.2119658
# 	speed: 0.2047s/iter; left time: 116.4857s
# Epoch: 4 cost time: 52.18435502052307
# Epoch: 4, Steps: 256 | Train Loss: 0.2193551 Vali Loss: 1.3397491 Test Loss: 1.2084477
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.1983767
# 	speed: 0.4253s/iter; left time: 175.6333s
# 	iters: 200, epoch: 5 | loss: 0.2213866
# 	speed: 0.2026s/iter; left time: 63.4002s
# Epoch: 5 cost time: 51.7109010219574
# Epoch: 5, Steps: 256 | Train Loss: 0.2092151 Vali Loss: 1.3152503 Test Loss: 1.1787865
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_pos_ph2_ETTh1_pred336_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:1.1193406581878662, mae:0.8653407692909241
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:24:35 PM UTC 2026
#
# ============================================================
#  PHASE 2 SUMMARY — Formula A (Positional Space)
#  Total: 12 | Completed: 12 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
# Seed  | PredLen | MSE      | MAE
# ------|---------|----------|----------
# 2021  | 48      | 0.8837067484855652 | 0.742670476436615
# 2021  | 96      | 0.8045598864555359 | 0.7026992440223694
# 2021  | 192     | 0.9127898812294006 | 0.7710499167442322
# 2021  | 336     | 1.0232146978378296 | 0.8233616948127747
#
# 2022  | 48      | 0.8641096353530884 | 0.7387957572937012
# 2022  | 96      | 0.8698857426643372 | 0.7494027614593506
# 2022  | 192     | 0.8873394131660461 | 0.7371362447738647
# 2022  | 336     | 1.200138807296753 | 0.8784056305885315
#
# 2023  | 48      | 0.8290919661521912 | 0.7213220596313477
# 2023  | 96      | 0.7605789303779602 | 0.6719040870666504
# 2023  | 192     | 0.9974824786186218 | 0.7885332703590393
# 2023  | 336     | 1.1193406581878662 | 0.8653407692909241
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0:
#  seed=2021 | pred=96  MSE=0.8683
#  seed=2021 | pred=192 MSE=0.8463  ← Phase 1 target
#
#  DECISION GUIDE:
#    Consistent improvement across all 3 seeds → result is robust
#    Improvement only at seed=2021             → Phase 1 was a fluke, investigate
#    Mixed results across pred_lens            → horizon-dependent, report range
#    Regression vs Phase 1 at all seeds        → implementation issue, debug
# ============================================================
# End: Wed Aug  5 01:24:35 PM UTC 2026
