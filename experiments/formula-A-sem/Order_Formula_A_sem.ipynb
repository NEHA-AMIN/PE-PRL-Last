# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

project_path = '/content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1'
os.chdir(project_path)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1

# %%
# !ls -la /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/formula-A-sem/formula-A-sem-ph1.sh
# Out:
# -rw------- 1 root root 6849 Aug  5 11:07 /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/formula-A-sem/formula-A-sem-ph1.sh

# %%
import os

# Set your Informer data directory
informer_path = f'{project_path}/Informer2020-original'
data_dir = f'{informer_path}/data/ETT'
os.makedirs(data_dir, exist_ok=True)

# File path
data_file = f'{data_dir}/ETTh1.csv'

# Download ETTh1 dataset
if not os.path.exists(data_file):
    print("Downloading ETTh1.csv...")
    os.system(
        f'wget -q "https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv" '
        f'-O "{data_file}"'
    )

# Verify
if os.path.exists(data_file):
    print(f"✅ Download successful: {data_file}")
else:
    print("❌ Download failed.")
# Out:
# ✅ Download successful: /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/data/ETT/ETTh1.csv

# %%
# Fix np.Inf -> np.inf in tools.py (removed in NumPy 2.0)
tools_path = f'{project_path}/Informer2020-original/utils/tools.py'

with open(tools_path, 'r') as f:
    content = f.read()

content_fixed = content.replace('np.Inf', 'np.inf')

with open(tools_path, 'w') as f:
    f.write(content_fixed)

print(":white_check_mark: Fixed np.Inf -> np.inf in utils/tools.py")
# Out:
# :white_check_mark: Fixed np.Inf -> np.inf in utils/tools.py

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/formula-A-sem/formula-A-sem-ph1.sh
# Out:
# ============================================================
#  Formula A (Semantic Space) — Phase 1: Consecutive Delta Ordering
#  Date: Wed Aug  5 12:03:58 PM UTC 2026
# ------------------------------------------------------------
#  Formula:   X'_i = X_i + Delta(X_i) + T_i
#  Signal:    Delta(X_i) = X_i - X_{i-1}  (zero-pad at i=0)
#  pe_mode:   delta_pos
#  Replaces:  sinusoidal PE
# ------------------------------------------------------------
#  Seed:       2021
#  Pred lens:  96, 192
#  Total runs: 2
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/2: formula_a_sem_ph1_ETTh1_pred96_seed2021
# Start: Wed Aug  5 12:04:04 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph1_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph1_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [DELTA_POS step=0] val_norm=29.3220 | delta_norm=10.3215 | temp_norm=7.4262 | delta/val=0.3520
# [DELTA_POS step=0] val_norm=12.0789 | delta_norm=3.9759 | temp_norm=7.7150 | delta/val=0.3292
# 	iters: 100, epoch: 1 | loss: 0.4750034
# 	speed: 0.1588s/iter; left time: 235.8552s
# [DELTA_POS step=100] val_norm=31.3312 | delta_norm=9.9217 | temp_norm=7.5527 | delta/val=0.3167
# [DELTA_POS step=100] val_norm=12.7376 | delta_norm=3.8501 | temp_norm=7.7292 | delta/val=0.3023
# 	iters: 200, epoch: 1 | loss: 0.3199449
# 	speed: 0.0856s/iter; left time: 118.5082s
# [DELTA_POS step=200] val_norm=28.8563 | delta_norm=10.4545 | temp_norm=7.5730 | delta/val=0.3623
# [DELTA_POS step=200] val_norm=12.2718 | delta_norm=3.9818 | temp_norm=7.7877 | delta/val=0.3245
# Epoch: 1 cost time: 24.3503897190094
# Epoch: 1, Steps: 264 | Train Loss: 0.4033251 Vali Loss: 0.9035764 Test Loss: 0.8535110
# Validation loss decreased (inf --> 0.903576).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=29.8700 | delta_norm=10.9794 | temp_norm=7.5280 | delta/val=0.3676
# [DELTA_POS step=300] val_norm=11.9994 | delta_norm=4.2256 | temp_norm=7.7783 | delta/val=0.3522
# 	iters: 100, epoch: 2 | loss: 0.2531455
# 	speed: 0.1942s/iter; left time: 237.0699s
# [DELTA_POS step=400] val_norm=29.3009 | delta_norm=9.7575 | temp_norm=7.4383 | delta/val=0.3330
# [DELTA_POS step=400] val_norm=12.1461 | delta_norm=3.8255 | temp_norm=7.7563 | delta/val=0.3150
# 	iters: 200, epoch: 2 | loss: 0.2404854
# 	speed: 0.0878s/iter; left time: 98.4321s
# [DELTA_POS step=500] val_norm=29.2939 | delta_norm=11.0120 | temp_norm=7.5605 | delta/val=0.3759
# [DELTA_POS step=500] val_norm=11.8907 | delta_norm=4.3963 | temp_norm=7.7744 | delta/val=0.3697
# Epoch: 2 cost time: 23.08785390853882
# Epoch: 2, Steps: 264 | Train Loss: 0.2539529 Vali Loss: 0.9461085 Test Loss: 0.9632382
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=28.3946 | delta_norm=11.0944 | temp_norm=7.4932 | delta/val=0.3907
# [DELTA_POS step=600] val_norm=11.8953 | delta_norm=4.3308 | temp_norm=7.7821 | delta/val=0.3641
# 	iters: 100, epoch: 3 | loss: 0.2101979
# 	speed: 0.1969s/iter; left time: 188.4190s
# [DELTA_POS step=700] val_norm=29.4814 | delta_norm=10.0484 | temp_norm=7.6119 | delta/val=0.3408
# [DELTA_POS step=700] val_norm=12.4563 | delta_norm=3.8674 | temp_norm=7.8526 | delta/val=0.3105
# 	iters: 200, epoch: 3 | loss: 0.2287018
# 	speed: 0.0899s/iter; left time: 77.0587s
# Epoch: 3 cost time: 23.64354634284973
# Epoch: 3, Steps: 264 | Train Loss: 0.2139133 Vali Loss: 0.9861684 Test Loss: 0.9879725
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=28.7771 | delta_norm=10.4225 | temp_norm=7.4759 | delta/val=0.3622
# [DELTA_POS step=800] val_norm=11.8677 | delta_norm=4.0965 | temp_norm=7.7457 | delta/val=0.3452
# 	iters: 100, epoch: 4 | loss: 0.2100068
# 	speed: 0.2011s/iter; left time: 139.3784s
# [DELTA_POS step=900] val_norm=29.2588 | delta_norm=10.0578 | temp_norm=7.5666 | delta/val=0.3438
# [DELTA_POS step=900] val_norm=12.2051 | delta_norm=3.8918 | temp_norm=7.7783 | delta/val=0.3189
# 	iters: 200, epoch: 4 | loss: 0.2025379
# 	speed: 0.0915s/iter; left time: 54.2403s
# [DELTA_POS step=1000] val_norm=27.0965 | delta_norm=10.0071 | temp_norm=7.6120 | delta/val=0.3693
# [DELTA_POS step=1000] val_norm=11.2089 | delta_norm=3.7497 | temp_norm=7.7591 | delta/val=0.3345
# Epoch: 4 cost time: 24.08236598968506
# Epoch: 4, Steps: 264 | Train Loss: 0.1957636 Vali Loss: 0.9985517 Test Loss: 1.0016850
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph1_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.853510856628418, mae:0.7282997369766235
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:06:27 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/2: formula_a_sem_ph1_ETTh1_pred192_seed2021
# Start: Wed Aug  5 12:06:27 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph1_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph1_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [DELTA_POS step=0] val_norm=27.8922 | delta_norm=10.3236 | temp_norm=7.8477 | delta/val=0.3701
# [DELTA_POS step=0] val_norm=7.8615 | delta_norm=2.3633 | temp_norm=7.6544 | delta/val=0.3006
# 	iters: 100, epoch: 1 | loss: 0.4380212
# 	speed: 0.1366s/iter; left time: 200.3517s
# [DELTA_POS step=100] val_norm=29.4055 | delta_norm=10.7984 | temp_norm=7.7558 | delta/val=0.3672
# [DELTA_POS step=100] val_norm=8.1370 | delta_norm=2.5587 | temp_norm=7.6007 | delta/val=0.3144
# 	iters: 200, epoch: 1 | loss: 0.3637854
# 	speed: 0.1218s/iter; left time: 166.5098s
# [DELTA_POS step=200] val_norm=29.2329 | delta_norm=9.9825 | temp_norm=7.9568 | delta/val=0.3415
# [DELTA_POS step=200] val_norm=8.1690 | delta_norm=2.3064 | temp_norm=7.6651 | delta/val=0.2823
# Epoch: 1 cost time: 32.27275371551514
# Epoch: 1, Steps: 261 | Train Loss: 0.4182392 Vali Loss: 1.1863338 Test Loss: 0.9195337
# Validation loss decreased (inf --> 1.186334).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=31.6410 | delta_norm=10.3626 | temp_norm=7.7920 | delta/val=0.3275
# [DELTA_POS step=300] val_norm=8.8457 | delta_norm=2.4876 | temp_norm=7.5772 | delta/val=0.2812
# 	iters: 100, epoch: 2 | loss: 0.2672696
# 	speed: 0.2677s/iter; left time: 322.8668s
# [DELTA_POS step=400] val_norm=31.1736 | delta_norm=9.9180 | temp_norm=7.7825 | delta/val=0.3182
# [DELTA_POS step=400] val_norm=8.6282 | delta_norm=2.4082 | temp_norm=7.6075 | delta/val=0.2791
# 	iters: 200, epoch: 2 | loss: 0.2397417
# 	speed: 0.1247s/iter; left time: 137.8849s
# [DELTA_POS step=500] val_norm=28.9170 | delta_norm=10.4835 | temp_norm=7.8487 | delta/val=0.3625
# [DELTA_POS step=500] val_norm=8.1343 | delta_norm=2.4137 | temp_norm=7.6467 | delta/val=0.2967
# Epoch: 2 cost time: 32.399712562561035
# Epoch: 2, Steps: 261 | Train Loss: 0.2715553 Vali Loss: 1.2187403 Test Loss: 0.9903730
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=27.6892 | delta_norm=10.4788 | temp_norm=7.7397 | delta/val=0.3784
# [DELTA_POS step=600] val_norm=7.8949 | delta_norm=2.4907 | temp_norm=7.5782 | delta/val=0.3155
# 	iters: 100, epoch: 3 | loss: 0.2380655
# 	speed: 0.2703s/iter; left time: 255.4378s
# [DELTA_POS step=700] val_norm=28.0841 | delta_norm=10.2450 | temp_norm=7.7965 | delta/val=0.3648
# [DELTA_POS step=700] val_norm=8.0954 | delta_norm=2.3296 | temp_norm=7.6061 | delta/val=0.2878
# 	iters: 200, epoch: 3 | loss: 0.2323340
# 	speed: 0.1265s/iter; left time: 106.9289s
# Epoch: 3 cost time: 32.92718577384949
# Epoch: 3, Steps: 261 | Train Loss: 0.2281990 Vali Loss: 1.2561896 Test Loss: 0.9878430
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=32.2631 | delta_norm=10.5015 | temp_norm=7.8004 | delta/val=0.3255
# [DELTA_POS step=800] val_norm=9.0260 | delta_norm=2.5398 | temp_norm=7.6183 | delta/val=0.2814
# 	iters: 100, epoch: 4 | loss: 0.2176714
# 	speed: 0.2739s/iter; left time: 187.3523s
# [DELTA_POS step=900] val_norm=29.1782 | delta_norm=10.4381 | temp_norm=7.7803 | delta/val=0.3577
# [DELTA_POS step=900] val_norm=8.1698 | delta_norm=2.4486 | temp_norm=7.6405 | delta/val=0.2997
# 	iters: 200, epoch: 4 | loss: 0.2217788
# 	speed: 0.1285s/iter; left time: 75.0656s
# [DELTA_POS step=1000] val_norm=29.2182 | delta_norm=10.6045 | temp_norm=7.8211 | delta/val=0.3629
# [DELTA_POS step=1000] val_norm=8.1907 | delta_norm=2.4930 | temp_norm=7.5756 | delta/val=0.3044
# Epoch: 4 cost time: 33.420669078826904
# Epoch: 4, Steps: 261 | Train Loss: 0.2088072 Vali Loss: 1.2482755 Test Loss: 0.9535829
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph1_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.9195334911346436, mae:0.7540802955627441
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:09:14 PM UTC 2026
#
# ============================================================
#  PHASE 1 SUMMARY — Formula A (Semantic Space)
#  Total: 2 | Completed: 2 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
#  RUN_ID                                                         MSE        MAE
#  ------------------------------------------------------- ---------- ----------
#  formula_a_sem_ph1_ETTh1_pred96_seed2021                 0.853510856628418 0.7282997369766235
#  formula_a_sem_ph1_ETTh1_pred192_seed2021                0.9195334911346436 0.7540802955627441
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0 (seed=2021):
#    pred=96  MSE=0.8683
#    pred=192 MSE=0.8463  ← target to beat
#
#  DECISION GUIDE:
#    Formula-A-sem wins BOTH vs Exp1-Pre → proceed to Phase 2
#    Formula-A-sem wins ONE  vs Exp1-Pre → Phase 2 to confirm
#    Formula-A-sem loses BOTH            → document, stop
# ============================================================
# End: Wed Aug  5 12:09:15 PM UTC 2026

# %%
# !bash /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/experiments/formula-A-sem/formula-A-sem-ph2.sh
# Out:
# ============================================================
#  Formula A (Semantic Space) — Phase 2: Consecutive Delta Ordering
#  Date: Wed Aug  5 12:32:57 PM UTC 2026
# ------------------------------------------------------------
#  Formula:   X'_i = X_i + Delta(X_i) + T_i
#  Signal:    Delta(X_i) = X_i - X_{i-1}  (zero-pad at i=0)
#  pe_mode:   delta_pos
#  Replaces:  sinusoidal PE
# ------------------------------------------------------------
#  Seeds:      2021, 2022, 2023
#  Pred lens:  48, 96, 192, 336
#  Total runs: 12
# ============================================================
#
# Copying model files to /content/drive/MyDrive/Dist-Abl-PRL-All-Exs-ETTH1/Informer2020-original/models/ ...
# File copy complete.
#
# ------------------------------------------------------------
# RUN 1/12: formula_a_sem_ph2_ETTh1_pred48_seed2021
# pred_len=48 | seed=2021
# Start: Wed Aug  5 12:32:57 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred48_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred48_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# [DELTA_POS step=0] val_norm=28.0022 | delta_norm=10.8183 | temp_norm=7.5363 | delta/val=0.3863
# [DELTA_POS step=0] val_norm=15.5211 | delta_norm=5.7150 | temp_norm=7.4559 | delta/val=0.3682
# 	iters: 100, epoch: 1 | loss: 0.4162499
# 	speed: 0.0929s/iter; left time: 138.5651s
# [DELTA_POS step=100] val_norm=30.7901 | delta_norm=10.9019 | temp_norm=7.6578 | delta/val=0.3541
# [DELTA_POS step=100] val_norm=17.1823 | delta_norm=6.1705 | temp_norm=7.4775 | delta/val=0.3591
# 	iters: 200, epoch: 1 | loss: 0.2845391
# 	speed: 0.0706s/iter; left time: 98.1381s
# [DELTA_POS step=200] val_norm=28.8185 | delta_norm=10.8377 | temp_norm=7.7276 | delta/val=0.3761
# [DELTA_POS step=200] val_norm=16.1198 | delta_norm=6.0088 | temp_norm=7.6002 | delta/val=0.3728
# Epoch: 1 cost time: 19.389880180358887
# Epoch: 1, Steps: 265 | Train Loss: 0.3957142 Vali Loss: 0.8340311 Test Loss: 0.8772594
# Validation loss decreased (inf --> 0.834031).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=29.9930 | delta_norm=10.6671 | temp_norm=7.6511 | delta/val=0.3557
# [DELTA_POS step=300] val_norm=16.9863 | delta_norm=6.2840 | temp_norm=7.5288 | delta/val=0.3699
# 	iters: 100, epoch: 2 | loss: 0.2494469
# 	speed: 0.1594s/iter; left time: 195.4006s
# [DELTA_POS step=400] val_norm=28.8288 | delta_norm=10.6599 | temp_norm=7.7068 | delta/val=0.3698
# [DELTA_POS step=400] val_norm=16.3121 | delta_norm=6.1034 | temp_norm=7.5596 | delta/val=0.3742
# 	iters: 200, epoch: 2 | loss: 0.2082514
# 	speed: 0.0721s/iter; left time: 81.2086s
# [DELTA_POS step=500] val_norm=28.6414 | delta_norm=10.9534 | temp_norm=7.6381 | delta/val=0.3824
# [DELTA_POS step=500] val_norm=15.9031 | delta_norm=6.0771 | temp_norm=7.4967 | delta/val=0.3821
# Epoch: 2 cost time: 19.068758249282837
# Epoch: 2, Steps: 265 | Train Loss: 0.2482457 Vali Loss: 0.8596869 Test Loss: 0.9853670
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=28.5669 | delta_norm=10.2095 | temp_norm=7.6391 | delta/val=0.3574
# [DELTA_POS step=600] val_norm=16.0690 | delta_norm=5.6411 | temp_norm=7.5838 | delta/val=0.3511
# 	iters: 100, epoch: 3 | loss: 0.2346492
# 	speed: 0.1620s/iter; left time: 155.6440s
# [DELTA_POS step=700] val_norm=27.2807 | delta_norm=10.4767 | temp_norm=7.6012 | delta/val=0.3840
# [DELTA_POS step=700] val_norm=15.4564 | delta_norm=5.8448 | temp_norm=7.4740 | delta/val=0.3781
# 	iters: 200, epoch: 3 | loss: 0.1900646
# 	speed: 0.0740s/iter; left time: 63.7324s
# Epoch: 3 cost time: 19.49017834663391
# Epoch: 3, Steps: 265 | Train Loss: 0.2065129 Vali Loss: 0.8600591 Test Loss: 1.0369978
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=28.7843 | delta_norm=10.6273 | temp_norm=7.7147 | delta/val=0.3692
# [DELTA_POS step=800] val_norm=16.1836 | delta_norm=5.9545 | temp_norm=7.5130 | delta/val=0.3679
# 	iters: 100, epoch: 4 | loss: 0.2108918
# 	speed: 0.1650s/iter; left time: 114.8275s
# [DELTA_POS step=900] val_norm=29.8340 | delta_norm=10.3720 | temp_norm=7.6952 | delta/val=0.3477
# [DELTA_POS step=900] val_norm=16.5196 | delta_norm=5.6286 | temp_norm=7.5900 | delta/val=0.3407
# 	iters: 200, epoch: 4 | loss: 0.1704718
# 	speed: 0.0750s/iter; left time: 44.6805s
# [DELTA_POS step=1000] val_norm=28.1279 | delta_norm=11.0602 | temp_norm=7.6952 | delta/val=0.3932
# [DELTA_POS step=1000] val_norm=15.9075 | delta_norm=6.2307 | temp_norm=7.5261 | delta/val=0.3917
# Epoch: 4 cost time: 19.829922914505005
# Epoch: 4, Steps: 265 | Train Loss: 0.1886353 Vali Loss: 0.8625295 Test Loss: 0.9901623
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred48_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.8772595524787903, mae:0.7386218309402466
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:34:40 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 2/12: formula_a_sem_ph2_ETTh1_pred96_seed2021
# pred_len=96 | seed=2021
# Start: Wed Aug  5 12:34:40 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred96_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred96_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [DELTA_POS step=0] val_norm=28.8752 | delta_norm=10.8880 | temp_norm=7.5495 | delta/val=0.3771
# [DELTA_POS step=0] val_norm=11.2194 | delta_norm=3.9909 | temp_norm=7.5185 | delta/val=0.3557
# 	iters: 100, epoch: 1 | loss: 0.4099787
# 	speed: 0.1083s/iter; left time: 160.8601s
# [DELTA_POS step=100] val_norm=30.4725 | delta_norm=10.7771 | temp_norm=7.6331 | delta/val=0.3537
# [DELTA_POS step=100] val_norm=11.8023 | delta_norm=4.0367 | temp_norm=7.5276 | delta/val=0.3420
# 	iters: 200, epoch: 1 | loss: 0.3464969
# 	speed: 0.0911s/iter; left time: 126.2410s
# [DELTA_POS step=200] val_norm=29.4236 | delta_norm=9.6319 | temp_norm=7.6371 | delta/val=0.3274
# [DELTA_POS step=200] val_norm=11.4745 | delta_norm=3.5662 | temp_norm=7.5635 | delta/val=0.3108
# Epoch: 1 cost time: 24.534927368164062
# Epoch: 1, Steps: 264 | Train Loss: 0.4006296 Vali Loss: 0.9987529 Test Loss: 0.8431423
# Validation loss decreased (inf --> 0.998753).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=29.0737 | delta_norm=11.1153 | temp_norm=7.5682 | delta/val=0.3823
# [DELTA_POS step=300] val_norm=11.4273 | delta_norm=4.0985 | temp_norm=7.5715 | delta/val=0.3587
# 	iters: 100, epoch: 2 | loss: 0.2519770
# 	speed: 0.2055s/iter; left time: 250.9210s
# [DELTA_POS step=400] val_norm=29.4159 | delta_norm=10.1406 | temp_norm=7.6100 | delta/val=0.3447
# [DELTA_POS step=400] val_norm=11.4508 | delta_norm=3.7149 | temp_norm=7.5447 | delta/val=0.3244
# 	iters: 200, epoch: 2 | loss: 0.2342228
# 	speed: 0.0933s/iter; left time: 104.5438s
# [DELTA_POS step=500] val_norm=29.5313 | delta_norm=10.5949 | temp_norm=7.6254 | delta/val=0.3588
# [DELTA_POS step=500] val_norm=11.4799 | delta_norm=3.8593 | temp_norm=7.5952 | delta/val=0.3362
# Epoch: 2 cost time: 24.539573431015015
# Epoch: 2, Steps: 264 | Train Loss: 0.2531249 Vali Loss: 1.0393224 Test Loss: 0.9496312
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=27.9315 | delta_norm=10.1957 | temp_norm=7.4830 | delta/val=0.3650
# [DELTA_POS step=600] val_norm=10.9174 | delta_norm=3.7628 | temp_norm=7.4669 | delta/val=0.3447
# 	iters: 100, epoch: 3 | loss: 0.2169729
# 	speed: 0.2081s/iter; left time: 199.1107s
# [DELTA_POS step=700] val_norm=29.0745 | delta_norm=10.8088 | temp_norm=7.5865 | delta/val=0.3718
# [DELTA_POS step=700] val_norm=11.6333 | delta_norm=3.9840 | temp_norm=7.5621 | delta/val=0.3425
# 	iters: 200, epoch: 3 | loss: 0.2252052
# 	speed: 0.0946s/iter; left time: 81.0496s
# Epoch: 3 cost time: 24.892465114593506
# Epoch: 3, Steps: 264 | Train Loss: 0.2120133 Vali Loss: 1.0504677 Test Loss: 1.0100571
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=28.3026 | delta_norm=10.3438 | temp_norm=7.6355 | delta/val=0.3655
# [DELTA_POS step=800] val_norm=11.0221 | delta_norm=3.9053 | temp_norm=7.5480 | delta/val=0.3543
# 	iters: 100, epoch: 4 | loss: 0.1901369
# 	speed: 0.2099s/iter; left time: 145.4327s
# [DELTA_POS step=900] val_norm=28.0449 | delta_norm=10.5838 | temp_norm=7.5984 | delta/val=0.3774
# [DELTA_POS step=900] val_norm=11.0755 | delta_norm=3.8680 | temp_norm=7.5028 | delta/val=0.3492
# 	iters: 200, epoch: 4 | loss: 0.1947024
# 	speed: 0.0953s/iter; left time: 56.5029s
# [DELTA_POS step=1000] val_norm=28.0115 | delta_norm=11.1669 | temp_norm=7.5783 | delta/val=0.3987
# [DELTA_POS step=1000] val_norm=10.9320 | delta_norm=4.0511 | temp_norm=7.4987 | delta/val=0.3706
# Epoch: 4 cost time: 25.11954402923584
# Epoch: 4, Steps: 264 | Train Loss: 0.1934896 Vali Loss: 1.0412897 Test Loss: 1.0419403
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred96_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8431422114372253, mae:0.7324570417404175
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:36:50 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 3/12: formula_a_sem_ph2_ETTh1_pred192_seed2021
# pred_len=192 | seed=2021
# Start: Wed Aug  5 12:36:50 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred192_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred192_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [DELTA_POS step=0] val_norm=29.2766 | delta_norm=10.8122 | temp_norm=7.7104 | delta/val=0.3693
# [DELTA_POS step=0] val_norm=8.1817 | delta_norm=2.4947 | temp_norm=7.7815 | delta/val=0.3049
# 	iters: 100, epoch: 1 | loss: 0.4432281
# 	speed: 0.1398s/iter; left time: 205.1100s
# [DELTA_POS step=100] val_norm=28.5877 | delta_norm=10.7451 | temp_norm=7.7221 | delta/val=0.3759
# [DELTA_POS step=100] val_norm=8.0620 | delta_norm=2.4431 | temp_norm=7.7492 | delta/val=0.3030
# 	iters: 200, epoch: 1 | loss: 0.3625223
# 	speed: 0.1260s/iter; left time: 172.2289s
# [DELTA_POS step=200] val_norm=31.0172 | delta_norm=10.5570 | temp_norm=7.6828 | delta/val=0.3404
# [DELTA_POS step=200] val_norm=8.5038 | delta_norm=2.4290 | temp_norm=7.7455 | delta/val=0.2856
# Epoch: 1 cost time: 33.26874113082886
# Epoch: 1, Steps: 261 | Train Loss: 0.4120905 Vali Loss: 1.2235624 Test Loss: 0.9949386
# Validation loss decreased (inf --> 1.223562).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=28.9602 | delta_norm=10.8069 | temp_norm=7.5758 | delta/val=0.3732
# [DELTA_POS step=300] val_norm=8.0385 | delta_norm=2.4031 | temp_norm=7.6891 | delta/val=0.2989
# 	iters: 100, epoch: 2 | loss: 0.2618721
# 	speed: 0.2745s/iter; left time: 331.0404s
# [DELTA_POS step=400] val_norm=31.8799 | delta_norm=10.4651 | temp_norm=7.6370 | delta/val=0.3283
# [DELTA_POS step=400] val_norm=8.5455 | delta_norm=2.4085 | temp_norm=7.6885 | delta/val=0.2818
# 	iters: 200, epoch: 2 | loss: 0.2592410
# 	speed: 0.1280s/iter; left time: 141.5568s
# [DELTA_POS step=500] val_norm=30.6312 | delta_norm=10.4817 | temp_norm=7.5732 | delta/val=0.3422
# [DELTA_POS step=500] val_norm=8.4579 | delta_norm=2.3880 | temp_norm=7.6883 | delta/val=0.2823
# Epoch: 2 cost time: 33.309789180755615
# Epoch: 2, Steps: 261 | Train Loss: 0.2678013 Vali Loss: 1.2633604 Test Loss: 1.0526642
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=32.0421 | delta_norm=10.6001 | temp_norm=7.6213 | delta/val=0.3308
# [DELTA_POS step=600] val_norm=8.7854 | delta_norm=2.3766 | temp_norm=7.7349 | delta/val=0.2705
# 	iters: 100, epoch: 3 | loss: 0.2295951
# 	speed: 0.2756s/iter; left time: 260.4073s
# [DELTA_POS step=700] val_norm=28.4582 | delta_norm=10.4511 | temp_norm=7.6851 | delta/val=0.3672
# [DELTA_POS step=700] val_norm=8.0544 | delta_norm=2.3063 | temp_norm=7.7653 | delta/val=0.2863
# 	iters: 200, epoch: 3 | loss: 0.2240106
# 	speed: 0.1296s/iter; left time: 109.5085s
# Epoch: 3 cost time: 33.69514083862305
# Epoch: 3, Steps: 261 | Train Loss: 0.2244756 Vali Loss: 1.2826697 Test Loss: 1.0956358
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=30.0038 | delta_norm=10.9762 | temp_norm=7.6973 | delta/val=0.3658
# [DELTA_POS step=800] val_norm=8.3414 | delta_norm=2.4895 | temp_norm=7.7577 | delta/val=0.2985
# 	iters: 100, epoch: 4 | loss: 0.2037878
# 	speed: 0.2777s/iter; left time: 189.9689s
# [DELTA_POS step=900] val_norm=32.3202 | delta_norm=10.3509 | temp_norm=7.6929 | delta/val=0.3203
# [DELTA_POS step=900] val_norm=8.6870 | delta_norm=2.3474 | temp_norm=7.7627 | delta/val=0.2702
# 	iters: 200, epoch: 4 | loss: 0.2098889
# 	speed: 0.1304s/iter; left time: 76.1357s
# [DELTA_POS step=1000] val_norm=28.4815 | delta_norm=10.8873 | temp_norm=7.6170 | delta/val=0.3823
# [DELTA_POS step=1000] val_norm=7.9763 | delta_norm=2.4173 | temp_norm=7.7403 | delta/val=0.3031
# Epoch: 4 cost time: 33.983269453048706
# Epoch: 4, Steps: 261 | Train Loss: 0.2037278 Vali Loss: 1.2922366 Test Loss: 1.1004496
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred192_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.9949384927749634, mae:0.8178584575653076
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:39:42 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 4/12: formula_a_sem_ph2_ETTh1_pred336_seed2021
# pred_len=336 | seed=2021
# Start: Wed Aug  5 12:39:42 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred336_seed2021', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred336_seed2021_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [DELTA_POS step=0] val_norm=28.2272 | delta_norm=10.8273 | temp_norm=7.5564 | delta/val=0.3836
# [DELTA_POS step=0] val_norm=5.9928 | delta_norm=1.5554 | temp_norm=7.7711 | delta/val=0.2595
# 	iters: 100, epoch: 1 | loss: 0.4276166
# 	speed: 0.1980s/iter; left time: 284.5149s
# [DELTA_POS step=100] val_norm=28.9774 | delta_norm=11.1425 | temp_norm=7.5571 | delta/val=0.3845
# [DELTA_POS step=100] val_norm=6.0000 | delta_norm=1.5611 | temp_norm=7.7197 | delta/val=0.2602
# 	iters: 200, epoch: 1 | loss: 0.3710775
# 	speed: 0.1859s/iter; left time: 248.5139s
# [DELTA_POS step=200] val_norm=29.0525 | delta_norm=10.7521 | temp_norm=7.5657 | delta/val=0.3701
# [DELTA_POS step=200] val_norm=6.0473 | delta_norm=1.5491 | temp_norm=7.7442 | delta/val=0.2562
# Epoch: 1 cost time: 47.843250036239624
# Epoch: 1, Steps: 256 | Train Loss: 0.4317252 Vali Loss: 1.2921343 Test Loss: 0.9097078
# Validation loss decreased (inf --> 1.292134).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=30.3204 | delta_norm=10.3018 | temp_norm=7.6503 | delta/val=0.3398
# [DELTA_POS step=300] val_norm=6.1821 | delta_norm=1.4792 | temp_norm=7.6967 | delta/val=0.2393
# 	iters: 100, epoch: 2 | loss: 0.2906087
# 	speed: 0.3896s/iter; left time: 460.1689s
# [DELTA_POS step=400] val_norm=30.2585 | delta_norm=10.5639 | temp_norm=7.6460 | delta/val=0.3491
# [DELTA_POS step=400] val_norm=6.1369 | delta_norm=1.5101 | temp_norm=7.6704 | delta/val=0.2461
# 	iters: 200, epoch: 2 | loss: 0.2927920
# 	speed: 0.1885s/iter; left time: 203.7385s
# [DELTA_POS step=500] val_norm=30.8000 | delta_norm=10.5350 | temp_norm=7.5408 | delta/val=0.3420
# [DELTA_POS step=500] val_norm=6.2180 | delta_norm=1.5711 | temp_norm=7.7680 | delta/val=0.2527
# Epoch: 2 cost time: 48.06445527076721
# Epoch: 2, Steps: 256 | Train Loss: 0.2859557 Vali Loss: 1.3384684 Test Loss: 0.9823323
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=31.9030 | delta_norm=10.5370 | temp_norm=7.5424 | delta/val=0.3303
# [DELTA_POS step=600] val_norm=6.2852 | delta_norm=1.4865 | temp_norm=7.7191 | delta/val=0.2365
# 	iters: 100, epoch: 3 | loss: 0.2382445
# 	speed: 0.3907s/iter; left time: 361.4032s
# [DELTA_POS step=700] val_norm=29.6625 | delta_norm=10.3821 | temp_norm=7.6489 | delta/val=0.3500
# [DELTA_POS step=700] val_norm=6.0988 | delta_norm=1.4837 | temp_norm=7.8530 | delta/val=0.2433
# 	iters: 200, epoch: 3 | loss: 0.2362414
# 	speed: 0.1889s/iter; left time: 155.8675s
# Epoch: 3 cost time: 48.24038648605347
# Epoch: 3, Steps: 256 | Train Loss: 0.2457650 Vali Loss: 1.3929935 Test Loss: 1.0684372
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=31.0997 | delta_norm=10.7972 | temp_norm=7.6724 | delta/val=0.3472
# [DELTA_POS step=800] val_norm=6.1568 | delta_norm=1.5460 | temp_norm=7.7802 | delta/val=0.2511
# 	iters: 100, epoch: 4 | loss: 0.2249383
# 	speed: 0.3904s/iter; left time: 261.1997s
# [DELTA_POS step=900] val_norm=28.9463 | delta_norm=11.3734 | temp_norm=7.5318 | delta/val=0.3929
# [DELTA_POS step=900] val_norm=5.8897 | delta_norm=1.5193 | temp_norm=7.7058 | delta/val=0.2580
# 	iters: 200, epoch: 4 | loss: 0.2178938
# 	speed: 0.1889s/iter; left time: 107.4593s
# [DELTA_POS step=1000] val_norm=29.7314 | delta_norm=10.5612 | temp_norm=7.5669 | delta/val=0.3552
# [DELTA_POS step=1000] val_norm=6.0702 | delta_norm=1.4729 | temp_norm=7.7525 | delta/val=0.2426
# Epoch: 4 cost time: 48.20088577270508
# Epoch: 4, Steps: 256 | Train Loss: 0.2261704 Vali Loss: 1.3825585 Test Loss: 1.0969480
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred336_seed2021_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:0.9097078442573547, mae:0.7581148147583008
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:43:45 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 5/12: formula_a_sem_ph2_ETTh1_pred48_seed2022
# pred_len=48 | seed=2022
# Start: Wed Aug  5 12:43:45 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred48_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred48_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# [DELTA_POS step=0] val_norm=30.3084 | delta_norm=10.1111 | temp_norm=7.7634 | delta/val=0.3336
# [DELTA_POS step=0] val_norm=17.5498 | delta_norm=5.7851 | temp_norm=7.7610 | delta/val=0.3296
# 	iters: 100, epoch: 1 | loss: 0.4168483
# 	speed: 0.0973s/iter; left time: 145.0559s
# [DELTA_POS step=100] val_norm=28.6824 | delta_norm=10.3870 | temp_norm=7.6606 | delta/val=0.3621
# [DELTA_POS step=100] val_norm=16.2027 | delta_norm=5.8358 | temp_norm=7.6613 | delta/val=0.3602
# 	iters: 200, epoch: 1 | loss: 0.2735653
# 	speed: 0.0810s/iter; left time: 112.6071s
# [DELTA_POS step=200] val_norm=29.2958 | delta_norm=10.7996 | temp_norm=7.7127 | delta/val=0.3686
# [DELTA_POS step=200] val_norm=16.9437 | delta_norm=6.1334 | temp_norm=7.7714 | delta/val=0.3620
# Epoch: 1 cost time: 21.95423197746277
# Epoch: 1, Steps: 265 | Train Loss: 0.4035459 Vali Loss: 0.8374946 Test Loss: 0.7995041
# Validation loss decreased (inf --> 0.837495).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=27.4606 | delta_norm=10.3220 | temp_norm=7.6376 | delta/val=0.3759
# [DELTA_POS step=300] val_norm=15.8468 | delta_norm=5.8677 | temp_norm=7.6685 | delta/val=0.3703
# 	iters: 100, epoch: 2 | loss: 0.2728491
# 	speed: 0.1817s/iter; left time: 222.7744s
# [DELTA_POS step=400] val_norm=27.2960 | delta_norm=10.1360 | temp_norm=7.7914 | delta/val=0.3713
# [DELTA_POS step=400] val_norm=15.5840 | delta_norm=5.8420 | temp_norm=7.8083 | delta/val=0.3749
# 	iters: 200, epoch: 2 | loss: 0.2526002
# 	speed: 0.0812s/iter; left time: 91.4809s
# [DELTA_POS step=500] val_norm=30.7378 | delta_norm=11.0777 | temp_norm=7.5723 | delta/val=0.3604
# [DELTA_POS step=500] val_norm=17.5251 | delta_norm=6.2418 | temp_norm=7.6593 | delta/val=0.3562
# Epoch: 2 cost time: 21.459367990493774
# Epoch: 2, Steps: 265 | Train Loss: 0.2521192 Vali Loss: 0.8924151 Test Loss: 1.0087891
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=30.2965 | delta_norm=10.7555 | temp_norm=7.6821 | delta/val=0.3550
# [DELTA_POS step=600] val_norm=17.2712 | delta_norm=6.0429 | temp_norm=7.7274 | delta/val=0.3499
# 	iters: 100, epoch: 3 | loss: 0.2148854
# 	speed: 0.1808s/iter; left time: 173.7601s
# [DELTA_POS step=700] val_norm=29.9006 | delta_norm=10.8080 | temp_norm=7.5433 | delta/val=0.3615
# [DELTA_POS step=700] val_norm=17.6409 | delta_norm=6.2431 | temp_norm=7.6327 | delta/val=0.3539
# 	iters: 200, epoch: 3 | loss: 0.2000966
# 	speed: 0.0814s/iter; left time: 70.0896s
# Epoch: 3 cost time: 21.481847047805786
# Epoch: 3, Steps: 265 | Train Loss: 0.2090468 Vali Loss: 0.9049116 Test Loss: 1.0005692
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=31.1241 | delta_norm=10.8489 | temp_norm=7.6490 | delta/val=0.3486
# [DELTA_POS step=800] val_norm=17.4565 | delta_norm=6.4164 | temp_norm=7.6266 | delta/val=0.3676
# 	iters: 100, epoch: 4 | loss: 0.1877164
# 	speed: 0.1804s/iter; left time: 125.5627s
# [DELTA_POS step=900] val_norm=28.5824 | delta_norm=10.6533 | temp_norm=7.6826 | delta/val=0.3727
# [DELTA_POS step=900] val_norm=15.9925 | delta_norm=5.9576 | temp_norm=7.6629 | delta/val=0.3725
# 	iters: 200, epoch: 4 | loss: 0.1787294
# 	speed: 0.0812s/iter; left time: 48.3923s
# [DELTA_POS step=1000] val_norm=28.1429 | delta_norm=10.2454 | temp_norm=7.6944 | delta/val=0.3641
# [DELTA_POS step=1000] val_norm=16.4612 | delta_norm=5.7317 | temp_norm=7.6717 | delta/val=0.3482
# Epoch: 4 cost time: 21.49246048927307
# Epoch: 4, Steps: 265 | Train Loss: 0.1913981 Vali Loss: 0.9075266 Test Loss: 1.0076848
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred48_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.7995040416717529, mae:0.69896000623703
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:45:38 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 6/12: formula_a_sem_ph2_ETTh1_pred96_seed2022
# pred_len=96 | seed=2022
# Start: Wed Aug  5 12:45:38 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred96_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred96_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# [DELTA_POS step=0] val_norm=31.7090 | delta_norm=10.6771 | temp_norm=7.6751 | delta/val=0.3367
# [DELTA_POS step=0] val_norm=11.8085 | delta_norm=3.8846 | temp_norm=7.5741 | delta/val=0.3290
# 	iters: 100, epoch: 1 | loss: 0.4156586
# 	speed: 0.1119s/iter; left time: 166.2173s
# [DELTA_POS step=100] val_norm=30.8147 | delta_norm=10.5095 | temp_norm=7.6677 | delta/val=0.3411
# [DELTA_POS step=100] val_norm=11.8582 | delta_norm=3.8765 | temp_norm=7.5797 | delta/val=0.3269
# 	iters: 200, epoch: 1 | loss: 0.3113281
# 	speed: 0.0970s/iter; left time: 134.3527s
# [DELTA_POS step=200] val_norm=32.4453 | delta_norm=10.4691 | temp_norm=7.5838 | delta/val=0.3227
# [DELTA_POS step=200] val_norm=12.7511 | delta_norm=4.0297 | temp_norm=7.4295 | delta/val=0.3160
# Epoch: 1 cost time: 26.086766481399536
# Epoch: 1, Steps: 264 | Train Loss: 0.4028006 Vali Loss: 0.9745685 Test Loss: 0.8310517
# Validation loss decreased (inf --> 0.974568).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=30.8741 | delta_norm=10.3035 | temp_norm=7.6574 | delta/val=0.3337
# [DELTA_POS step=300] val_norm=11.8861 | delta_norm=4.0125 | temp_norm=7.4959 | delta/val=0.3376
# 	iters: 100, epoch: 2 | loss: 0.2559512
# 	speed: 0.2180s/iter; left time: 266.1916s
# [DELTA_POS step=400] val_norm=31.0389 | delta_norm=10.7784 | temp_norm=7.6865 | delta/val=0.3473
# [DELTA_POS step=400] val_norm=12.3294 | delta_norm=3.9699 | temp_norm=7.5631 | delta/val=0.3220
# 	iters: 200, epoch: 2 | loss: 0.2466588
# 	speed: 0.0975s/iter; left time: 109.2703s
# [DELTA_POS step=500] val_norm=30.1348 | delta_norm=10.5532 | temp_norm=7.8865 | delta/val=0.3502
# [DELTA_POS step=500] val_norm=11.5635 | delta_norm=3.8348 | temp_norm=7.6043 | delta/val=0.3316
# Epoch: 2 cost time: 25.76719617843628
# Epoch: 2, Steps: 264 | Train Loss: 0.2534055 Vali Loss: 0.9978960 Test Loss: 0.8775436
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=32.2671 | delta_norm=10.6258 | temp_norm=7.7044 | delta/val=0.3293
# [DELTA_POS step=600] val_norm=12.5580 | delta_norm=3.9758 | temp_norm=7.5597 | delta/val=0.3166
# 	iters: 100, epoch: 3 | loss: 0.2218428
# 	speed: 0.2174s/iter; left time: 208.0555s
# [DELTA_POS step=700] val_norm=29.4546 | delta_norm=10.9036 | temp_norm=7.6370 | delta/val=0.3702
# [DELTA_POS step=700] val_norm=11.3780 | delta_norm=3.9847 | temp_norm=7.5061 | delta/val=0.3502
# 	iters: 200, epoch: 3 | loss: 0.2087931
# 	speed: 0.0982s/iter; left time: 84.1492s
# Epoch: 3 cost time: 25.886144399642944
# Epoch: 3, Steps: 264 | Train Loss: 0.2148829 Vali Loss: 1.0327780 Test Loss: 0.9218058
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=33.1557 | delta_norm=10.9231 | temp_norm=7.6495 | delta/val=0.3294
# [DELTA_POS step=800] val_norm=12.9352 | delta_norm=4.0998 | temp_norm=7.5443 | delta/val=0.3170
# 	iters: 100, epoch: 4 | loss: 0.2065100
# 	speed: 0.2182s/iter; left time: 151.2144s
# [DELTA_POS step=900] val_norm=30.6469 | delta_norm=10.7610 | temp_norm=7.6935 | delta/val=0.3511
# [DELTA_POS step=900] val_norm=11.5600 | delta_norm=3.8620 | temp_norm=7.5453 | delta/val=0.3341
# 	iters: 200, epoch: 4 | loss: 0.1984540
# 	speed: 0.0986s/iter; left time: 58.4561s
# [DELTA_POS step=1000] val_norm=32.6346 | delta_norm=11.3630 | temp_norm=7.6137 | delta/val=0.3482
# [DELTA_POS step=1000] val_norm=12.5126 | delta_norm=4.1911 | temp_norm=7.4761 | delta/val=0.3349
# Epoch: 4 cost time: 26.01775884628296
# Epoch: 4, Steps: 264 | Train Loss: 0.1976289 Vali Loss: 1.0458221 Test Loss: 0.9343945
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred96_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8310517072677612, mae:0.7140151858329773
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:47:54 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 7/12: formula_a_sem_ph2_ETTh1_pred192_seed2022
# pred_len=192 | seed=2022
# Start: Wed Aug  5 12:47:54 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred192_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred192_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [DELTA_POS step=0] val_norm=30.9847 | delta_norm=10.3700 | temp_norm=7.5787 | delta/val=0.3347
# [DELTA_POS step=0] val_norm=8.4830 | delta_norm=2.4388 | temp_norm=7.6242 | delta/val=0.2875
# 	iters: 100, epoch: 1 | loss: 0.4390388
# 	speed: 0.1430s/iter; left time: 209.8030s
# [DELTA_POS step=100] val_norm=31.0765 | delta_norm=10.8797 | temp_norm=7.5364 | delta/val=0.3501
# [DELTA_POS step=100] val_norm=8.5944 | delta_norm=2.5440 | temp_norm=7.5196 | delta/val=0.2960
# 	iters: 200, epoch: 1 | loss: 0.3385297
# 	speed: 0.1293s/iter; left time: 176.8154s
# [DELTA_POS step=200] val_norm=29.5997 | delta_norm=10.7178 | temp_norm=7.6193 | delta/val=0.3621
# [DELTA_POS step=200] val_norm=8.3961 | delta_norm=2.4533 | temp_norm=7.6457 | delta/val=0.2922
# Epoch: 1 cost time: 34.14146685600281
# Epoch: 1, Steps: 261 | Train Loss: 0.4279111 Vali Loss: 1.1308223 Test Loss: 0.8169058
# Validation loss decreased (inf --> 1.130822).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=27.4894 | delta_norm=10.1941 | temp_norm=7.6266 | delta/val=0.3708
# [DELTA_POS step=300] val_norm=7.6670 | delta_norm=2.2730 | temp_norm=7.7172 | delta/val=0.2965
# 	iters: 100, epoch: 2 | loss: 0.2627599
# 	speed: 0.2797s/iter; left time: 337.3025s
# [DELTA_POS step=400] val_norm=31.8144 | delta_norm=9.8483 | temp_norm=7.6409 | delta/val=0.3096
# [DELTA_POS step=400] val_norm=8.6162 | delta_norm=2.3657 | temp_norm=7.6926 | delta/val=0.2746
# 	iters: 200, epoch: 2 | loss: 0.2583275
# 	speed: 0.1307s/iter; left time: 144.5789s
# [DELTA_POS step=500] val_norm=30.6686 | delta_norm=10.6951 | temp_norm=7.5588 | delta/val=0.3487
# [DELTA_POS step=500] val_norm=8.5004 | delta_norm=2.4240 | temp_norm=7.5789 | delta/val=0.2852
# Epoch: 2 cost time: 34.00473427772522
# Epoch: 2, Steps: 261 | Train Loss: 0.2731477 Vali Loss: 1.2266884 Test Loss: 0.9562562
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=29.8018 | delta_norm=10.6745 | temp_norm=7.6202 | delta/val=0.3582
# [DELTA_POS step=600] val_norm=8.4465 | delta_norm=2.4403 | temp_norm=7.6260 | delta/val=0.2889
# 	iters: 100, epoch: 3 | loss: 0.2497510
# 	speed: 0.2806s/iter; left time: 265.1360s
# [DELTA_POS step=700] val_norm=29.0326 | delta_norm=10.6947 | temp_norm=7.6740 | delta/val=0.3684
# [DELTA_POS step=700] val_norm=8.1018 | delta_norm=2.4467 | temp_norm=7.6693 | delta/val=0.3020
# 	iters: 200, epoch: 3 | loss: 0.2334443
# 	speed: 0.1315s/iter; left time: 111.1528s
# Epoch: 3 cost time: 34.24255633354187
# Epoch: 3, Steps: 261 | Train Loss: 0.2307621 Vali Loss: 1.2404330 Test Loss: 0.9477010
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=28.9783 | delta_norm=10.5802 | temp_norm=7.6283 | delta/val=0.3651
# [DELTA_POS step=800] val_norm=8.1934 | delta_norm=2.5538 | temp_norm=7.6501 | delta/val=0.3117
# 	iters: 100, epoch: 4 | loss: 0.2165972
# 	speed: 0.2823s/iter; left time: 193.0879s
# [DELTA_POS step=900] val_norm=28.6215 | delta_norm=10.8970 | temp_norm=7.5763 | delta/val=0.3807
# [DELTA_POS step=900] val_norm=8.1267 | delta_norm=2.5153 | temp_norm=7.6249 | delta/val=0.3095
# 	iters: 200, epoch: 4 | loss: 0.2095219
# 	speed: 0.1313s/iter; left time: 76.6938s
# [DELTA_POS step=1000] val_norm=29.6508 | delta_norm=10.6853 | temp_norm=7.6052 | delta/val=0.3604
# [DELTA_POS step=1000] val_norm=8.3507 | delta_norm=2.4172 | temp_norm=7.6603 | delta/val=0.2895
# Epoch: 4 cost time: 34.20984625816345
# Epoch: 4, Steps: 261 | Train Loss: 0.2103775 Vali Loss: 1.2700565 Test Loss: 0.9798253
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred192_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.8169058561325073, mae:0.7183377742767334
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:50:47 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 8/12: formula_a_sem_ph2_ETTh1_pred336_seed2022
# pred_len=336 | seed=2022
# Start: Wed Aug  5 12:50:47 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred336_seed2022', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred336_seed2022_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [DELTA_POS step=0] val_norm=27.8738 | delta_norm=10.1908 | temp_norm=7.5491 | delta/val=0.3656
# [DELTA_POS step=0] val_norm=5.9397 | delta_norm=1.3825 | temp_norm=7.6576 | delta/val=0.2328
# 	iters: 100, epoch: 1 | loss: 0.3902123
# 	speed: 0.2004s/iter; left time: 287.9172s
# [DELTA_POS step=100] val_norm=28.5134 | delta_norm=10.4179 | temp_norm=7.5566 | delta/val=0.3654
# [DELTA_POS step=100] val_norm=6.1218 | delta_norm=1.4461 | temp_norm=7.6791 | delta/val=0.2362
# 	iters: 200, epoch: 1 | loss: 0.3397591
# 	speed: 0.1883s/iter; left time: 251.7783s
# [DELTA_POS step=200] val_norm=30.2675 | delta_norm=10.4445 | temp_norm=7.5955 | delta/val=0.3451
# [DELTA_POS step=200] val_norm=6.2449 | delta_norm=1.4538 | temp_norm=7.7344 | delta/val=0.2328
# Epoch: 1 cost time: 48.47709679603577
# Epoch: 1, Steps: 256 | Train Loss: 0.4259899 Vali Loss: 1.2643427 Test Loss: 0.9712794
# Validation loss decreased (inf --> 1.264343).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=29.7489 | delta_norm=10.8875 | temp_norm=7.5267 | delta/val=0.3660
# [DELTA_POS step=300] val_norm=6.1539 | delta_norm=1.4643 | temp_norm=7.6645 | delta/val=0.2380
# 	iters: 100, epoch: 2 | loss: 0.2864812
# 	speed: 0.3914s/iter; left time: 462.2872s
# [DELTA_POS step=400] val_norm=28.6655 | delta_norm=10.7063 | temp_norm=7.5590 | delta/val=0.3735
# [DELTA_POS step=400] val_norm=6.1434 | delta_norm=1.5002 | temp_norm=7.6637 | delta/val=0.2442
# 	iters: 200, epoch: 2 | loss: 0.2547452
# 	speed: 0.1873s/iter; left time: 202.4758s
# [DELTA_POS step=500] val_norm=28.8508 | delta_norm=10.6966 | temp_norm=7.5546 | delta/val=0.3708
# [DELTA_POS step=500] val_norm=6.0419 | delta_norm=1.5147 | temp_norm=7.6373 | delta/val=0.2507
# Epoch: 2 cost time: 47.92095160484314
# Epoch: 2, Steps: 256 | Train Loss: 0.2813609 Vali Loss: 1.2914081 Test Loss: 1.1106017
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=30.2623 | delta_norm=10.8952 | temp_norm=7.5197 | delta/val=0.3600
# [DELTA_POS step=600] val_norm=6.1131 | delta_norm=1.4565 | temp_norm=7.6136 | delta/val=0.2383
# 	iters: 100, epoch: 3 | loss: 0.2333505
# 	speed: 0.3884s/iter; left time: 359.2870s
# [DELTA_POS step=700] val_norm=29.3572 | delta_norm=10.3702 | temp_norm=7.6045 | delta/val=0.3532
# [DELTA_POS step=700] val_norm=6.1838 | delta_norm=1.4368 | temp_norm=7.6358 | delta/val=0.2324
# 	iters: 200, epoch: 3 | loss: 0.2269924
# 	speed: 0.1879s/iter; left time: 155.0346s
# Epoch: 3 cost time: 47.99341344833374
# Epoch: 3, Steps: 256 | Train Loss: 0.2374551 Vali Loss: 1.3334875 Test Loss: 1.1521926
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=29.2730 | delta_norm=10.3990 | temp_norm=7.5782 | delta/val=0.3552
# [DELTA_POS step=800] val_norm=6.2007 | delta_norm=1.4600 | temp_norm=7.7041 | delta/val=0.2355
# 	iters: 100, epoch: 4 | loss: 0.2298588
# 	speed: 0.3889s/iter; left time: 260.1743s
# [DELTA_POS step=900] val_norm=30.1556 | delta_norm=10.7320 | temp_norm=7.5564 | delta/val=0.3559
# [DELTA_POS step=900] val_norm=6.3668 | delta_norm=1.5121 | temp_norm=7.7377 | delta/val=0.2375
# 	iters: 200, epoch: 4 | loss: 0.2176244
# 	speed: 0.1881s/iter; left time: 107.0038s
# [DELTA_POS step=1000] val_norm=31.2691 | delta_norm=10.5642 | temp_norm=7.4838 | delta/val=0.3378
# [DELTA_POS step=1000] val_norm=6.3211 | delta_norm=1.5010 | temp_norm=7.6815 | delta/val=0.2375
# Epoch: 4 cost time: 48.03423047065735
# Epoch: 4, Steps: 256 | Train Loss: 0.2172855 Vali Loss: 1.3252801 Test Loss: 1.1834704
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred336_seed2022_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:0.9712790846824646, mae:0.7961394190788269
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:54:48 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 9/12: formula_a_sem_ph2_ETTh1_pred48_seed2023
# pred_len=48 | seed=2023
# Start: Wed Aug  5 12:54:48 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=48, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred48_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred48_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8497
# val 2833
# test 2833
# [DELTA_POS step=0] val_norm=28.9403 | delta_norm=9.9213 | temp_norm=7.6243 | delta/val=0.3428
# [DELTA_POS step=0] val_norm=16.4602 | delta_norm=5.7514 | temp_norm=7.8959 | delta/val=0.3494
# 	iters: 100, epoch: 1 | loss: 0.4052701
# 	speed: 0.1034s/iter; left time: 154.2353s
# [DELTA_POS step=100] val_norm=28.4281 | delta_norm=10.1573 | temp_norm=7.6066 | delta/val=0.3573
# [DELTA_POS step=100] val_norm=15.9944 | delta_norm=5.7774 | temp_norm=7.8533 | delta/val=0.3612
# 	iters: 200, epoch: 1 | loss: 0.3160405
# 	speed: 0.0807s/iter; left time: 112.2189s
# [DELTA_POS step=200] val_norm=28.5584 | delta_norm=10.6285 | temp_norm=7.5300 | delta/val=0.3722
# [DELTA_POS step=200] val_norm=16.0437 | delta_norm=6.1809 | temp_norm=7.8942 | delta/val=0.3853
# Epoch: 1 cost time: 22.167338609695435
# Epoch: 1, Steps: 265 | Train Loss: 0.4069101 Vali Loss: 0.8567647 Test Loss: 0.8388438
# Validation loss decreased (inf --> 0.856765).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=31.2887 | delta_norm=10.6224 | temp_norm=7.5413 | delta/val=0.3395
# [DELTA_POS step=300] val_norm=16.9405 | delta_norm=6.1512 | temp_norm=7.9002 | delta/val=0.3631
# 	iters: 100, epoch: 2 | loss: 0.2653275
# 	speed: 0.1815s/iter; left time: 222.4983s
# [DELTA_POS step=400] val_norm=32.1181 | delta_norm=10.8248 | temp_norm=7.5738 | delta/val=0.3370
# [DELTA_POS step=400] val_norm=17.7346 | delta_norm=6.3533 | temp_norm=7.9231 | delta/val=0.3582
# 	iters: 200, epoch: 2 | loss: 0.2363962
# 	speed: 0.0810s/iter; left time: 91.1617s
# [DELTA_POS step=500] val_norm=27.1512 | delta_norm=10.3329 | temp_norm=7.5668 | delta/val=0.3806
# [DELTA_POS step=500] val_norm=14.8306 | delta_norm=5.6143 | temp_norm=7.8466 | delta/val=0.3786
# Epoch: 2 cost time: 21.44235134124756
# Epoch: 2, Steps: 265 | Train Loss: 0.2533344 Vali Loss: 0.8963882 Test Loss: 1.0126159
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=28.5971 | delta_norm=11.0848 | temp_norm=7.5680 | delta/val=0.3876
# [DELTA_POS step=600] val_norm=15.9190 | delta_norm=6.1363 | temp_norm=7.9241 | delta/val=0.3855
# 	iters: 100, epoch: 3 | loss: 0.1856801
# 	speed: 0.1805s/iter; left time: 173.4144s
# [DELTA_POS step=700] val_norm=30.3900 | delta_norm=10.2112 | temp_norm=7.6330 | delta/val=0.3360
# [DELTA_POS step=700] val_norm=16.5715 | delta_norm=5.7536 | temp_norm=7.9944 | delta/val=0.3472
# 	iters: 200, epoch: 3 | loss: 0.1980626
# 	speed: 0.0812s/iter; left time: 69.9286s
# Epoch: 3 cost time: 21.494569063186646
# Epoch: 3, Steps: 265 | Train Loss: 0.2096300 Vali Loss: 0.9167469 Test Loss: 1.1239277
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=30.9331 | delta_norm=10.3622 | temp_norm=7.5433 | delta/val=0.3350
# [DELTA_POS step=800] val_norm=17.3187 | delta_norm=6.0096 | temp_norm=7.8834 | delta/val=0.3470
# 	iters: 100, epoch: 4 | loss: 0.2063469
# 	speed: 0.1805s/iter; left time: 125.6094s
# [DELTA_POS step=900] val_norm=28.4799 | delta_norm=10.6425 | temp_norm=7.5213 | delta/val=0.3737
# [DELTA_POS step=900] val_norm=15.9259 | delta_norm=6.2460 | temp_norm=7.9104 | delta/val=0.3922
# 	iters: 200, epoch: 4 | loss: 0.1842217
# 	speed: 0.0810s/iter; left time: 48.2700s
# [DELTA_POS step=1000] val_norm=31.3021 | delta_norm=10.7330 | temp_norm=7.5446 | delta/val=0.3429
# [DELTA_POS step=1000] val_norm=17.4814 | delta_norm=6.0879 | temp_norm=7.8322 | delta/val=0.3483
# Epoch: 4 cost time: 21.465626001358032
# Epoch: 4, Steps: 265 | Train Loss: 0.1914413 Vali Loss: 0.9341202 Test Loss: 1.1229762
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred48_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2833
# test shape: (88, 32, 48, 7) (88, 32, 48, 7)
# test shape: (2816, 48, 7) (2816, 48, 7)
# mse:0.8388440608978271, mae:0.7162598967552185
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:56:42 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 10/12: formula_a_sem_ph2_ETTh1_pred96_seed2023
# pred_len=96 | seed=2023
# Start: Wed Aug  5 12:56:42 PM UTC 2026
# Args in experiment:
# ...
# train 8449
# val 2785
# test 2785
# [DELTA_POS step=0] val_norm=31.5522 | delta_norm=10.7777 | temp_norm=7.6874 | delta/val=0.3416
# [DELTA_POS step=0] val_norm=12.7361 | delta_norm=4.1343 | temp_norm=7.4953 | delta/val=0.3246
# 	iters: 100, epoch: 1 | loss: 0.4100486
# 	speed: 0.1174s/iter; left time: 174.3401s
# [DELTA_POS step=100] val_norm=29.2375 | delta_norm=10.5913 | temp_norm=7.8222 | delta/val=0.3623
# [DELTA_POS step=100] val_norm=11.6348 | delta_norm=3.9316 | temp_norm=7.6220 | delta/val=0.3379
# 	iters: 200, epoch: 1 | loss: 0.3172826
# 	speed: 0.0970s/iter; left time: 134.2884s
# [DELTA_POS step=200] val_norm=30.5930 | delta_norm=10.3221 | temp_norm=7.7452 | delta/val=0.3374
# [DELTA_POS step=200] val_norm=12.1979 | delta_norm=3.9283 | temp_norm=7.5978 | delta/val=0.3221
# Epoch: 1 cost time: 26.266575813293457
# Epoch: 1, Steps: 264 | Train Loss: 0.4023837 Vali Loss: 0.9893946 Test Loss: 0.8739126
# Validation loss decreased (inf --> 0.989395).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=29.5987 | delta_norm=10.8228 | temp_norm=7.7192 | delta/val=0.3657
# [DELTA_POS step=300] val_norm=11.8627 | delta_norm=4.1606 | temp_norm=7.5888 | delta/val=0.3507
# 	iters: 100, epoch: 2 | loss: 0.2457066
# 	speed: 0.2173s/iter; left time: 265.3475s
# [DELTA_POS step=400] val_norm=28.5548 | delta_norm=10.3808 | temp_norm=7.7748 | delta/val=0.3635
# [DELTA_POS step=400] val_norm=11.7946 | delta_norm=3.8950 | temp_norm=7.6263 | delta/val=0.3302
# 	iters: 200, epoch: 2 | loss: 0.2178345
# 	speed: 0.0976s/iter; left time: 109.3552s
# [DELTA_POS step=500] val_norm=30.8787 | delta_norm=10.0872 | temp_norm=7.8262 | delta/val=0.3267
# [DELTA_POS step=500] val_norm=12.7949 | delta_norm=3.7767 | temp_norm=7.6681 | delta/val=0.2952
# Epoch: 2 cost time: 25.668319702148438
# Epoch: 2, Steps: 264 | Train Loss: 0.2554904 Vali Loss: 1.0079863 Test Loss: 0.9929709
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=30.3520 | delta_norm=10.0857 | temp_norm=7.7317 | delta/val=0.3323
# [DELTA_POS step=600] val_norm=12.3119 | delta_norm=3.8861 | temp_norm=7.6354 | delta/val=0.3156
# 	iters: 100, epoch: 3 | loss: 0.2215674
# 	speed: 0.2167s/iter; left time: 207.3758s
# [DELTA_POS step=700] val_norm=29.0294 | delta_norm=10.8073 | temp_norm=7.7531 | delta/val=0.3723
# [DELTA_POS step=700] val_norm=11.5445 | delta_norm=3.8481 | temp_norm=7.6501 | delta/val=0.3333
# 	iters: 200, epoch: 3 | loss: 0.2090925
# 	speed: 0.0981s/iter; left time: 84.0527s
# Epoch: 3 cost time: 25.83340835571289
# Epoch: 3, Steps: 264 | Train Loss: 0.2136678 Vali Loss: 1.0294603 Test Loss: 0.9923073
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=28.2554 | delta_norm=10.0284 | temp_norm=7.8220 | delta/val=0.3549
# [DELTA_POS step=800] val_norm=11.4803 | delta_norm=3.7727 | temp_norm=7.6795 | delta/val=0.3286
# 	iters: 100, epoch: 4 | loss: 0.2113895
# 	speed: 0.2180s/iter; left time: 151.0816s
# [DELTA_POS step=900] val_norm=30.6597 | delta_norm=10.2496 | temp_norm=7.8171 | delta/val=0.3343
# [DELTA_POS step=900] val_norm=11.8785 | delta_norm=3.7509 | temp_norm=7.6356 | delta/val=0.3158
# 	iters: 200, epoch: 4 | loss: 0.1768016
# 	speed: 0.0989s/iter; left time: 58.6219s
# [DELTA_POS step=1000] val_norm=30.2019 | delta_norm=10.6879 | temp_norm=7.7223 | delta/val=0.3539
# [DELTA_POS step=1000] val_norm=12.0640 | delta_norm=4.0693 | temp_norm=7.5952 | delta/val=0.3373
# Epoch: 4 cost time: 26.01451849937439
# Epoch: 4, Steps: 264 | Train Loss: 0.1956866 Vali Loss: 1.0612340 Test Loss: 1.0299700
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred96_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.8739127516746521, mae:0.7304813265800476
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 12:58:57 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 11/12: formula_a_sem_ph2_ETTh1_pred192_seed2023
# pred_len=192 | seed=2023
# Start: Wed Aug  5 12:58:57 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=192, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred192_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred192_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8353
# val 2689
# test 2689
# [DELTA_POS step=0] val_norm=29.3366 | delta_norm=10.3725 | temp_norm=7.6422 | delta/val=0.3536
# [DELTA_POS step=0] val_norm=8.2509 | delta_norm=2.2586 | temp_norm=7.7858 | delta/val=0.2737
# 	iters: 100, epoch: 1 | loss: 0.3978625
# 	speed: 0.1424s/iter; left time: 208.8846s
# [DELTA_POS step=100] val_norm=29.8430 | delta_norm=10.6100 | temp_norm=7.5786 | delta/val=0.3555
# [DELTA_POS step=100] val_norm=8.4283 | delta_norm=2.3637 | temp_norm=7.7400 | delta/val=0.2805
# 	iters: 200, epoch: 1 | loss: 0.3132774
# 	speed: 0.1285s/iter; left time: 175.5988s
# [DELTA_POS step=200] val_norm=28.2652 | delta_norm=9.9793 | temp_norm=7.6799 | delta/val=0.3531
# [DELTA_POS step=200] val_norm=7.9066 | delta_norm=2.2241 | temp_norm=7.6875 | delta/val=0.2813
# Epoch: 1 cost time: 33.907355308532715
# Epoch: 1, Steps: 261 | Train Loss: 0.4142803 Vali Loss: 1.1545372 Test Loss: 0.8467879
# Validation loss decreased (inf --> 1.154537).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=28.9385 | delta_norm=10.3055 | temp_norm=7.6638 | delta/val=0.3561
# [DELTA_POS step=300] val_norm=7.8450 | delta_norm=2.3023 | temp_norm=7.8014 | delta/val=0.2935
# 	iters: 100, epoch: 2 | loss: 0.2560346
# 	speed: 0.2783s/iter; left time: 335.5979s
# [DELTA_POS step=400] val_norm=28.3330 | delta_norm=10.8650 | temp_norm=7.5291 | delta/val=0.3835
# [DELTA_POS step=400] val_norm=8.0052 | delta_norm=2.3907 | temp_norm=7.7066 | delta/val=0.2986
# 	iters: 200, epoch: 2 | loss: 0.2588462
# 	speed: 0.1299s/iter; left time: 143.6823s
# [DELTA_POS step=500] val_norm=29.0482 | delta_norm=10.8606 | temp_norm=7.5573 | delta/val=0.3739
# [DELTA_POS step=500] val_norm=8.2671 | delta_norm=2.4156 | temp_norm=7.7688 | delta/val=0.2922
# Epoch: 2 cost time: 33.83220958709717
# Epoch: 2, Steps: 261 | Train Loss: 0.2687383 Vali Loss: 1.2400120 Test Loss: 0.9604222
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=27.3970 | delta_norm=10.4293 | temp_norm=7.5923 | delta/val=0.3807
# [DELTA_POS step=600] val_norm=7.7140 | delta_norm=2.2993 | temp_norm=7.6344 | delta/val=0.2981
# 	iters: 100, epoch: 3 | loss: 0.2419434
# 	speed: 0.2815s/iter; left time: 266.0165s
# [DELTA_POS step=700] val_norm=28.8179 | delta_norm=10.4028 | temp_norm=7.6673 | delta/val=0.3610
# [DELTA_POS step=700] val_norm=8.0561 | delta_norm=2.3124 | temp_norm=7.7707 | delta/val=0.2870
# 	iters: 200, epoch: 3 | loss: 0.2230140
# 	speed: 0.1314s/iter; left time: 111.0565s
# Epoch: 3 cost time: 34.21243357658386
# Epoch: 3, Steps: 261 | Train Loss: 0.2284210 Vali Loss: 1.2521437 Test Loss: 1.0177962
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=30.0300 | delta_norm=10.9883 | temp_norm=7.5909 | delta/val=0.3659
# [DELTA_POS step=800] val_norm=8.5246 | delta_norm=2.5476 | temp_norm=7.8089 | delta/val=0.2989
# 	iters: 100, epoch: 4 | loss: 0.2127549
# 	speed: 0.2798s/iter; left time: 191.3676s
# [DELTA_POS step=900] val_norm=27.6683 | delta_norm=10.9947 | temp_norm=7.6418 | delta/val=0.3974
# [DELTA_POS step=900] val_norm=7.8492 | delta_norm=2.3717 | temp_norm=7.7949 | delta/val=0.3022
# 	iters: 200, epoch: 4 | loss: 0.2106165
# 	speed: 0.1308s/iter; left time: 76.3945s
# [DELTA_POS step=1000] val_norm=30.6963 | delta_norm=10.3819 | temp_norm=7.5685 | delta/val=0.3382
# [DELTA_POS step=1000] val_norm=8.6827 | delta_norm=2.3419 | temp_norm=7.7193 | delta/val=0.2697
# Epoch: 4 cost time: 34.01599454879761
# Epoch: 4, Steps: 261 | Train Loss: 0.2091034 Vali Loss: 1.2740120 Test Loss: 1.0967062
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl192_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred192_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2689
# test shape: (84, 32, 192, 7) (84, 32, 192, 7)
# test shape: (2688, 192, 7) (2688, 192, 7)
# mse:0.8467883467674255, mae:0.7108168601989746
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:01:50 PM UTC 2026
#
# ------------------------------------------------------------
# RUN 12/12: formula_a_sem_ph2_ETTh1_pred336_seed2023
# pred_len=336 | seed=2023
# Start: Wed Aug  5 01:01:50 PM UTC 2026
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=336, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='full', embed='timeF', activation='gelu', output_attention=False, decay_a=1.0, do_predict=False, mix=True, cols=None, num_workers=0, itr=1, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='formula_a_sem_ph2_ETTh1_pred336_seed2023', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', pe_mode='delta_pos', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred336_seed2023_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2545
# test 2545
# [DELTA_POS step=0] val_norm=28.2415 | delta_norm=10.6484 | temp_norm=7.8871 | delta/val=0.3770
# [DELTA_POS step=0] val_norm=5.9941 | delta_norm=1.5047 | temp_norm=7.6483 | delta/val=0.2510
# 	iters: 100, epoch: 1 | loss: 0.4762340
# 	speed: 0.2001s/iter; left time: 287.5253s
# [DELTA_POS step=100] val_norm=30.6084 | delta_norm=11.1300 | temp_norm=7.8954 | delta/val=0.3636
# [DELTA_POS step=100] val_norm=6.1612 | delta_norm=1.5189 | temp_norm=7.6522 | delta/val=0.2465
# 	iters: 200, epoch: 1 | loss: 0.3227529
# 	speed: 0.1879s/iter; left time: 251.1921s
# [DELTA_POS step=200] val_norm=28.9734 | delta_norm=10.7732 | temp_norm=7.8473 | delta/val=0.3718
# [DELTA_POS step=200] val_norm=6.0215 | delta_norm=1.4829 | temp_norm=7.5534 | delta/val=0.2463
# Epoch: 1 cost time: 48.30935192108154
# Epoch: 1, Steps: 256 | Train Loss: 0.4279209 Vali Loss: 1.2487875 Test Loss: 0.8964798
# Validation loss decreased (inf --> 1.248788).  Saving model ...
# Updating learning rate to 0.0001
# [DELTA_POS step=300] val_norm=30.6001 | delta_norm=10.9954 | temp_norm=7.7781 | delta/val=0.3593
# [DELTA_POS step=300] val_norm=6.1894 | delta_norm=1.5609 | temp_norm=7.5462 | delta/val=0.2522
# 	iters: 100, epoch: 2 | loss: 0.2874895
# 	speed: 0.3911s/iter; left time: 461.9005s
# [DELTA_POS step=400] val_norm=30.5338 | delta_norm=10.8143 | temp_norm=7.9382 | delta/val=0.3542
# [DELTA_POS step=400] val_norm=6.2040 | delta_norm=1.5011 | temp_norm=7.6197 | delta/val=0.2420
# 	iters: 200, epoch: 2 | loss: 0.2795498
# 	speed: 0.1885s/iter; left time: 203.7448s
# [DELTA_POS step=500] val_norm=29.7256 | delta_norm=10.6863 | temp_norm=7.8401 | delta/val=0.3595
# [DELTA_POS step=500] val_norm=6.1119 | delta_norm=1.4971 | temp_norm=7.6094 | delta/val=0.2449
# Epoch: 2 cost time: 48.13056135177612
# Epoch: 2, Steps: 256 | Train Loss: 0.2823478 Vali Loss: 1.2700727 Test Loss: 1.0338489
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# [DELTA_POS step=600] val_norm=29.3606 | delta_norm=10.6434 | temp_norm=7.8668 | delta/val=0.3625
# [DELTA_POS step=600] val_norm=6.0516 | delta_norm=1.4748 | temp_norm=7.6172 | delta/val=0.2437
# 	iters: 100, epoch: 3 | loss: 0.2373513
# 	speed: 0.3910s/iter; left time: 361.7067s
# [DELTA_POS step=700] val_norm=28.9284 | delta_norm=10.6304 | temp_norm=7.9517 | delta/val=0.3675
# [DELTA_POS step=700] val_norm=5.9956 | delta_norm=1.3817 | temp_norm=7.6811 | delta/val=0.2305
# 	iters: 200, epoch: 3 | loss: 0.2428236
# 	speed: 0.1898s/iter; left time: 156.5753s
# Epoch: 3 cost time: 48.35558724403381
# Epoch: 3, Steps: 256 | Train Loss: 0.2381304 Vali Loss: 1.3020017 Test Loss: 1.0677255
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# [DELTA_POS step=800] val_norm=30.0524 | delta_norm=11.0798 | temp_norm=7.8845 | delta/val=0.3687
# [DELTA_POS step=800] val_norm=6.1246 | delta_norm=1.5630 | temp_norm=7.6255 | delta/val=0.2552
# 	iters: 100, epoch: 4 | loss: 0.2174279
# 	speed: 0.3891s/iter; left time: 260.3216s
# [DELTA_POS step=900] val_norm=30.8446 | delta_norm=10.1803 | temp_norm=7.8800 | delta/val=0.3301
# [DELTA_POS step=900] val_norm=6.2519 | delta_norm=1.3792 | temp_norm=7.6162 | delta/val=0.2206
# 	iters: 200, epoch: 4 | loss: 0.2169779
# 	speed: 0.1889s/iter; left time: 107.4643s
# [DELTA_POS step=1000] val_norm=31.5234 | delta_norm=10.8238 | temp_norm=7.9054 | delta/val=0.3434
# [DELTA_POS step=1000] val_norm=6.3112 | delta_norm=1.4939 | temp_norm=7.6038 | delta/val=0.2367
# Epoch: 4 cost time: 48.15570378303528
# Epoch: 4, Steps: 256 | Train Loss: 0.2171163 Vali Loss: 1.3199512 Test Loss: 1.0687952
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_ETTh1_ftM_sl96_ll48_pl336_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_formula_a_sem_ph2_ETTh1_pred336_seed2023_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2545
# test shape: (79, 32, 336, 7) (79, 32, 336, 7)
# test shape: (2528, 336, 7) (2528, 336, 7)
# mse:0.8964798450469971, mae:0.7633677124977112
# STATUS: COMPLETED
# STATUS: COMPLETED
# End: Wed Aug  5 01:05:52 PM UTC 2026
#
# ============================================================
#  PHASE 2 SUMMARY — Formula A (Semantic Space)
#  Total: 12 | Completed: 12 | Failed: 0 | Skipped: 0
# ------------------------------------------------------------
# Seed  | PredLen | MSE      | MAE
# ------|---------|----------|----------
# 2021  | 48      | 0.8772595524787903 | 0.7386218309402466
# 2021  | 96      | 0.8431422114372253 | 0.7324570417404175
# 2021  | 192     | 0.9949384927749634 | 0.8178584575653076
# 2021  | 336     | 0.9097078442573547 | 0.7581148147583008
#
# 2022  | 48      | 0.7995040416717529 | 0.69896000623703
# 2022  | 96      | 0.8310517072677612 | 0.7140151858329773
# 2022  | 192     | 0.8169058561325073 | 0.7183377742767334
# 2022  | 336     | 0.9712790846824646 | 0.7961394190788269
#
# 2023  | 48      | 0.8388440608978271 | 0.7162598967552185
# 2023  | 96      | 0.8739127516746521 | 0.7304813265800476
# 2023  | 192     | 0.8467883467674255 | 0.7108168601989746
# 2023  | 336     | 0.8964798450469971 | 0.7633677124977112
#
# ------------------------------------------------------------
#  REFERENCE — Exp1-Pre alpha=1.0:
#  seed=2021 | pred=96  MSE=0.8683
#  seed=2021 | pred=192 MSE=0.8463  ← Phase 1 target
#
#  DECISION GUIDE:
#    Consistent improvement across all 3 seeds → result is robust
#    Improvement only at seed=2021             → Phase 1 was a fluke, investigate
#    Mixed results across pred_lens            → horizon-dependent, report range
#    Regression vs Phase 1 at all seeds        → implementation issue, debug
# ============================================================
# End: Wed Aug  5 01:05:53 PM UTC 2026
